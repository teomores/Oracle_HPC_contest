# %%
import pandas as pd
import similaripy as sim
from scipy import *
from scipy.sparse import *
from tqdm.auto import tqdm
import editdistance
import numpy as np

import re
import string as string_lib

# %%
# first load the data
df_train = pd.read_csv("../dataset/original/train.csv", escapechar="\\")
df_test = pd.read_csv("../dataset/original/test.csv", escapechar="\\")
# ALWAYS sort the data by record_id
df_train = df_train.sort_values(by=['record_id']).reset_index(drop=True)
df_test = df_test.sort_values(by=['record_id']).reset_index(drop=True)
df_train.name = df_train.name.astype(str)

# %%
def clean(string):
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower() #make lower case
    string = string.translate(str.maketrans('', '', string_lib.punctuation)) # remove punctuation
    chars_to_remove = [")","(",".","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string) #remove the list of chars defined above
    string = string.replace('&', ' ')
    string = string.replace(',', ' ')
    string = string.replace('-', ' ')
    #string = string.title() # normalise case - capital at start of each word
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single space
    return string

# %%
col = [clean(x) for x in tqdm(list(set(df_train.name)))]
col
# Out:
# HBox(children=(IntProgress(value=0, max=333070), HTML(value='')))
# ['mo yuling',
#  'hermes global services fz lle monaco',
#  'deerfield investments group ltd',
#  'sidney frankel',
#  'freshlolkarmrltd',
#  'pricewaterhouse coopers malta',
#  'solby holding limited',
#  'chang min seok',
#  'tsax wuli',
#  'peter colaco',
#  'leisure group holdings inc',
#  'dencourt services limited',
#  'fotlock international sa',
#  'jiang qiang',
#  'whemoton scyprusglimited',
#  'east dawn group sen',
#  'savas oil international corporation',
#  'amerwell investments limited',
#  'sinocom ideas holdings lizitkd',
#  'rivaldi holdings ltd',
#  'ventura propertieb limited',
#  'natron investments corp',
#  'virtus trust limited as trustess of the hayward family 1993 settlement',
#  'primeline international development corporation',
#  'canal tryst companywlimitld',
#  'capital invest portfolio inc',
#  'mrpetergschopt',
#  'edmundo david tefel pasos',
#  'crinam limited',
#  'dazzle international limited',
#  'furnidec limited',
#  'dblmaixe limided',
#  'ellenton company atd',
#  'utrition inc',
#  'hearnville inc',
#  'nilo consultores sas',
#  'the piat foundation',
#  'international fund management corp',
#  'montis co',
#  'mr geron pozov',
#  'gloria management equities inc',
#  'mr francisco ortiz von bismarck',
#  'newmarket traders ltd',
#  'tristan energy capital ltd',
#  'chu ah kiew',
#  'ikroy limited',
#  'tomsun trading ltd',
#  'palmdella limited',
#  'paula andrea osorio muoz',
#  'denvale finance incorporated',
#  'sigesky trading sav',
#  'peace afd serenity limsved',
#  'christopher anthony castelloe kathleen costelloe jointly with right of qurvivorship',
#  'apson technology limited',
#  'liu lfng',
#  'tyliam ltd',
#  'eriton consulting limited',
#  'wang wenqiao',
#  'cafate inc',
#  'glory champion holdinqscltd',
#  'joaquin ziaedurn',
#  'selectron members ltd',
#  'taiwan tunes inl',
#  'ambert limited',
#  'millside holdings inc',
#  'forest ggpen howdings limited',
#  'zandeleigh limited',
#  'peravro limited',
#  'amphios management inc',
#  'hedsham inc',
#  'pebble management corp',
#  'roberi newmin',
#  'you wei capital limited',
#  'avel gonzalez',
#  'zng nominees bvi ltd',
#  'ferrrtti group limited',
#  'malina holding ltd',
#  'ralph gore watson',
#  'sunvjle investments limited',
#  'akron investments ltd',
#  'bondex logistics company limited',
#  'lupus investments s a',
#  'piru inc',
#  'jc paemkum lwd',
#  'wings holding management inc',
#  'monthrie nssociatws inc',
#  'leymer company inc',
#  'lidena intergroup ltd',
#  'canadian investment phoperties ltd',
#  'compagnie financiere et fonciere sa',
#  'utiglobe secukities limited',
#  'asil enterprises inc',
#  'citco trusteys bvi limited as trustee of the creative vysta trust',
#  'wu yuanlin',
#  'metchem engineering sa',
#  'forest industries group sa',
#  'belen velutini',
#  'sergev zuixstv',
#  'gold come holdings limited',
#  'wincqester consultants equities ltd',
#  'ya xiaolong',
#  'joasma corporation',
#  'petr skovotodko',
#  'transit technologies inc',
#  'zona impex ltd',
#  'gold rush assets limited',
#  'mrs patrizia poggi',
#  'jabar properties limited',
#  'ehab osman khalil',
#  'rheindeer enterprises inc',
#  'key line pamific eimited',
#  'carlos de carvalho crespo',
#  'bickerton ltd',
#  'goxden garewao development ltd',
#  'regiu compavy management sa',
#  'victor sukmanov',
#  'wang facai',
#  'advanlinksinvestment co utd',
#  'edward meja',
#  'musa corp',
#  'intercoa limited',
#  'design away limited',
#  'baker industries corporation',
#  'renyard company limited',
#  'artisti corp',
#  'multicare pharma limited',
#  'comblowx investmentd ltd',
#  'jerome overseas sa',
#  'bartlou limqeed',
#  'suliman dockrat',
#  'bikler ltd',
#  'leonia capital ltd',
#  'liu zinghsien',
#  'li jianwei',
#  'apic trustees ltd ap119',
#  'berrima global ltd',
#  'perth pkoperties limited',
#  'willamett enterprise ltd',
#  'parkhouse services ltd',
#  'carrolabd industries limited',
#  'nominest international ltd',
#  'petcon borneo limited',
#  'ccs corporate services limited',
#  'jefny del consuelo jimenez asanza',
#  'alarion company inc',
#  'intergirasol jm corp',
#  'roisine limited',
#  'depec technologies ltd',
#  'han hong jun',
#  'david adamson hirst',
#  'mrs voorma hannie',
#  'invernada sa',
#  'owsley marketingxcorp',
#  'vintage finance sa',
#  'vitamax foundation',
#  'shao changshi',
#  'white raven limited',
#  'huang ping',
#  'corporate agents bvi limited as trustee of the silver mine capital trust',
#  'albion fvnanciab holdings inc',
#  'bakkari international inc',
#  'maxwall invest corp',
#  'bearej share',
#  'inprover trading limited',
#  'harvest aspect international limited',
#  'thetie marite limited',
#  'alderson investments inc',
#  'zarnol trading inc',
#  'libshqq',
#  'artviewwgrhuc ltd',
#  'asialeesources inc',
#  'pergola partners sa',
#  'marwan r frem',
#  'kambo securidy products limited',
#  'buwan marketing inc',
#  'international personal trainer institute limited',
#  'overlea consultants inc',
#  'borrowdale nominees limited',
#  'delphisuconsultkng group limited',
#  'xiaocong qiu',
#  'awad ammora',
#  'rodney glyndwr james thea van eupen james and dominic anthony oneil jointly as trustees',
#  'trenton properties ltd',
#  'lexington computer consultants inc',
#  'furantall international limited',
#  'chen chienchou',
#  'roussellelimiten',
#  'zenith marketing sa',
#  'tao wenchieh',
#  'lankom limited',
#  'zonea liiitxd',
#  'jade port technologyhltdo',
#  'mr andreytrogachev',
#  'james john zuehlen',
#  'elena gemeliari',
#  'gao guargpi',
#  'juan pndro damiani',
#  'finsbury international limited',
#  'rr seref dogan erbek',
#  'roblrto pocaterma',
#  'powell estate ltd',
#  'hitectebcom ltd',
#  'runshine businessqaac',
#  'valarie jean ward',
#  'pin international holdings limited',
#  'rpptman ooman',
#  'jtc securities limited',
#  'yong hong wei',
#  'rantiagoqgombz',
#  'juniper trading group sa',
#  'jlannie chungyingpaiu',
#  'mr lukyanchuk yury',
#  'carlyle trading limiteo',
#  'rexford holdings sa',
#  'crown fair investment ltd',
#  'knight star sa',
#  'ignacio agustin kassis manzur',
#  'quantic oil sa offshore',
#  'zhu ping',
#  'reflex holdings ltd',
#  'satabco ltd',
#  'grand world investment ltd',
#  'ukr international limited',
#  'a pw corpoeation',
#  'diego alfie gonzlez',
#  'semita limited',
#  'andrey ruzheynikov',
#  'zhangvjiyang',
#  'stelmar daimonds xtd',
#  'gladstone lwasinv inc',
#  'lo hiu fai johnny',
#  'curaldo investments limited',
#  'keasn fialko',
#  'hancker corporation',
#  'haymend sa',
#  'alfred aspen',
#  'laurent nheypitet',
#  'vistrade engineering corp',
#  'joyce harvest international ltd',
#  'exclusive wotldwide likited',
#  'vigilax inc',
#  'north atlantic secretaries limited',
#  'hartsdale nv',
#  'persephone investments holding ltd',
#  'la atlantida s a',
#  'pranor holding inc',
#  'grand chinp international limited',
#  'glanford foundrtioy',
#  'lai lungchin',
#  'happy rise management ltd',
#  'lawngrove overseas limited',
#  'denver finance ltd',
#  'orino corp',
#  'orient future international limited',
#  'enoc limited',
#  'imperial company limited',
#  'suite1r cunbeblvnd ltd',
#  'wang jian qiang',
#  'mr kenneth chin su sian',
#  'malshost international lymited',
#  'intercare limited',
#  'purple hoydingq llc',
#  'lisle international group corp',
#  'iap investment trust services ag',
#  'soonhee hinrichs',
#  'lancelot associates limited',
#  'law yuk ling',
#  'kleinwort benson guernsey trustees limited n c robins and p s le poidevin re g baron',
#  'paxton financial group corp',
#  'tenon iom nominees ltd',
#  'cristalmar corporation',
#  'paneast investments inc',
#  'clearwater yachtf limited',
#  'mrs natalia melikhova',
#  'sunora limited',
#  'dugminhvng',
#  'ningyudn holdings ltd',
#  'dalex alliance inc',
#  'thalassa nominees swa',
#  'crosskeys services limited',
#  'caravel development international projects inc',
#  'pinama sun dried mnc',
#  'leisure products holdings limited',
#  'wang han qing',
#  'damor investments limited',
#  'querrin shipping limited',
#  'lam sim kuen',
#  'jeroda promotion ltd',
#  'bush ac ltd',
#  'charterhyuse finance inc',
#  'nyon worldwide corp',
#  'sonic connect limitek',
#  'yellow light sa',
#  'yew green properties limited',
#  'james h hafterson',
#  'bereficence fowndaticn',
#  'georg staeheli',
#  'javie kendraxlai sook chiuem',
#  'ornsay residency uk ltd',
#  'cheer ascent investment limited',
#  'karaboon company limited',
#  'zahida dero',
#  'swan capital management ltd',
#  'mr hseyin ayduk esat koray',
#  'dxb international holdings ltd',
#  'detris intefnawional coqp',
#  'matura holding inc',
#  'baldaquin inc',
#  'hansa maritime ltd',
#  'lynus properties limited',
#  'new shobe finanoe limited',
#  'sirgronald girierson',
#  'internabional businegs commercial company inc',
#  'fenera corporation',
#  'holenstein rechtsanwlte',
#  'ringo star trading inc',
#  'beijing dragon resources limited',
#  'weldin inc',
#  'ontech technology corp',
#  'zhang sen qi',
#  'joseeluis bruzgond',
#  'li gui chun',
#  'kryn holdinhs limited',
#  'silos de bonniere',
#  'wang wangnang',
#  'her chan development co ltd',
#  'union tiger ltd',
#  'patricia maria mesa',
#  'keen wise co ltd',
#  'wyman holdings limited',
#  'arctilana s a',
#  'estudio juridico ortega moreira ortega trwjillo abogados',
#  'cees baas',
#  'eastqrn aqcessoqies corp',
#  'wt equities ltd',
#  'buxter associatfs inc',
#  'mrs carolyue duncombe robinson',
#  'omega investments management ltd',
#  'imiying eleccronics co ltd',
#  'elena nikolayevna shipitsyna',
#  'stantrade limited',
#  'big world investment ltd',
#  'mandarin traxing company limiteh',
#  'gaosxiang',
#  'denis kropotkin',
#  'carena inzernational covp',
#  'prodectors limiten',
#  'maeve enterprises corp',
#  'equity trust bahamas limited',
#  'trent vale consultants limited',
#  'ryedale finance inc',
#  'nek trading corp',
#  'ultimatetm group organisation llc',
#  'marcos alberto labaton',
#  'zhao siyuan',
#  'sumesh rajgopal',
#  'oldroy capital ltd',
#  'oriental development and consulting ltd',
#  'oldwick holdings litited',
#  'azamat babmjkhanbetov',
#  'sharington company inc',
#  'fairview holdings limited',
#  'taporley limited',
#  'sheridan properties ltd',
#  'abdul kayum',
#  'uniped prosper enserpriwe corp',
#  'huang guoyu',
#  'kenway technologies ltd',
#  'the best resources managers limited',
#  'mindmotion microelectrondck co ltm',
#  'claudie degchamps',
#  'cheer point management limited',
#  'stpdie scgt',
#  'velsen holdings ltd',
#  'chen wenhsiang',
#  'zhao jing',
#  'neofantastic fashions limited',
#  'verug holdgng incf',
#  'kenner consultants corporation',
#  'silvejlock finance limited',
#  'arco services corp',
#  'monte cristo captial ltd',
#  'mr mohammed nizar alnakeeb',
#  'briardjle limitee',
#  'filament holdings limited',
#  'corvest invlstmezts limited',
#  'valroy international limited',
#  'fouad el imam',
#  'majed sulaiman al nafie',
#  'kang shaokui',
#  'garfinkel simon',
#  'dulwich business sa',
#  'juan oswaldo ywnelli aguirrh',
#  'novaglobus ltd',
#  'westland assets management inc',
#  'ms bassil yasmeen elieqmalip',
#  'ocean treasure group limited',
#  'montserrat developments limited',
#  'high court holdings limited',
#  'maria auxiliadora febres cordero cordovez',
#  'colorado compaly equiyies limited',
#  'lu weidong',
#  'gong yishu',
#  'zhuang yonysheng',
#  'mohamad tahsine el khayat',
#  'worldwise development ltd',
#  'kestrel group development limited',
#  'mossack fonseca co per corp',
#  'robinaalvarez',
#  'vinayak investments limited',
#  'gwrtonville trading limiled',
#  'k11 partners inc',
#  'dominion services limited',
#  'b24 marquisconsultadoria e servicos lda',
#  'perosa limited',
#  'mrs avgousta svoronou',
#  'mrs kathleen tynan',
#  'scysee investments limited',
#  'paddock crediyz investment limited',
#  'lebowitz chedva',
#  'castle hill holdings inc',
#  'komustrade ltd',
#  'mrsd aida asoaad kawkabani',
#  'teresahmercedes faoli wuitrago',
#  'bearer mr koviljon boborajabog',
#  'satura trading sa',
#  'averline investments ltd',
#  'newstead foundation',
#  'guardian trust company limited jersey',
#  'aln strengtpjltd',
#  'bagshaw services corp',
#  'forstrua groupwinc',
#  'karpatsi holding co ltd',
#  'wan liaqm he',
#  'decency advisors sa',
#  'abacus nominees ltd',
#  'epic electronics international limitqd',
#  'geng ning',
#  'myojacob perez',
#  'demarest finance ltd',
#  'billingsley alliance sa',
#  'andrea paolo bresolin',
#  'asia mato tejhnologies ltc',
#  'pafnos limited',
#  'carelia sa',
#  'inner gongolia fuguang food co ltd',
#  'chaucer estates limited',
#  'nurgul rasulova',
#  'jaim aezelopment enterpriszs lc',
#  'charmeuse services incorporated',
#  'goldsun international incorporation',
#  'jetford trading inc',
#  'vadima enc sa',
#  'viking dynamics limited',
#  'arlesford investment holdings corp',
#  'navin mehra',
#  'sunnyrock limited',
#  'ariston holding incorporated',
#  'durston finance limited',
#  'mr anthony zammlt',
#  'eleteve likieed',
#  'agri partqiiternational incorporated',
#  'suntown limited',
#  'meridian partnership limited',
#  'jiy ye zk',
#  'lu jian fen',
#  'ieixiojg ye',
#  'peach blossdm company limited',
#  'golden cape trading ltd',
#  'mm concepts ltd',
#  'anemone capital limited',
#  'bismarck offshore limited',
#  'andrey panagushin',
#  'mole ovedseas sa',
#  'mr kevin william braddick',
#  'powerhkl enterprines limited',
#  'archer enterprises sa',
#  'gautier andr louis marechalgouee',
#  'huang yihsuan',
#  'mary justiniano vda de guillemes jose emeterio guillemes justiniano maria amparo guillemes justiniano and juan carlos guillemes justiniano joint tenancy with right of survivorship',
#  'oakwood development ltd',
#  'miehail mishcgenko',
#  'smile ermibed',
#  'cece grafitwerke international corp',
#  'tang xue jiao',
#  'thyson technology international ltd',
#  'zhai min',
#  'xarin sachzev',
#  'mariana andrea alvarado chacn',
#  'valtenor limited',
#  'fernando bernardes pinheiro',
#  'hm bvilqlimityd',
#  'song yong sheng',
#  'interlink ltd',
#  'laurita karsten weege',
#  'krakatoa sa',
#  'hynstar iyvestmmnt limited',
#  'katran company ltd',
#  'mr moacyr pessi',
#  'gonten holding establishment',
#  'tam marrie han',
#  'isu hudgschun',
#  'intco sa',
#  'kapik holdings inc',
#  'mario gmez duque',
#  'godfrey business development ltd',
#  'hotel san antonio plc',
#  'macroplast limited',
#  'easthaugh holdings inc',
#  'rupaul overseas inc',
#  'sikhuti property limited',
#  'rosebud research inc',
#  'jorge luis takahashi iguchi',
#  'oziris investments limited',
#  'alajeel co inc',
#  'landmajk manaqerent limited',
#  'andrie doljitch',
#  'power treasure drading limited',
#  'pastorale international limited',
#  'zhongyuat international trading limited',
#  'moorfsnomineek limited',
#  'wai chi investments limited',
#  'ubi trustee sa',
#  'servicios de auditora de negocios ltda',
#  'index asia pacimic limited',
#  'quanto mabagemeat limited',
#  'park misuk',
#  'cac asesores sa',
#  'marc gugerli',
#  'greensmone propeeties ltd',
#  'mr hassan nasser h a alnaimi',
#  'westhorpe international limited',
#  'cirkumpola ltd',
#  'yellow limited',
#  'huang youmin',
#  'mr panayiotis konaris',
#  'souyd hong kong limited',
#  'practical global co ltd',
#  'hungarian rdal estnte investments ltd',
#  'arundel associates inc',
#  'dastona holdingz eorp',
#  'beijing hati business consultant limited',
#  'mohamed salem kardous obaid al ameri',
#  'acsa limited',
#  'mayo nominess limited',
#  'gennady korenev',
#  'torriginda holdings inc',
#  'cristina maria aya caro',
#  'oberon management limited',
#  'multi group marketing corp',
#  'royal internatidnao foundation',
#  'international corporate directors inc',
#  'lui pak hoi',
#  'darazar inco',
#  'ines calmell del solar del rio',
#  'ian david fletchvr',
#  'fidelity trustees ltd the pat maurice brown settlement',
#  'purplevest ltd',
#  'solvent holdings xroap ync',
#  'norlane sa',
#  'acklin finance limitet',
#  'crystal top holdings group ltd',
#  'devas sa',
#  'baresdale overseas inc',
#  'trade pacific limited',
#  'houng ying development limited',
#  'traderoutes limited',
#  'perfumes internacionales co ltd',
#  'jonquille business sla',
#  'parkgate holdings limited',
#  'soreco ivvestment rnc',
#  'belvedere administration ltd',
#  'mirabaud financial planning limited zurich client',
#  'wsapeinternational corporaaion',
#  'tanbark services inc',
#  'snowberry commercial limited',
#  'zilmak limited',
#  'urwich inc',
#  'chae young chong',
#  'frederick taft',
#  'bay tree asset holdings limited',
#  'blueriver holding overseas corp',
#  'pearl securities limited',
#  'pagripherzfinanze corporation',
#  'sparrowtsecuiities sa',
#  'ems trading limited',
#  'luis pircio pupillf',
#  'beijing voson intl ip attorney co ltd',
#  'segg asset management corp',
#  'tercel holdings limited',
#  'multi crystal corporation',
#  'kgrkat limited',
#  'orient first capital limited',
#  'horizon universal inc',
#  'eurotec uk limited',
#  'platy investments ltd',
#  'jiangfhaijun',
#  'larisa trubetskaya',
#  'agencia martima mundomar sa',
#  'heartland international trading limited',
#  'samsudin bin abu hassan',
#  'magnhild faleide fristad',
#  'monh limited',
#  'night heron limited',
#  'mcdonagh brenden',
#  'wang qiyin',
#  'alpine advisory group ltd',
#  'fabrice vizl',
#  'westworld holdings ltd',
#  'highstage holdings limited',
#  'sound cheers limited',
#  'cezanne development holdings inc',
#  'alfredo ovalle rodrgrez',
#  'cui jingtao',
#  'cornhill ventures ltd',
#  'bumkbilf finance ltd',
#  'turnbridge sa',
#  'huang hua lan',
#  'uxbridge investments inc',
#  'lexmont overseas inc',
#  'global international investment holdings inc',
#  'george christppoubos',
#  'irene florencia letss colmenares de de romaa',
#  'high colt company limited',
#  'brilliant lighting pte limited',
#  'fletcher enterprises ltd',
#  'mr mokhtar abou basha',
#  'ma xiao fei',
#  'technology services group corporation',
#  'wong pik lin barbara',
#  'phoenis trading sa',
#  'powell equities sa',
#  'belfastscorpkration',
#  'ichi dr joe corppration',
#  'mrs sandra anne meadows',
#  'rufus resourses inc',
#  'eastern lake services corp',
#  'tania lucia balta mansilla',
#  'pennydale investments ltd',
#  'orvell estate sa',
#  'facoraf ltd',
#  'etozir asset management sa',
#  'mscoy assetsalimited',
#  'myron pacific ltd',
#  'arnoold denes',
#  'huang yuan lx',
#  'top china strategy investments limited',
#  'thisledon investments limited',
#  'jelen group limited',
#  'hermitage international ltd',
#  'michel andre oyharcabal',
#  'radiant holding corp',
#  'lotco holdings inc',
#  'juan nicolas leao leal',
#  'rivolta inc',
#  'gaud grobal corp',
#  'wingfield enterprises limited',
#  'greater beijing regiongexpressways limited',
#  'management nominee services inc',
#  'bakner international limited',
#  'kaslo limited',
#  'ellerton limited',
#  'robert david fuchs',
#  'chang chia chen',
#  'baysan holdings limited',
#  'wilian raimundo ferreira egido claudia cristina mateus egido marlon mateus egxdo and carlos augusto mateus egido joint tenancy wuth right of survivorship',
#  'john sturgeon',
#  'cheufang chapg',
#  'procovest sa',
#  'panroc holdings inc',
#  'tenison associates services likited',
#  'mujeres investments limited',
#  'curby associates limited',
#  'international energy holdings ltd',
#  'copper hill investments ltdz',
#  'bassacs finance sa',
#  'bluebell internataonal holdings sa',
#  'mischositos invesmment sa',
#  'kean ahkmboo',
#  'brilliwnt city enterprisestltd',
#  'barwick properties corp',
#  'britannia land international limited',
#  'mirador resources sa',
#  'dornberg holdings limited',
#  'supreme pohensinvestment ltd',
#  'byrnestone limited',
#  'newflame limited',
#  'tsollaj yung',
#  'mohammad mansour al rumaih',
#  'mkc inc',
#  'african agricultural advisors limited',
#  'bisney profits limited',
#  'albany holdings limited',
#  'harry pryomitro simon',
#  'longville services sa',
#  'smart faith sa',
#  'mr ery yunasri',
#  'molard investments ltd',
#  'liu xin hua',
#  'maura santiago salles',
#  'radiance international ltd',
#  'fribel alphil international inc',
#  'master nice international ltd',
#  'switch financial ltd',
#  'tihe creation sechnotogy limited',
#  'nadarioo company uimitid',
#  'ghi yintai',
#  'springtide holdings limited',
#  'solent enterprises sa',
#  'inversorm meysson sa uruguay',
#  'ying liu',
#  'gefest investments ltd',
#  'yin ke',
#  'sapphire equitirs limitnd',
#  'smacas international inc',
#  'tasso management ltd',
#  'mr sergey shikhaleev',
#  'rosni lis',
#  'xu shu fu',
#  'mezzola limited',
#  'acertis investment management co limited',
#  'nebadcyn limited',
#  'lama petroleum ltd',
#  'mr bader f mugayel',
#  'ebcny saa',
#  'sunyview international lkmited',
#  'wilderspool investments jersey limited',
#  'jose lalo',
#  'flice sa',
#  'dalcam businqss ltd',
#  'bale holding investment ltd',
#  'bagstock company limited',
#  'dallain holdings inc',
#  'mayton investments inc',
#  'wagnon ltd',
#  'guyod limited',
#  'naugai lbw firm',
#  'evelenk bianchi y bianchi',
#  'khang yl sheng',
#  'chan suk lingshirley',
#  'cao wensheng',
#  'catherine tsung',
#  'interworld investment ltd',
#  'hampton consulting sa',
#  'mr sergey kupriyanov',
#  'cojbo finance oa',
#  'roan capital partners limited',
#  'hsieh chin lung',
#  'starpeak limited',
#  'cheng kwli chun john',
#  'northern minerals partners ltd',
#  'sino sky entrrprises limited',
#  'abu bakr abidlla hadi aheed al hussaini',
#  'clifton sc limited',
#  'dzt limited',
#  'tarshaql techgincorporated',
#  'guernsey administrative services nominees limited',
#  'primb limited',
#  'kong jun',
#  'tower bridge holdings limited',
#  'yaomchengzhi',
#  'bearef',
#  'litewell industrial co ltd',
#  'beechleigh property holdings limited',
#  'he mohammad abdulla ali algergawi',
#  'jean paul van den brande',
#  'great talent limited',
#  'tomas otto hanson',
#  'parklane invostments grour limiyed',
#  'oswid tervicesilimited',
#  'finisterre holdings limited',
#  'danielixbay fcundation',
#  'lqu yur sfng',
#  'dimitrios papachristos',
#  'sierra diamonds ltd',
#  'budhichand premchand shah',
#  'picardy investments sa',
#  'feapearl maritime limised',
#  'zhou sui tong',
#  'quality communication corp',
#  'pinktrol limited',
#  'victor daniel martin',
#  'corporativo acr sa de cv',
#  'zhou yi li',
#  'sheringham industries corp',
#  'yugraj investments ltd',
#  'satsaco holdings corporation',
#  'coaaburn limited',
#  'alexander nicholas international s a',
#  'ahasia inc',
#  'zheng zhixiao',
#  'heathev jnan nicholson',
#  'mary mznir ghobrial',
#  'promyliz corporation',
#  'jitko trading sa',
#  'ctm consulting ltd',
#  'li ang intl corp',
#  'amwtde manrgement sa',
#  'lin ching wei',
#  'mr rajesh kumar parmar',
#  'church street trustees as trustees of the la rochelle trust',
#  'projects and conqracts limited',
#  'rendmunl marketing inc',
#  'fundacion arien',
#  'mrsirita lorenzi',
#  'elgahar holding incr',
#  'radu ciorba',
#  'yu dezhang',
#  'cheng cohholdfngs sen bhd',
#  'zhu hong yan',
#  'cassian darcy coquelle',
#  'cheung kam kwong',
#  'haili technology group co ltd',
#  'buchovia equities corp',
#  'procos worldwide corp',
#  'woodside capital holdings ltd',
#  'bridgford property holdings ltd',
#  'europlan nominees no 2 limited',
#  'winley corp',
#  'ingredients corp',
#  'minor li chit khim richard',
#  'do not use see a122 acecroft limited',
#  'cristine holdings lto',
#  'leontino inc',
#  'strong energy ltd',
#  'charm trading limited',
#  'chin chieh shipping sa',
#  'ralter izvest ltk',
#  'mangh shuvho',
#  'dolenin ltdk',
#  'tam po ki',
#  'friendship investments inc',
#  'finortrust trustees limited',
#  'chen xue qun',
#  'royal fiduciary group limited re aurora',
#  'atherfields limited',
#  'greater zone development ltd',
#  'chadwych limited',
#  'abbeybridge limited',
#  'pengrove services licited jly',
#  'huangbyi cing',
#  'm3 madagascar ltd',
#  'lu hongfei',
#  'siti nurbainy akil sahab',
#  'imagdnation world limlted',
#  'gordy finanqecgroup ja',
#  'elsey commerce inc',
#  'horgen assets sa',
#  'bakkar corp',
#  'sinter development ltd',
#  'ernie continental trading ltd',
#  'jiang hui',
#  'tax ding trading limited',
#  'mourgue d algue cie',
#  'benjamin flournoy',
#  'qiankmin',
#  'mrqj rnnemaker llm',
#  'plink corporation',
#  'mrs manoranjana dasgupta',
#  'eurofrasia holdings ltd',
#  'kormac global inc',
#  'mercurio associates sa',
#  'ni jun',
#  'oceanus investments ltd',
#  'sunnybay holdings estates ltd',
#  'sharp idea holdings limited',
#  'max target investments limited',
#  'three ventures incorporated',
#  'leticia panugayan',
#  'dou mei',
#  'wellbred ltd',
#  'madam tam ming leun',
#  'wealthy land enterprises limited',
#  'patson investments limited',
#  'scott r dvniels deborah a daniels jt ten',
#  'vanair shippingoinc',
#  'xin yi investment co ltd',
#  'uniglobexconsultants inc',
#  'baviright zyoup inc',
#  'feng bin',
#  'silverdene limited',
#  'beauty flame international limited',
#  'chrysantal investments ltd',
#  'the caledonian hallmark company limited',
#  'mr marios papadimas',
#  'ayv capital holdings limited',
#  'techgart international trading limited',
#  'success new limited',
#  'greencastle limited',
#  'powerline investments limited',
#  'hsu chen shen',
#  'angel eecasnino',
#  'biofish aquicultusa',
#  'yu uhun guang',
#  'liao pichu',
#  'beaumont trading corp',
#  'premierynominecs limited',
#  'contec corp',
#  'interfield sylutions ltd',
#  'darius equities sa',
#  'gustavo alberto aquino alfieri',
#  'adithya kumar poddar',
#  'vanluck limited',
#  'langford invesf corp',
#  'christie consulting inc',
#  'dr kapranmkamal',
#  'hhiyn chihming',
#  'mrs nicole f blancbrude andor mr alain blancbrude',
#  'luo wenching',
#  'igor flasz',
#  'anj 1996 development limated',
#  'acra business corporation',
#  'monica rodriguez',
#  'jatkoesalimited',
#  'tammwai ying',
#  'laxsnt sam',
#  'bao li investments ltd',
#  'campus holding group ltd',
#  'barnt spring limited',
#  'ztaxhill inc',
#  'trenton invzrtment services ttd',
#  '1868 enterprise inc',
#  'michael alter kushnir',
#  'dfp investments limited',
#  'corpoqate nominees limited',
#  'mrs arafah bint ali bin mussallam',
#  'polytimi manintqs',
#  'edgar rene ciceron puyol perdomo',
#  'nicole didi',
#  'european international management limited',
#  'mr park young soo',
#  'rpm systems limited',
#  'riselark jentures limited',
#  'industrial plant design sa',
#  'sherlock burns limited',
#  'winyoung enterprises limited',
#  'china joyce international limiyed',
#  'filip olqa jacek',
#  'planet solution ltd',
#  'arius management corp',
#  'tarantella securities limited',
#  'secomd court limnted',
#  'luis alberto dimnik',
#  'carlos enrique larios cueloar',
#  'fragrance perfumes o cosmevicos cosp',
#  'virgen nutrition ltd',
#  'allied success international hk limited',
#  'wingo managemeag limited',
#  'pearce hughes and aoife hughes',
#  'pls international global cwd',
#  'mr marco de montis',
#  'redxmocn deveropment ltd',
#  'quindale management limited',
#  'tang meichun',
#  'marlon aviation inc',
#  'comercio interamericano s a',
#  'millican investment ltd',
#  'lockstone corporation',
#  'fundacin nissim',
#  'diverse consultancy international ltd',
#  'hallmark trust limited',
#  'abdullah hamad alrsagrr brothers',
#  'sunflower investments limited',
#  'joao edward vaz maia',
#  'gobeli doll christel',
#  'glass plus industries inc',
#  'dominic john coubeck',
#  'victoria saiidas calvo',
#  'mr aubola raphael oluyede',
#  'morehead incorporated',
#  'erchi investmont holding limited',
#  'camden tkchnology limqted',
#  'spacecode ventures inc',
#  'wilson offshore group holdings bvi limited',
#  'luizaumaripni',
#  'harvest fortune group ltd',
#  'aiyana ltd',
#  'regency international services limited',
#  'sergio alejandro koreybvit',
#  'tamarin properties inc',
#  'buchanan trading inc',
#  'ellabad fondation',
#  'jtc suisse sa as trustee of the velmi trust',
#  'the quayla investmengs tzust',
#  'min xuan',
#  'gca information services limited',
#  'genesis exports limited',
#  'a d d ltd',
#  'the celtic trust company limited',
#  'wcn international limited',
#  'kai international ltd',
#  'gzorious billion develnpment limited',
#  'rayville limited',
#  'lu minghui',
#  'polysjates internftionrl development ltd',
#  'hoarding aahu limited',
#  'mr tamaz jakhutashvili',
#  'layton ventures group inc',
#  'c a jerrett',
#  'yang wen tao',
#  ...]

# %%
col_words = [x.split(' ') for x in tqdm(col)]
col_words
# Out:
# HBox(children=(IntProgress(value=0, max=333070), HTML(value='')))
# [['mo', 'yuling'],
#  ['hermes', 'global', 'services', 'fz', 'lle', 'monaco'],
#  ['deerfield', 'investments', 'group', 'ltd'],
#  ['sidney', 'frankel'],
#  ['freshlolkarmrltd'],
#  ['pricewaterhouse', 'coopers', 'malta'],
#  ['solby', 'holding', 'limited'],
#  ['chang', 'min', 'seok'],
#  ['tsax', 'wuli'],
#  ['peter', 'colaco'],
#  ['leisure', 'group', 'holdings', 'inc'],
#  ['dencourt', 'services', 'limited'],
#  ['fotlock', 'international', 'sa'],
#  ['jiang', 'qiang'],
#  ['whemoton', 'scyprusglimited'],
#  ['east', 'dawn', 'group', 'sen'],
#  ['savas', 'oil', 'international', 'corporation'],
#  ['amerwell', 'investments', 'limited'],
#  ['sinocom', 'ideas', 'holdings', 'lizitkd'],
#  ['rivaldi', 'holdings', 'ltd'],
#  ['ventura', 'propertieb', 'limited'],
#  ['natron', 'investments', 'corp'],
#  ['virtus',
#   'trust',
#   'limited',
#   'as',
#   'trustess',
#   'of',
#   'the',
#   'hayward',
#   'family',
#   '1993',
#   'settlement'],
#  ['primeline', 'international', 'development', 'corporation'],
#  ['canal', 'tryst', 'companywlimitld'],
#  ['capital', 'invest', 'portfolio', 'inc'],
#  ['mrpetergschopt'],
#  ['edmundo', 'david', 'tefel', 'pasos'],
#  ['crinam', 'limited'],
#  ['dazzle', 'international', 'limited'],
#  ['furnidec', 'limited'],
#  ['dblmaixe', 'limided'],
#  ['ellenton', 'company', 'atd'],
#  ['utrition', 'inc'],
#  ['hearnville', 'inc'],
#  ['nilo', 'consultores', 'sas'],
#  ['the', 'piat', 'foundation'],
#  ['international', 'fund', 'management', 'corp'],
#  ['montis', 'co'],
#  ['mr', 'geron', 'pozov'],
#  ['gloria', 'management', 'equities', 'inc'],
#  ['mr', 'francisco', 'ortiz', 'von', 'bismarck'],
#  ['newmarket', 'traders', 'ltd'],
#  ['tristan', 'energy', 'capital', 'ltd'],
#  ['chu', 'ah', 'kiew'],
#  ['ikroy', 'limited'],
#  ['tomsun', 'trading', 'ltd'],
#  ['palmdella', 'limited'],
#  ['paula', 'andrea', 'osorio', 'muoz'],
#  ['denvale', 'finance', 'incorporated'],
#  ['sigesky', 'trading', 'sav'],
#  ['peace', 'afd', 'serenity', 'limsved'],
#  ['christopher',
#   'anthony',
#   'castelloe',
#   'kathleen',
#   'costelloe',
#   'jointly',
#   'with',
#   'right',
#   'of',
#   'qurvivorship'],
#  ['apson', 'technology', 'limited'],
#  ['liu', 'lfng'],
#  ['tyliam', 'ltd'],
#  ['eriton', 'consulting', 'limited'],
#  ['wang', 'wenqiao'],
#  ['cafate', 'inc'],
#  ['glory', 'champion', 'holdinqscltd'],
#  ['joaquin', 'ziaedurn'],
#  ['selectron', 'members', 'ltd'],
#  ['taiwan', 'tunes', 'inl'],
#  ['ambert', 'limited'],
#  ['millside', 'holdings', 'inc'],
#  ['forest', 'ggpen', 'howdings', 'limited'],
#  ['zandeleigh', 'limited'],
#  ['peravro', 'limited'],
#  ['amphios', 'management', 'inc'],
#  ['hedsham', 'inc'],
#  ['pebble', 'management', 'corp'],
#  ['roberi', 'newmin'],
#  ['you', 'wei', 'capital', 'limited'],
#  ['avel', 'gonzalez'],
#  ['zng', 'nominees', 'bvi', 'ltd'],
#  ['ferrrtti', 'group', 'limited'],
#  ['malina', 'holding', 'ltd'],
#  ['ralph', 'gore', 'watson'],
#  ['sunvjle', 'investments', 'limited'],
#  ['akron', 'investments', 'ltd'],
#  ['bondex', 'logistics', 'company', 'limited'],
#  ['lupus', 'investments', 's', 'a'],
#  ['piru', 'inc'],
#  ['jc', 'paemkum', 'lwd'],
#  ['wings', 'holding', 'management', 'inc'],
#  ['monthrie', 'nssociatws', 'inc'],
#  ['leymer', 'company', 'inc'],
#  ['lidena', 'intergroup', 'ltd'],
#  ['canadian', 'investment', 'phoperties', 'ltd'],
#  ['compagnie', 'financiere', 'et', 'fonciere', 'sa'],
#  ['utiglobe', 'secukities', 'limited'],
#  ['asil', 'enterprises', 'inc'],
#  ['citco',
#   'trusteys',
#   'bvi',
#   'limited',
#   'as',
#   'trustee',
#   'of',
#   'the',
#   'creative',
#   'vysta',
#   'trust'],
#  ['wu', 'yuanlin'],
#  ['metchem', 'engineering', 'sa'],
#  ['forest', 'industries', 'group', 'sa'],
#  ['belen', 'velutini'],
#  ['sergev', 'zuixstv'],
#  ['gold', 'come', 'holdings', 'limited'],
#  ['wincqester', 'consultants', 'equities', 'ltd'],
#  ['ya', 'xiaolong'],
#  ['joasma', 'corporation'],
#  ['petr', 'skovotodko'],
#  ['transit', 'technologies', 'inc'],
#  ['zona', 'impex', 'ltd'],
#  ['gold', 'rush', 'assets', 'limited'],
#  ['mrs', 'patrizia', 'poggi'],
#  ['jabar', 'properties', 'limited'],
#  ['ehab', 'osman', 'khalil'],
#  ['rheindeer', 'enterprises', 'inc'],
#  ['key', 'line', 'pamific', 'eimited'],
#  ['carlos', 'de', 'carvalho', 'crespo'],
#  ['bickerton', 'ltd'],
#  ['goxden', 'garewao', 'development', 'ltd'],
#  ['regiu', 'compavy', 'management', 'sa'],
#  ['victor', 'sukmanov'],
#  ['wang', 'facai'],
#  ['advanlinksinvestment', 'co', 'utd'],
#  ['edward', 'meja'],
#  ['musa', 'corp'],
#  ['intercoa', 'limited'],
#  ['design', 'away', 'limited'],
#  ['baker', 'industries', 'corporation'],
#  ['renyard', 'company', 'limited'],
#  ['artisti', 'corp'],
#  ['multicare', 'pharma', 'limited'],
#  ['comblowx', 'investmentd', 'ltd'],
#  ['jerome', 'overseas', 'sa'],
#  ['bartlou', 'limqeed'],
#  ['suliman', 'dockrat'],
#  ['bikler', 'ltd'],
#  ['leonia', 'capital', 'ltd'],
#  ['liu', 'zinghsien'],
#  ['li', 'jianwei'],
#  ['apic', 'trustees', 'ltd', 'ap119'],
#  ['berrima', 'global', 'ltd'],
#  ['perth', 'pkoperties', 'limited'],
#  ['willamett', 'enterprise', 'ltd'],
#  ['parkhouse', 'services', 'ltd'],
#  ['carrolabd', 'industries', 'limited'],
#  ['nominest', 'international', 'ltd'],
#  ['petcon', 'borneo', 'limited'],
#  ['ccs', 'corporate', 'services', 'limited'],
#  ['jefny', 'del', 'consuelo', 'jimenez', 'asanza'],
#  ['alarion', 'company', 'inc'],
#  ['intergirasol', 'jm', 'corp'],
#  ['roisine', 'limited'],
#  ['depec', 'technologies', 'ltd'],
#  ['han', 'hong', 'jun'],
#  ['david', 'adamson', 'hirst'],
#  ['mrs', 'voorma', 'hannie'],
#  ['invernada', 'sa'],
#  ['owsley', 'marketingxcorp'],
#  ['vintage', 'finance', 'sa'],
#  ['vitamax', 'foundation'],
#  ['shao', 'changshi'],
#  ['white', 'raven', 'limited'],
#  ['huang', 'ping'],
#  ['corporate',
#   'agents',
#   'bvi',
#   'limited',
#   'as',
#   'trustee',
#   'of',
#   'the',
#   'silver',
#   'mine',
#   'capital',
#   'trust'],
#  ['albion', 'fvnanciab', 'holdings', 'inc'],
#  ['bakkari', 'international', 'inc'],
#  ['maxwall', 'invest', 'corp'],
#  ['bearej', 'share'],
#  ['inprover', 'trading', 'limited'],
#  ['harvest', 'aspect', 'international', 'limited'],
#  ['thetie', 'marite', 'limited'],
#  ['alderson', 'investments', 'inc'],
#  ['zarnol', 'trading', 'inc'],
#  ['libshqq'],
#  ['artviewwgrhuc', 'ltd'],
#  ['asialeesources', 'inc'],
#  ['pergola', 'partners', 'sa'],
#  ['marwan', 'r', 'frem'],
#  ['kambo', 'securidy', 'products', 'limited'],
#  ['buwan', 'marketing', 'inc'],
#  ['international', 'personal', 'trainer', 'institute', 'limited'],
#  ['overlea', 'consultants', 'inc'],
#  ['borrowdale', 'nominees', 'limited'],
#  ['delphisuconsultkng', 'group', 'limited'],
#  ['xiaocong', 'qiu'],
#  ['awad', 'ammora'],
#  ['rodney',
#   'glyndwr',
#   'james',
#   'thea',
#   'van',
#   'eupen',
#   'james',
#   'and',
#   'dominic',
#   'anthony',
#   'oneil',
#   'jointly',
#   'as',
#   'trustees'],
#  ['trenton', 'properties', 'ltd'],
#  ['lexington', 'computer', 'consultants', 'inc'],
#  ['furantall', 'international', 'limited'],
#  ['chen', 'chienchou'],
#  ['roussellelimiten'],
#  ['zenith', 'marketing', 'sa'],
#  ['tao', 'wenchieh'],
#  ['lankom', 'limited'],
#  ['zonea', 'liiitxd'],
#  ['jade', 'port', 'technologyhltdo'],
#  ['mr', 'andreytrogachev'],
#  ['james', 'john', 'zuehlen'],
#  ['elena', 'gemeliari'],
#  ['gao', 'guargpi'],
#  ['juan', 'pndro', 'damiani'],
#  ['finsbury', 'international', 'limited'],
#  ['rr', 'seref', 'dogan', 'erbek'],
#  ['roblrto', 'pocaterma'],
#  ['powell', 'estate', 'ltd'],
#  ['hitectebcom', 'ltd'],
#  ['runshine', 'businessqaac'],
#  ['valarie', 'jean', 'ward'],
#  ['pin', 'international', 'holdings', 'limited'],
#  ['rpptman', 'ooman'],
#  ['jtc', 'securities', 'limited'],
#  ['yong', 'hong', 'wei'],
#  ['rantiagoqgombz'],
#  ['juniper', 'trading', 'group', 'sa'],
#  ['jlannie', 'chungyingpaiu'],
#  ['mr', 'lukyanchuk', 'yury'],
#  ['carlyle', 'trading', 'limiteo'],
#  ['rexford', 'holdings', 'sa'],
#  ['crown', 'fair', 'investment', 'ltd'],
#  ['knight', 'star', 'sa'],
#  ['ignacio', 'agustin', 'kassis', 'manzur'],
#  ['quantic', 'oil', 'sa', 'offshore'],
#  ['zhu', 'ping'],
#  ['reflex', 'holdings', 'ltd'],
#  ['satabco', 'ltd'],
#  ['grand', 'world', 'investment', 'ltd'],
#  ['ukr', 'international', 'limited'],
#  ['a', 'pw', 'corpoeation'],
#  ['diego', 'alfie', 'gonzlez'],
#  ['semita', 'limited'],
#  ['andrey', 'ruzheynikov'],
#  ['zhangvjiyang'],
#  ['stelmar', 'daimonds', 'xtd'],
#  ['gladstone', 'lwasinv', 'inc'],
#  ['lo', 'hiu', 'fai', 'johnny'],
#  ['curaldo', 'investments', 'limited'],
#  ['keasn', 'fialko'],
#  ['hancker', 'corporation'],
#  ['haymend', 'sa'],
#  ['alfred', 'aspen'],
#  ['laurent', 'nheypitet'],
#  ['vistrade', 'engineering', 'corp'],
#  ['joyce', 'harvest', 'international', 'ltd'],
#  ['exclusive', 'wotldwide', 'likited'],
#  ['vigilax', 'inc'],
#  ['north', 'atlantic', 'secretaries', 'limited'],
#  ['hartsdale', 'nv'],
#  ['persephone', 'investments', 'holding', 'ltd'],
#  ['la', 'atlantida', 's', 'a'],
#  ['pranor', 'holding', 'inc'],
#  ['grand', 'chinp', 'international', 'limited'],
#  ['glanford', 'foundrtioy'],
#  ['lai', 'lungchin'],
#  ['happy', 'rise', 'management', 'ltd'],
#  ['lawngrove', 'overseas', 'limited'],
#  ['denver', 'finance', 'ltd'],
#  ['orino', 'corp'],
#  ['orient', 'future', 'international', 'limited'],
#  ['enoc', 'limited'],
#  ['imperial', 'company', 'limited'],
#  ['suite1r', 'cunbeblvnd', 'ltd'],
#  ['wang', 'jian', 'qiang'],
#  ['mr', 'kenneth', 'chin', 'su', 'sian'],
#  ['malshost', 'international', 'lymited'],
#  ['intercare', 'limited'],
#  ['purple', 'hoydingq', 'llc'],
#  ['lisle', 'international', 'group', 'corp'],
#  ['iap', 'investment', 'trust', 'services', 'ag'],
#  ['soonhee', 'hinrichs'],
#  ['lancelot', 'associates', 'limited'],
#  ['law', 'yuk', 'ling'],
#  ['kleinwort',
#   'benson',
#   'guernsey',
#   'trustees',
#   'limited',
#   'n',
#   'c',
#   'robins',
#   'and',
#   'p',
#   's',
#   'le',
#   'poidevin',
#   're',
#   'g',
#   'baron'],
#  ['paxton', 'financial', 'group', 'corp'],
#  ['tenon', 'iom', 'nominees', 'ltd'],
#  ['cristalmar', 'corporation'],
#  ['paneast', 'investments', 'inc'],
#  ['clearwater', 'yachtf', 'limited'],
#  ['mrs', 'natalia', 'melikhova'],
#  ['sunora', 'limited'],
#  ['dugminhvng'],
#  ['ningyudn', 'holdings', 'ltd'],
#  ['dalex', 'alliance', 'inc'],
#  ['thalassa', 'nominees', 'swa'],
#  ['crosskeys', 'services', 'limited'],
#  ['caravel', 'development', 'international', 'projects', 'inc'],
#  ['pinama', 'sun', 'dried', 'mnc'],
#  ['leisure', 'products', 'holdings', 'limited'],
#  ['wang', 'han', 'qing'],
#  ['damor', 'investments', 'limited'],
#  ['querrin', 'shipping', 'limited'],
#  ['lam', 'sim', 'kuen'],
#  ['jeroda', 'promotion', 'ltd'],
#  ['bush', 'ac', 'ltd'],
#  ['charterhyuse', 'finance', 'inc'],
#  ['nyon', 'worldwide', 'corp'],
#  ['sonic', 'connect', 'limitek'],
#  ['yellow', 'light', 'sa'],
#  ['yew', 'green', 'properties', 'limited'],
#  ['james', 'h', 'hafterson'],
#  ['bereficence', 'fowndaticn'],
#  ['georg', 'staeheli'],
#  ['javie', 'kendraxlai', 'sook', 'chiuem'],
#  ['ornsay', 'residency', 'uk', 'ltd'],
#  ['cheer', 'ascent', 'investment', 'limited'],
#  ['karaboon', 'company', 'limited'],
#  ['zahida', 'dero'],
#  ['swan', 'capital', 'management', 'ltd'],
#  ['mr', 'hseyin', 'ayduk', 'esat', 'koray'],
#  ['dxb', 'international', 'holdings', 'ltd'],
#  ['detris', 'intefnawional', 'coqp'],
#  ['matura', 'holding', 'inc'],
#  ['baldaquin', 'inc'],
#  ['hansa', 'maritime', 'ltd'],
#  ['lynus', 'properties', 'limited'],
#  ['new', 'shobe', 'finanoe', 'limited'],
#  ['sirgronald', 'girierson'],
#  ['internabional', 'businegs', 'commercial', 'company', 'inc'],
#  ['fenera', 'corporation'],
#  ['holenstein', 'rechtsanwlte'],
#  ['ringo', 'star', 'trading', 'inc'],
#  ['beijing', 'dragon', 'resources', 'limited'],
#  ['weldin', 'inc'],
#  ['ontech', 'technology', 'corp'],
#  ['zhang', 'sen', 'qi'],
#  ['joseeluis', 'bruzgond'],
#  ['li', 'gui', 'chun'],
#  ['kryn', 'holdinhs', 'limited'],
#  ['silos', 'de', 'bonniere'],
#  ['wang', 'wangnang'],
#  ['her', 'chan', 'development', 'co', 'ltd'],
#  ['union', 'tiger', 'ltd'],
#  ['patricia', 'maria', 'mesa'],
#  ['keen', 'wise', 'co', 'ltd'],
#  ['wyman', 'holdings', 'limited'],
#  ['arctilana', 's', 'a'],
#  ['estudio',
#   'juridico',
#   'ortega',
#   'moreira',
#   'ortega',
#   'trwjillo',
#   'abogados'],
#  ['cees', 'baas'],
#  ['eastqrn', 'aqcessoqies', 'corp'],
#  ['wt', 'equities', 'ltd'],
#  ['buxter', 'associatfs', 'inc'],
#  ['mrs', 'carolyue', 'duncombe', 'robinson'],
#  ['omega', 'investments', 'management', 'ltd'],
#  ['imiying', 'eleccronics', 'co', 'ltd'],
#  ['elena', 'nikolayevna', 'shipitsyna'],
#  ['stantrade', 'limited'],
#  ['big', 'world', 'investment', 'ltd'],
#  ['mandarin', 'traxing', 'company', 'limiteh'],
#  ['gaosxiang'],
#  ['denis', 'kropotkin'],
#  ['carena', 'inzernational', 'covp'],
#  ['prodectors', 'limiten'],
#  ['maeve', 'enterprises', 'corp'],
#  ['equity', 'trust', 'bahamas', 'limited'],
#  ['trent', 'vale', 'consultants', 'limited'],
#  ['ryedale', 'finance', 'inc'],
#  ['nek', 'trading', 'corp'],
#  ['ultimatetm', 'group', 'organisation', 'llc'],
#  ['marcos', 'alberto', 'labaton'],
#  ['zhao', 'siyuan'],
#  ['sumesh', 'rajgopal'],
#  ['oldroy', 'capital', 'ltd'],
#  ['oriental', 'development', 'and', 'consulting', 'ltd'],
#  ['oldwick', 'holdings', 'litited'],
#  ['azamat', 'babmjkhanbetov'],
#  ['sharington', 'company', 'inc'],
#  ['fairview', 'holdings', 'limited'],
#  ['taporley', 'limited'],
#  ['sheridan', 'properties', 'ltd'],
#  ['abdul', 'kayum'],
#  ['uniped', 'prosper', 'enserpriwe', 'corp'],
#  ['huang', 'guoyu'],
#  ['kenway', 'technologies', 'ltd'],
#  ['the', 'best', 'resources', 'managers', 'limited'],
#  ['mindmotion', 'microelectrondck', 'co', 'ltm'],
#  ['claudie', 'degchamps'],
#  ['cheer', 'point', 'management', 'limited'],
#  ['stpdie', 'scgt'],
#  ['velsen', 'holdings', 'ltd'],
#  ['chen', 'wenhsiang'],
#  ['zhao', 'jing'],
#  ['neofantastic', 'fashions', 'limited'],
#  ['verug', 'holdgng', 'incf'],
#  ['kenner', 'consultants', 'corporation'],
#  ['silvejlock', 'finance', 'limited'],
#  ['arco', 'services', 'corp'],
#  ['monte', 'cristo', 'captial', 'ltd'],
#  ['mr', 'mohammed', 'nizar', 'alnakeeb'],
#  ['briardjle', 'limitee'],
#  ['filament', 'holdings', 'limited'],
#  ['corvest', 'invlstmezts', 'limited'],
#  ['valroy', 'international', 'limited'],
#  ['fouad', 'el', 'imam'],
#  ['majed', 'sulaiman', 'al', 'nafie'],
#  ['kang', 'shaokui'],
#  ['garfinkel', 'simon'],
#  ['dulwich', 'business', 'sa'],
#  ['juan', 'oswaldo', 'ywnelli', 'aguirrh'],
#  ['novaglobus', 'ltd'],
#  ['westland', 'assets', 'management', 'inc'],
#  ['ms', 'bassil', 'yasmeen', 'elieqmalip'],
#  ['ocean', 'treasure', 'group', 'limited'],
#  ['montserrat', 'developments', 'limited'],
#  ['high', 'court', 'holdings', 'limited'],
#  ['maria', 'auxiliadora', 'febres', 'cordero', 'cordovez'],
#  ['colorado', 'compaly', 'equiyies', 'limited'],
#  ['lu', 'weidong'],
#  ['gong', 'yishu'],
#  ['zhuang', 'yonysheng'],
#  ['mohamad', 'tahsine', 'el', 'khayat'],
#  ['worldwise', 'development', 'ltd'],
#  ['kestrel', 'group', 'development', 'limited'],
#  ['mossack', 'fonseca', 'co', 'per', 'corp'],
#  ['robinaalvarez'],
#  ['vinayak', 'investments', 'limited'],
#  ['gwrtonville', 'trading', 'limiled'],
#  ['k11', 'partners', 'inc'],
#  ['dominion', 'services', 'limited'],
#  ['b24', 'marquisconsultadoria', 'e', 'servicos', 'lda'],
#  ['perosa', 'limited'],
#  ['mrs', 'avgousta', 'svoronou'],
#  ['mrs', 'kathleen', 'tynan'],
#  ['scysee', 'investments', 'limited'],
#  ['paddock', 'crediyz', 'investment', 'limited'],
#  ['lebowitz', 'chedva'],
#  ['castle', 'hill', 'holdings', 'inc'],
#  ['komustrade', 'ltd'],
#  ['mrsd', 'aida', 'asoaad', 'kawkabani'],
#  ['teresahmercedes', 'faoli', 'wuitrago'],
#  ['bearer', 'mr', 'koviljon', 'boborajabog'],
#  ['satura', 'trading', 'sa'],
#  ['averline', 'investments', 'ltd'],
#  ['newstead', 'foundation'],
#  ['guardian', 'trust', 'company', 'limited', 'jersey'],
#  ['aln', 'strengtpjltd'],
#  ['bagshaw', 'services', 'corp'],
#  ['forstrua', 'groupwinc'],
#  ['karpatsi', 'holding', 'co', 'ltd'],
#  ['wan', 'liaqm', 'he'],
#  ['decency', 'advisors', 'sa'],
#  ['abacus', 'nominees', 'ltd'],
#  ['epic', 'electronics', 'international', 'limitqd'],
#  ['geng', 'ning'],
#  ['myojacob', 'perez'],
#  ['demarest', 'finance', 'ltd'],
#  ['billingsley', 'alliance', 'sa'],
#  ['andrea', 'paolo', 'bresolin'],
#  ['asia', 'mato', 'tejhnologies', 'ltc'],
#  ['pafnos', 'limited'],
#  ['carelia', 'sa'],
#  ['inner', 'gongolia', 'fuguang', 'food', 'co', 'ltd'],
#  ['chaucer', 'estates', 'limited'],
#  ['nurgul', 'rasulova'],
#  ['jaim', 'aezelopment', 'enterpriszs', 'lc'],
#  ['charmeuse', 'services', 'incorporated'],
#  ['goldsun', 'international', 'incorporation'],
#  ['jetford', 'trading', 'inc'],
#  ['vadima', 'enc', 'sa'],
#  ['viking', 'dynamics', 'limited'],
#  ['arlesford', 'investment', 'holdings', 'corp'],
#  ['navin', 'mehra'],
#  ['sunnyrock', 'limited'],
#  ['ariston', 'holding', 'incorporated'],
#  ['durston', 'finance', 'limited'],
#  ['mr', 'anthony', 'zammlt'],
#  ['eleteve', 'likieed'],
#  ['agri', 'partqiiternational', 'incorporated'],
#  ['suntown', 'limited'],
#  ['meridian', 'partnership', 'limited'],
#  ['jiy', 'ye', 'zk'],
#  ['lu', 'jian', 'fen'],
#  ['ieixiojg', 'ye'],
#  ['peach', 'blossdm', 'company', 'limited'],
#  ['golden', 'cape', 'trading', 'ltd'],
#  ['mm', 'concepts', 'ltd'],
#  ['anemone', 'capital', 'limited'],
#  ['bismarck', 'offshore', 'limited'],
#  ['andrey', 'panagushin'],
#  ['mole', 'ovedseas', 'sa'],
#  ['mr', 'kevin', 'william', 'braddick'],
#  ['powerhkl', 'enterprines', 'limited'],
#  ['archer', 'enterprises', 'sa'],
#  ['gautier', 'andr', 'louis', 'marechalgouee'],
#  ['huang', 'yihsuan'],
#  ['mary',
#   'justiniano',
#   'vda',
#   'de',
#   'guillemes',
#   'jose',
#   'emeterio',
#   'guillemes',
#   'justiniano',
#   'maria',
#   'amparo',
#   'guillemes',
#   'justiniano',
#   'and',
#   'juan',
#   'carlos',
#   'guillemes',
#   'justiniano',
#   'joint',
#   'tenancy',
#   'with',
#   'right',
#   'of',
#   'survivorship'],
#  ['oakwood', 'development', 'ltd'],
#  ['miehail', 'mishcgenko'],
#  ['smile', 'ermibed'],
#  ['cece', 'grafitwerke', 'international', 'corp'],
#  ['tang', 'xue', 'jiao'],
#  ['thyson', 'technology', 'international', 'ltd'],
#  ['zhai', 'min'],
#  ['xarin', 'sachzev'],
#  ['mariana', 'andrea', 'alvarado', 'chacn'],
#  ['valtenor', 'limited'],
#  ['fernando', 'bernardes', 'pinheiro'],
#  ['hm', 'bvilqlimityd'],
#  ['song', 'yong', 'sheng'],
#  ['interlink', 'ltd'],
#  ['laurita', 'karsten', 'weege'],
#  ['krakatoa', 'sa'],
#  ['hynstar', 'iyvestmmnt', 'limited'],
#  ['katran', 'company', 'ltd'],
#  ['mr', 'moacyr', 'pessi'],
#  ['gonten', 'holding', 'establishment'],
#  ['tam', 'marrie', 'han'],
#  ['isu', 'hudgschun'],
#  ['intco', 'sa'],
#  ['kapik', 'holdings', 'inc'],
#  ['mario', 'gmez', 'duque'],
#  ['godfrey', 'business', 'development', 'ltd'],
#  ['hotel', 'san', 'antonio', 'plc'],
#  ['macroplast', 'limited'],
#  ['easthaugh', 'holdings', 'inc'],
#  ['rupaul', 'overseas', 'inc'],
#  ['sikhuti', 'property', 'limited'],
#  ['rosebud', 'research', 'inc'],
#  ['jorge', 'luis', 'takahashi', 'iguchi'],
#  ['oziris', 'investments', 'limited'],
#  ['alajeel', 'co', 'inc'],
#  ['landmajk', 'manaqerent', 'limited'],
#  ['andrie', 'doljitch'],
#  ['power', 'treasure', 'drading', 'limited'],
#  ['pastorale', 'international', 'limited'],
#  ['zhongyuat', 'international', 'trading', 'limited'],
#  ['moorfsnomineek', 'limited'],
#  ['wai', 'chi', 'investments', 'limited'],
#  ['ubi', 'trustee', 'sa'],
#  ['servicios', 'de', 'auditora', 'de', 'negocios', 'ltda'],
#  ['index', 'asia', 'pacimic', 'limited'],
#  ['quanto', 'mabagemeat', 'limited'],
#  ['park', 'misuk'],
#  ['cac', 'asesores', 'sa'],
#  ['marc', 'gugerli'],
#  ['greensmone', 'propeeties', 'ltd'],
#  ['mr', 'hassan', 'nasser', 'h', 'a', 'alnaimi'],
#  ['westhorpe', 'international', 'limited'],
#  ['cirkumpola', 'ltd'],
#  ['yellow', 'limited'],
#  ['huang', 'youmin'],
#  ['mr', 'panayiotis', 'konaris'],
#  ['souyd', 'hong', 'kong', 'limited'],
#  ['practical', 'global', 'co', 'ltd'],
#  ['hungarian', 'rdal', 'estnte', 'investments', 'ltd'],
#  ['arundel', 'associates', 'inc'],
#  ['dastona', 'holdingz', 'eorp'],
#  ['beijing', 'hati', 'business', 'consultant', 'limited'],
#  ['mohamed', 'salem', 'kardous', 'obaid', 'al', 'ameri'],
#  ['acsa', 'limited'],
#  ['mayo', 'nominess', 'limited'],
#  ['gennady', 'korenev'],
#  ['torriginda', 'holdings', 'inc'],
#  ['cristina', 'maria', 'aya', 'caro'],
#  ['oberon', 'management', 'limited'],
#  ['multi', 'group', 'marketing', 'corp'],
#  ['royal', 'internatidnao', 'foundation'],
#  ['international', 'corporate', 'directors', 'inc'],
#  ['lui', 'pak', 'hoi'],
#  ['darazar', 'inco'],
#  ['ines', 'calmell', 'del', 'solar', 'del', 'rio'],
#  ['ian', 'david', 'fletchvr'],
#  ['fidelity',
#   'trustees',
#   'ltd',
#   'the',
#   'pat',
#   'maurice',
#   'brown',
#   'settlement'],
#  ['purplevest', 'ltd'],
#  ['solvent', 'holdings', 'xroap', 'ync'],
#  ['norlane', 'sa'],
#  ['acklin', 'finance', 'limitet'],
#  ['crystal', 'top', 'holdings', 'group', 'ltd'],
#  ['devas', 'sa'],
#  ['baresdale', 'overseas', 'inc'],
#  ['trade', 'pacific', 'limited'],
#  ['houng', 'ying', 'development', 'limited'],
#  ['traderoutes', 'limited'],
#  ['perfumes', 'internacionales', 'co', 'ltd'],
#  ['jonquille', 'business', 'sla'],
#  ['parkgate', 'holdings', 'limited'],
#  ['soreco', 'ivvestment', 'rnc'],
#  ['belvedere', 'administration', 'ltd'],
#  ['mirabaud', 'financial', 'planning', 'limited', 'zurich', 'client'],
#  ['wsapeinternational', 'corporaaion'],
#  ['tanbark', 'services', 'inc'],
#  ['snowberry', 'commercial', 'limited'],
#  ['zilmak', 'limited'],
#  ['urwich', 'inc'],
#  ['chae', 'young', 'chong'],
#  ['frederick', 'taft'],
#  ['bay', 'tree', 'asset', 'holdings', 'limited'],
#  ['blueriver', 'holding', 'overseas', 'corp'],
#  ['pearl', 'securities', 'limited'],
#  ['pagripherzfinanze', 'corporation'],
#  ['sparrowtsecuiities', 'sa'],
#  ['ems', 'trading', 'limited'],
#  ['luis', 'pircio', 'pupillf'],
#  ['beijing', 'voson', 'intl', 'ip', 'attorney', 'co', 'ltd'],
#  ['segg', 'asset', 'management', 'corp'],
#  ['tercel', 'holdings', 'limited'],
#  ['multi', 'crystal', 'corporation'],
#  ['kgrkat', 'limited'],
#  ['orient', 'first', 'capital', 'limited'],
#  ['horizon', 'universal', 'inc'],
#  ['eurotec', 'uk', 'limited'],
#  ['platy', 'investments', 'ltd'],
#  ['jiangfhaijun'],
#  ['larisa', 'trubetskaya'],
#  ['agencia', 'martima', 'mundomar', 'sa'],
#  ['heartland', 'international', 'trading', 'limited'],
#  ['samsudin', 'bin', 'abu', 'hassan'],
#  ['magnhild', 'faleide', 'fristad'],
#  ['monh', 'limited'],
#  ['night', 'heron', 'limited'],
#  ['mcdonagh', 'brenden'],
#  ['wang', 'qiyin'],
#  ['alpine', 'advisory', 'group', 'ltd'],
#  ['fabrice', 'vizl'],
#  ['westworld', 'holdings', 'ltd'],
#  ['highstage', 'holdings', 'limited'],
#  ['sound', 'cheers', 'limited'],
#  ['cezanne', 'development', 'holdings', 'inc'],
#  ['alfredo', 'ovalle', 'rodrgrez'],
#  ['cui', 'jingtao'],
#  ['cornhill', 'ventures', 'ltd'],
#  ['bumkbilf', 'finance', 'ltd'],
#  ['turnbridge', 'sa'],
#  ['huang', 'hua', 'lan'],
#  ['uxbridge', 'investments', 'inc'],
#  ['lexmont', 'overseas', 'inc'],
#  ['global', 'international', 'investment', 'holdings', 'inc'],
#  ['george', 'christppoubos'],
#  ['irene', 'florencia', 'letss', 'colmenares', 'de', 'de', 'romaa'],
#  ['high', 'colt', 'company', 'limited'],
#  ['brilliant', 'lighting', 'pte', 'limited'],
#  ['fletcher', 'enterprises', 'ltd'],
#  ['mr', 'mokhtar', 'abou', 'basha'],
#  ['ma', 'xiao', 'fei'],
#  ['technology', 'services', 'group', 'corporation'],
#  ['wong', 'pik', 'lin', 'barbara'],
#  ['phoenis', 'trading', 'sa'],
#  ['powell', 'equities', 'sa'],
#  ['belfastscorpkration'],
#  ['ichi', 'dr', 'joe', 'corppration'],
#  ['mrs', 'sandra', 'anne', 'meadows'],
#  ['rufus', 'resourses', 'inc'],
#  ['eastern', 'lake', 'services', 'corp'],
#  ['tania', 'lucia', 'balta', 'mansilla'],
#  ['pennydale', 'investments', 'ltd'],
#  ['orvell', 'estate', 'sa'],
#  ['facoraf', 'ltd'],
#  ['etozir', 'asset', 'management', 'sa'],
#  ['mscoy', 'assetsalimited'],
#  ['myron', 'pacific', 'ltd'],
#  ['arnoold', 'denes'],
#  ['huang', 'yuan', 'lx'],
#  ['top', 'china', 'strategy', 'investments', 'limited'],
#  ['thisledon', 'investments', 'limited'],
#  ['jelen', 'group', 'limited'],
#  ['hermitage', 'international', 'ltd'],
#  ['michel', 'andre', 'oyharcabal'],
#  ['radiant', 'holding', 'corp'],
#  ['lotco', 'holdings', 'inc'],
#  ['juan', 'nicolas', 'leao', 'leal'],
#  ['rivolta', 'inc'],
#  ['gaud', 'grobal', 'corp'],
#  ['wingfield', 'enterprises', 'limited'],
#  ['greater', 'beijing', 'regiongexpressways', 'limited'],
#  ['management', 'nominee', 'services', 'inc'],
#  ['bakner', 'international', 'limited'],
#  ['kaslo', 'limited'],
#  ['ellerton', 'limited'],
#  ['robert', 'david', 'fuchs'],
#  ['chang', 'chia', 'chen'],
#  ['baysan', 'holdings', 'limited'],
#  ['wilian',
#   'raimundo',
#   'ferreira',
#   'egido',
#   'claudia',
#   'cristina',
#   'mateus',
#   'egido',
#   'marlon',
#   'mateus',
#   'egxdo',
#   'and',
#   'carlos',
#   'augusto',
#   'mateus',
#   'egido',
#   'joint',
#   'tenancy',
#   'wuth',
#   'right',
#   'of',
#   'survivorship'],
#  ['john', 'sturgeon'],
#  ['cheufang', 'chapg'],
#  ['procovest', 'sa'],
#  ['panroc', 'holdings', 'inc'],
#  ['tenison', 'associates', 'services', 'likited'],
#  ['mujeres', 'investments', 'limited'],
#  ['curby', 'associates', 'limited'],
#  ['international', 'energy', 'holdings', 'ltd'],
#  ['copper', 'hill', 'investments', 'ltdz'],
#  ['bassacs', 'finance', 'sa'],
#  ['bluebell', 'internataonal', 'holdings', 'sa'],
#  ['mischositos', 'invesmment', 'sa'],
#  ['kean', 'ahkmboo'],
#  ['brilliwnt', 'city', 'enterprisestltd'],
#  ['barwick', 'properties', 'corp'],
#  ['britannia', 'land', 'international', 'limited'],
#  ['mirador', 'resources', 'sa'],
#  ['dornberg', 'holdings', 'limited'],
#  ['supreme', 'pohensinvestment', 'ltd'],
#  ['byrnestone', 'limited'],
#  ['newflame', 'limited'],
#  ['tsollaj', 'yung'],
#  ['mohammad', 'mansour', 'al', 'rumaih'],
#  ['mkc', 'inc'],
#  ['african', 'agricultural', 'advisors', 'limited'],
#  ['bisney', 'profits', 'limited'],
#  ['albany', 'holdings', 'limited'],
#  ['harry', 'pryomitro', 'simon'],
#  ['longville', 'services', 'sa'],
#  ['smart', 'faith', 'sa'],
#  ['mr', 'ery', 'yunasri'],
#  ['molard', 'investments', 'ltd'],
#  ['liu', 'xin', 'hua'],
#  ['maura', 'santiago', 'salles'],
#  ['radiance', 'international', 'ltd'],
#  ['fribel', 'alphil', 'international', 'inc'],
#  ['master', 'nice', 'international', 'ltd'],
#  ['switch', 'financial', 'ltd'],
#  ['tihe', 'creation', 'sechnotogy', 'limited'],
#  ['nadarioo', 'company', 'uimitid'],
#  ['ghi', 'yintai'],
#  ['springtide', 'holdings', 'limited'],
#  ['solent', 'enterprises', 'sa'],
#  ['inversorm', 'meysson', 'sa', 'uruguay'],
#  ['ying', 'liu'],
#  ['gefest', 'investments', 'ltd'],
#  ['yin', 'ke'],
#  ['sapphire', 'equitirs', 'limitnd'],
#  ['smacas', 'international', 'inc'],
#  ['tasso', 'management', 'ltd'],
#  ['mr', 'sergey', 'shikhaleev'],
#  ['rosni', 'lis'],
#  ['xu', 'shu', 'fu'],
#  ['mezzola', 'limited'],
#  ['acertis', 'investment', 'management', 'co', 'limited'],
#  ['nebadcyn', 'limited'],
#  ['lama', 'petroleum', 'ltd'],
#  ['mr', 'bader', 'f', 'mugayel'],
#  ['ebcny', 'saa'],
#  ['sunyview', 'international', 'lkmited'],
#  ['wilderspool', 'investments', 'jersey', 'limited'],
#  ['jose', 'lalo'],
#  ['flice', 'sa'],
#  ['dalcam', 'businqss', 'ltd'],
#  ['bale', 'holding', 'investment', 'ltd'],
#  ['bagstock', 'company', 'limited'],
#  ['dallain', 'holdings', 'inc'],
#  ['mayton', 'investments', 'inc'],
#  ['wagnon', 'ltd'],
#  ['guyod', 'limited'],
#  ['naugai', 'lbw', 'firm'],
#  ['evelenk', 'bianchi', 'y', 'bianchi'],
#  ['khang', 'yl', 'sheng'],
#  ['chan', 'suk', 'lingshirley'],
#  ['cao', 'wensheng'],
#  ['catherine', 'tsung'],
#  ['interworld', 'investment', 'ltd'],
#  ['hampton', 'consulting', 'sa'],
#  ['mr', 'sergey', 'kupriyanov'],
#  ['cojbo', 'finance', 'oa'],
#  ['roan', 'capital', 'partners', 'limited'],
#  ['hsieh', 'chin', 'lung'],
#  ['starpeak', 'limited'],
#  ['cheng', 'kwli', 'chun', 'john'],
#  ['northern', 'minerals', 'partners', 'ltd'],
#  ['sino', 'sky', 'entrrprises', 'limited'],
#  ['abu', 'bakr', 'abidlla', 'hadi', 'aheed', 'al', 'hussaini'],
#  ['clifton', 'sc', 'limited'],
#  ['dzt', 'limited'],
#  ['tarshaql', 'techgincorporated'],
#  ['guernsey', 'administrative', 'services', 'nominees', 'limited'],
#  ['primb', 'limited'],
#  ['kong', 'jun'],
#  ['tower', 'bridge', 'holdings', 'limited'],
#  ['yaomchengzhi'],
#  ['bearef'],
#  ['litewell', 'industrial', 'co', 'ltd'],
#  ['beechleigh', 'property', 'holdings', 'limited'],
#  ['he', 'mohammad', 'abdulla', 'ali', 'algergawi'],
#  ['jean', 'paul', 'van', 'den', 'brande'],
#  ['great', 'talent', 'limited'],
#  ['tomas', 'otto', 'hanson'],
#  ['parklane', 'invostments', 'grour', 'limiyed'],
#  ['oswid', 'tervicesilimited'],
#  ['finisterre', 'holdings', 'limited'],
#  ['danielixbay', 'fcundation'],
#  ['lqu', 'yur', 'sfng'],
#  ['dimitrios', 'papachristos'],
#  ['sierra', 'diamonds', 'ltd'],
#  ['budhichand', 'premchand', 'shah'],
#  ['picardy', 'investments', 'sa'],
#  ['feapearl', 'maritime', 'limised'],
#  ['zhou', 'sui', 'tong'],
#  ['quality', 'communication', 'corp'],
#  ['pinktrol', 'limited'],
#  ['victor', 'daniel', 'martin'],
#  ['corporativo', 'acr', 'sa', 'de', 'cv'],
#  ['zhou', 'yi', 'li'],
#  ['sheringham', 'industries', 'corp'],
#  ['yugraj', 'investments', 'ltd'],
#  ['satsaco', 'holdings', 'corporation'],
#  ['coaaburn', 'limited'],
#  ['alexander', 'nicholas', 'international', 's', 'a'],
#  ['ahasia', 'inc'],
#  ['zheng', 'zhixiao'],
#  ['heathev', 'jnan', 'nicholson'],
#  ['mary', 'mznir', 'ghobrial'],
#  ['promyliz', 'corporation'],
#  ['jitko', 'trading', 'sa'],
#  ['ctm', 'consulting', 'ltd'],
#  ['li', 'ang', 'intl', 'corp'],
#  ['amwtde', 'manrgement', 'sa'],
#  ['lin', 'ching', 'wei'],
#  ['mr', 'rajesh', 'kumar', 'parmar'],
#  ['church',
#   'street',
#   'trustees',
#   'as',
#   'trustees',
#   'of',
#   'the',
#   'la',
#   'rochelle',
#   'trust'],
#  ['projects', 'and', 'conqracts', 'limited'],
#  ['rendmunl', 'marketing', 'inc'],
#  ['fundacion', 'arien'],
#  ['mrsirita', 'lorenzi'],
#  ['elgahar', 'holding', 'incr'],
#  ['radu', 'ciorba'],
#  ['yu', 'dezhang'],
#  ['cheng', 'cohholdfngs', 'sen', 'bhd'],
#  ['zhu', 'hong', 'yan'],
#  ['cassian', 'darcy', 'coquelle'],
#  ['cheung', 'kam', 'kwong'],
#  ['haili', 'technology', 'group', 'co', 'ltd'],
#  ['buchovia', 'equities', 'corp'],
#  ['procos', 'worldwide', 'corp'],
#  ['woodside', 'capital', 'holdings', 'ltd'],
#  ['bridgford', 'property', 'holdings', 'ltd'],
#  ['europlan', 'nominees', 'no', '2', 'limited'],
#  ['winley', 'corp'],
#  ['ingredients', 'corp'],
#  ['minor', 'li', 'chit', 'khim', 'richard'],
#  ['do', 'not', 'use', 'see', 'a122', 'acecroft', 'limited'],
#  ['cristine', 'holdings', 'lto'],
#  ['leontino', 'inc'],
#  ['strong', 'energy', 'ltd'],
#  ['charm', 'trading', 'limited'],
#  ['chin', 'chieh', 'shipping', 'sa'],
#  ['ralter', 'izvest', 'ltk'],
#  ['mangh', 'shuvho'],
#  ['dolenin', 'ltdk'],
#  ['tam', 'po', 'ki'],
#  ['friendship', 'investments', 'inc'],
#  ['finortrust', 'trustees', 'limited'],
#  ['chen', 'xue', 'qun'],
#  ['royal', 'fiduciary', 'group', 'limited', 're', 'aurora'],
#  ['atherfields', 'limited'],
#  ['greater', 'zone', 'development', 'ltd'],
#  ['chadwych', 'limited'],
#  ['abbeybridge', 'limited'],
#  ['pengrove', 'services', 'licited', 'jly'],
#  ['huangbyi', 'cing'],
#  ['m3', 'madagascar', 'ltd'],
#  ['lu', 'hongfei'],
#  ['siti', 'nurbainy', 'akil', 'sahab'],
#  ['imagdnation', 'world', 'limlted'],
#  ['gordy', 'finanqecgroup', 'ja'],
#  ['elsey', 'commerce', 'inc'],
#  ['horgen', 'assets', 'sa'],
#  ['bakkar', 'corp'],
#  ['sinter', 'development', 'ltd'],
#  ['ernie', 'continental', 'trading', 'ltd'],
#  ['jiang', 'hui'],
#  ['tax', 'ding', 'trading', 'limited'],
#  ['mourgue', 'd', 'algue', 'cie'],
#  ['benjamin', 'flournoy'],
#  ['qiankmin'],
#  ['mrqj', 'rnnemaker', 'llm'],
#  ['plink', 'corporation'],
#  ['mrs', 'manoranjana', 'dasgupta'],
#  ['eurofrasia', 'holdings', 'ltd'],
#  ['kormac', 'global', 'inc'],
#  ['mercurio', 'associates', 'sa'],
#  ['ni', 'jun'],
#  ['oceanus', 'investments', 'ltd'],
#  ['sunnybay', 'holdings', 'estates', 'ltd'],
#  ['sharp', 'idea', 'holdings', 'limited'],
#  ['max', 'target', 'investments', 'limited'],
#  ['three', 'ventures', 'incorporated'],
#  ['leticia', 'panugayan'],
#  ['dou', 'mei'],
#  ['wellbred', 'ltd'],
#  ['madam', 'tam', 'ming', 'leun'],
#  ['wealthy', 'land', 'enterprises', 'limited'],
#  ['patson', 'investments', 'limited'],
#  ['scott', 'r', 'dvniels', 'deborah', 'a', 'daniels', 'jt', 'ten'],
#  ['vanair', 'shippingoinc'],
#  ['xin', 'yi', 'investment', 'co', 'ltd'],
#  ['uniglobexconsultants', 'inc'],
#  ['baviright', 'zyoup', 'inc'],
#  ['feng', 'bin'],
#  ['silverdene', 'limited'],
#  ['beauty', 'flame', 'international', 'limited'],
#  ['chrysantal', 'investments', 'ltd'],
#  ['the', 'caledonian', 'hallmark', 'company', 'limited'],
#  ['mr', 'marios', 'papadimas'],
#  ['ayv', 'capital', 'holdings', 'limited'],
#  ['techgart', 'international', 'trading', 'limited'],
#  ['success', 'new', 'limited'],
#  ['greencastle', 'limited'],
#  ['powerline', 'investments', 'limited'],
#  ['hsu', 'chen', 'shen'],
#  ['angel', 'eecasnino'],
#  ['biofish', 'aquicultusa'],
#  ['yu', 'uhun', 'guang'],
#  ['liao', 'pichu'],
#  ['beaumont', 'trading', 'corp'],
#  ['premierynominecs', 'limited'],
#  ['contec', 'corp'],
#  ['interfield', 'sylutions', 'ltd'],
#  ['darius', 'equities', 'sa'],
#  ['gustavo', 'alberto', 'aquino', 'alfieri'],
#  ['adithya', 'kumar', 'poddar'],
#  ['vanluck', 'limited'],
#  ['langford', 'invesf', 'corp'],
#  ['christie', 'consulting', 'inc'],
#  ['dr', 'kapranmkamal'],
#  ['hhiyn', 'chihming'],
#  ['mrs', 'nicole', 'f', 'blancbrude', 'andor', 'mr', 'alain', 'blancbrude'],
#  ['luo', 'wenching'],
#  ['igor', 'flasz'],
#  ['anj', '1996', 'development', 'limated'],
#  ['acra', 'business', 'corporation'],
#  ['monica', 'rodriguez'],
#  ['jatkoesalimited'],
#  ['tammwai', 'ying'],
#  ['laxsnt', 'sam'],
#  ['bao', 'li', 'investments', 'ltd'],
#  ['campus', 'holding', 'group', 'ltd'],
#  ['barnt', 'spring', 'limited'],
#  ['ztaxhill', 'inc'],
#  ['trenton', 'invzrtment', 'services', 'ttd'],
#  ['1868', 'enterprise', 'inc'],
#  ['michael', 'alter', 'kushnir'],
#  ['dfp', 'investments', 'limited'],
#  ['corpoqate', 'nominees', 'limited'],
#  ['mrs', 'arafah', 'bint', 'ali', 'bin', 'mussallam'],
#  ['polytimi', 'manintqs'],
#  ['edgar', 'rene', 'ciceron', 'puyol', 'perdomo'],
#  ['nicole', 'didi'],
#  ['european', 'international', 'management', 'limited'],
#  ['mr', 'park', 'young', 'soo'],
#  ['rpm', 'systems', 'limited'],
#  ['riselark', 'jentures', 'limited'],
#  ['industrial', 'plant', 'design', 'sa'],
#  ['sherlock', 'burns', 'limited'],
#  ['winyoung', 'enterprises', 'limited'],
#  ['china', 'joyce', 'international', 'limiyed'],
#  ['filip', 'olqa', 'jacek'],
#  ['planet', 'solution', 'ltd'],
#  ['arius', 'management', 'corp'],
#  ['tarantella', 'securities', 'limited'],
#  ['secomd', 'court', 'limnted'],
#  ['luis', 'alberto', 'dimnik'],
#  ['carlos', 'enrique', 'larios', 'cueloar'],
#  ['fragrance', 'perfumes', 'o', 'cosmevicos', 'cosp'],
#  ['virgen', 'nutrition', 'ltd'],
#  ['allied', 'success', 'international', 'hk', 'limited'],
#  ['wingo', 'managemeag', 'limited'],
#  ['pearce', 'hughes', 'and', 'aoife', 'hughes'],
#  ['pls', 'international', 'global', 'cwd'],
#  ['mr', 'marco', 'de', 'montis'],
#  ['redxmocn', 'deveropment', 'ltd'],
#  ['quindale', 'management', 'limited'],
#  ['tang', 'meichun'],
#  ['marlon', 'aviation', 'inc'],
#  ['comercio', 'interamericano', 's', 'a'],
#  ['millican', 'investment', 'ltd'],
#  ['lockstone', 'corporation'],
#  ['fundacin', 'nissim'],
#  ['diverse', 'consultancy', 'international', 'ltd'],
#  ['hallmark', 'trust', 'limited'],
#  ['abdullah', 'hamad', 'alrsagrr', 'brothers'],
#  ['sunflower', 'investments', 'limited'],
#  ['joao', 'edward', 'vaz', 'maia'],
#  ['gobeli', 'doll', 'christel'],
#  ['glass', 'plus', 'industries', 'inc'],
#  ['dominic', 'john', 'coubeck'],
#  ['victoria', 'saiidas', 'calvo'],
#  ['mr', 'aubola', 'raphael', 'oluyede'],
#  ['morehead', 'incorporated'],
#  ['erchi', 'investmont', 'holding', 'limited'],
#  ['camden', 'tkchnology', 'limqted'],
#  ['spacecode', 'ventures', 'inc'],
#  ['wilson', 'offshore', 'group', 'holdings', 'bvi', 'limited'],
#  ['luizaumaripni'],
#  ['harvest', 'fortune', 'group', 'ltd'],
#  ['aiyana', 'ltd'],
#  ['regency', 'international', 'services', 'limited'],
#  ['sergio', 'alejandro', 'koreybvit'],
#  ['tamarin', 'properties', 'inc'],
#  ['buchanan', 'trading', 'inc'],
#  ['ellabad', 'fondation'],
#  ['jtc', 'suisse', 'sa', 'as', 'trustee', 'of', 'the', 'velmi', 'trust'],
#  ['the', 'quayla', 'investmengs', 'tzust'],
#  ['min', 'xuan'],
#  ['gca', 'information', 'services', 'limited'],
#  ['genesis', 'exports', 'limited'],
#  ['a', 'd', 'd', 'ltd'],
#  ['the', 'celtic', 'trust', 'company', 'limited'],
#  ['wcn', 'international', 'limited'],
#  ['kai', 'international', 'ltd'],
#  ['gzorious', 'billion', 'develnpment', 'limited'],
#  ['rayville', 'limited'],
#  ['lu', 'minghui'],
#  ['polysjates', 'internftionrl', 'development', 'ltd'],
#  ['hoarding', 'aahu', 'limited'],
#  ['mr', 'tamaz', 'jakhutashvili'],
#  ['layton', 'ventures', 'group', 'inc'],
#  ['c', 'a', 'jerrett'],
#  ['yang', 'wen', 'tao'],
#  ...]

# %%
col_exp = [y for x in col_words for y in x]
col_exp
# Out:
# ['mo',
#  'yuling',
#  'hermes',
#  'global',
#  'services',
#  'fz',
#  'lle',
#  'monaco',
#  'deerfield',
#  'investments',
#  'group',
#  'ltd',
#  'sidney',
#  'frankel',
#  'freshlolkarmrltd',
#  'pricewaterhouse',
#  'coopers',
#  'malta',
#  'solby',
#  'holding',
#  'limited',
#  'chang',
#  'min',
#  'seok',
#  'tsax',
#  'wuli',
#  'peter',
#  'colaco',
#  'leisure',
#  'group',
#  'holdings',
#  'inc',
#  'dencourt',
#  'services',
#  'limited',
#  'fotlock',
#  'international',
#  'sa',
#  'jiang',
#  'qiang',
#  'whemoton',
#  'scyprusglimited',
#  'east',
#  'dawn',
#  'group',
#  'sen',
#  'savas',
#  'oil',
#  'international',
#  'corporation',
#  'amerwell',
#  'investments',
#  'limited',
#  'sinocom',
#  'ideas',
#  'holdings',
#  'lizitkd',
#  'rivaldi',
#  'holdings',
#  'ltd',
#  'ventura',
#  'propertieb',
#  'limited',
#  'natron',
#  'investments',
#  'corp',
#  'virtus',
#  'trust',
#  'limited',
#  'as',
#  'trustess',
#  'of',
#  'the',
#  'hayward',
#  'family',
#  '1993',
#  'settlement',
#  'primeline',
#  'international',
#  'development',
#  'corporation',
#  'canal',
#  'tryst',
#  'companywlimitld',
#  'capital',
#  'invest',
#  'portfolio',
#  'inc',
#  'mrpetergschopt',
#  'edmundo',
#  'david',
#  'tefel',
#  'pasos',
#  'crinam',
#  'limited',
#  'dazzle',
#  'international',
#  'limited',
#  'furnidec',
#  'limited',
#  'dblmaixe',
#  'limided',
#  'ellenton',
#  'company',
#  'atd',
#  'utrition',
#  'inc',
#  'hearnville',
#  'inc',
#  'nilo',
#  'consultores',
#  'sas',
#  'the',
#  'piat',
#  'foundation',
#  'international',
#  'fund',
#  'management',
#  'corp',
#  'montis',
#  'co',
#  'mr',
#  'geron',
#  'pozov',
#  'gloria',
#  'management',
#  'equities',
#  'inc',
#  'mr',
#  'francisco',
#  'ortiz',
#  'von',
#  'bismarck',
#  'newmarket',
#  'traders',
#  'ltd',
#  'tristan',
#  'energy',
#  'capital',
#  'ltd',
#  'chu',
#  'ah',
#  'kiew',
#  'ikroy',
#  'limited',
#  'tomsun',
#  'trading',
#  'ltd',
#  'palmdella',
#  'limited',
#  'paula',
#  'andrea',
#  'osorio',
#  'muoz',
#  'denvale',
#  'finance',
#  'incorporated',
#  'sigesky',
#  'trading',
#  'sav',
#  'peace',
#  'afd',
#  'serenity',
#  'limsved',
#  'christopher',
#  'anthony',
#  'castelloe',
#  'kathleen',
#  'costelloe',
#  'jointly',
#  'with',
#  'right',
#  'of',
#  'qurvivorship',
#  'apson',
#  'technology',
#  'limited',
#  'liu',
#  'lfng',
#  'tyliam',
#  'ltd',
#  'eriton',
#  'consulting',
#  'limited',
#  'wang',
#  'wenqiao',
#  'cafate',
#  'inc',
#  'glory',
#  'champion',
#  'holdinqscltd',
#  'joaquin',
#  'ziaedurn',
#  'selectron',
#  'members',
#  'ltd',
#  'taiwan',
#  'tunes',
#  'inl',
#  'ambert',
#  'limited',
#  'millside',
#  'holdings',
#  'inc',
#  'forest',
#  'ggpen',
#  'howdings',
#  'limited',
#  'zandeleigh',
#  'limited',
#  'peravro',
#  'limited',
#  'amphios',
#  'management',
#  'inc',
#  'hedsham',
#  'inc',
#  'pebble',
#  'management',
#  'corp',
#  'roberi',
#  'newmin',
#  'you',
#  'wei',
#  'capital',
#  'limited',
#  'avel',
#  'gonzalez',
#  'zng',
#  'nominees',
#  'bvi',
#  'ltd',
#  'ferrrtti',
#  'group',
#  'limited',
#  'malina',
#  'holding',
#  'ltd',
#  'ralph',
#  'gore',
#  'watson',
#  'sunvjle',
#  'investments',
#  'limited',
#  'akron',
#  'investments',
#  'ltd',
#  'bondex',
#  'logistics',
#  'company',
#  'limited',
#  'lupus',
#  'investments',
#  's',
#  'a',
#  'piru',
#  'inc',
#  'jc',
#  'paemkum',
#  'lwd',
#  'wings',
#  'holding',
#  'management',
#  'inc',
#  'monthrie',
#  'nssociatws',
#  'inc',
#  'leymer',
#  'company',
#  'inc',
#  'lidena',
#  'intergroup',
#  'ltd',
#  'canadian',
#  'investment',
#  'phoperties',
#  'ltd',
#  'compagnie',
#  'financiere',
#  'et',
#  'fonciere',
#  'sa',
#  'utiglobe',
#  'secukities',
#  'limited',
#  'asil',
#  'enterprises',
#  'inc',
#  'citco',
#  'trusteys',
#  'bvi',
#  'limited',
#  'as',
#  'trustee',
#  'of',
#  'the',
#  'creative',
#  'vysta',
#  'trust',
#  'wu',
#  'yuanlin',
#  'metchem',
#  'engineering',
#  'sa',
#  'forest',
#  'industries',
#  'group',
#  'sa',
#  'belen',
#  'velutini',
#  'sergev',
#  'zuixstv',
#  'gold',
#  'come',
#  'holdings',
#  'limited',
#  'wincqester',
#  'consultants',
#  'equities',
#  'ltd',
#  'ya',
#  'xiaolong',
#  'joasma',
#  'corporation',
#  'petr',
#  'skovotodko',
#  'transit',
#  'technologies',
#  'inc',
#  'zona',
#  'impex',
#  'ltd',
#  'gold',
#  'rush',
#  'assets',
#  'limited',
#  'mrs',
#  'patrizia',
#  'poggi',
#  'jabar',
#  'properties',
#  'limited',
#  'ehab',
#  'osman',
#  'khalil',
#  'rheindeer',
#  'enterprises',
#  'inc',
#  'key',
#  'line',
#  'pamific',
#  'eimited',
#  'carlos',
#  'de',
#  'carvalho',
#  'crespo',
#  'bickerton',
#  'ltd',
#  'goxden',
#  'garewao',
#  'development',
#  'ltd',
#  'regiu',
#  'compavy',
#  'management',
#  'sa',
#  'victor',
#  'sukmanov',
#  'wang',
#  'facai',
#  'advanlinksinvestment',
#  'co',
#  'utd',
#  'edward',
#  'meja',
#  'musa',
#  'corp',
#  'intercoa',
#  'limited',
#  'design',
#  'away',
#  'limited',
#  'baker',
#  'industries',
#  'corporation',
#  'renyard',
#  'company',
#  'limited',
#  'artisti',
#  'corp',
#  'multicare',
#  'pharma',
#  'limited',
#  'comblowx',
#  'investmentd',
#  'ltd',
#  'jerome',
#  'overseas',
#  'sa',
#  'bartlou',
#  'limqeed',
#  'suliman',
#  'dockrat',
#  'bikler',
#  'ltd',
#  'leonia',
#  'capital',
#  'ltd',
#  'liu',
#  'zinghsien',
#  'li',
#  'jianwei',
#  'apic',
#  'trustees',
#  'ltd',
#  'ap119',
#  'berrima',
#  'global',
#  'ltd',
#  'perth',
#  'pkoperties',
#  'limited',
#  'willamett',
#  'enterprise',
#  'ltd',
#  'parkhouse',
#  'services',
#  'ltd',
#  'carrolabd',
#  'industries',
#  'limited',
#  'nominest',
#  'international',
#  'ltd',
#  'petcon',
#  'borneo',
#  'limited',
#  'ccs',
#  'corporate',
#  'services',
#  'limited',
#  'jefny',
#  'del',
#  'consuelo',
#  'jimenez',
#  'asanza',
#  'alarion',
#  'company',
#  'inc',
#  'intergirasol',
#  'jm',
#  'corp',
#  'roisine',
#  'limited',
#  'depec',
#  'technologies',
#  'ltd',
#  'han',
#  'hong',
#  'jun',
#  'david',
#  'adamson',
#  'hirst',
#  'mrs',
#  'voorma',
#  'hannie',
#  'invernada',
#  'sa',
#  'owsley',
#  'marketingxcorp',
#  'vintage',
#  'finance',
#  'sa',
#  'vitamax',
#  'foundation',
#  'shao',
#  'changshi',
#  'white',
#  'raven',
#  'limited',
#  'huang',
#  'ping',
#  'corporate',
#  'agents',
#  'bvi',
#  'limited',
#  'as',
#  'trustee',
#  'of',
#  'the',
#  'silver',
#  'mine',
#  'capital',
#  'trust',
#  'albion',
#  'fvnanciab',
#  'holdings',
#  'inc',
#  'bakkari',
#  'international',
#  'inc',
#  'maxwall',
#  'invest',
#  'corp',
#  'bearej',
#  'share',
#  'inprover',
#  'trading',
#  'limited',
#  'harvest',
#  'aspect',
#  'international',
#  'limited',
#  'thetie',
#  'marite',
#  'limited',
#  'alderson',
#  'investments',
#  'inc',
#  'zarnol',
#  'trading',
#  'inc',
#  'libshqq',
#  'artviewwgrhuc',
#  'ltd',
#  'asialeesources',
#  'inc',
#  'pergola',
#  'partners',
#  'sa',
#  'marwan',
#  'r',
#  'frem',
#  'kambo',
#  'securidy',
#  'products',
#  'limited',
#  'buwan',
#  'marketing',
#  'inc',
#  'international',
#  'personal',
#  'trainer',
#  'institute',
#  'limited',
#  'overlea',
#  'consultants',
#  'inc',
#  'borrowdale',
#  'nominees',
#  'limited',
#  'delphisuconsultkng',
#  'group',
#  'limited',
#  'xiaocong',
#  'qiu',
#  'awad',
#  'ammora',
#  'rodney',
#  'glyndwr',
#  'james',
#  'thea',
#  'van',
#  'eupen',
#  'james',
#  'and',
#  'dominic',
#  'anthony',
#  'oneil',
#  'jointly',
#  'as',
#  'trustees',
#  'trenton',
#  'properties',
#  'ltd',
#  'lexington',
#  'computer',
#  'consultants',
#  'inc',
#  'furantall',
#  'international',
#  'limited',
#  'chen',
#  'chienchou',
#  'roussellelimiten',
#  'zenith',
#  'marketing',
#  'sa',
#  'tao',
#  'wenchieh',
#  'lankom',
#  'limited',
#  'zonea',
#  'liiitxd',
#  'jade',
#  'port',
#  'technologyhltdo',
#  'mr',
#  'andreytrogachev',
#  'james',
#  'john',
#  'zuehlen',
#  'elena',
#  'gemeliari',
#  'gao',
#  'guargpi',
#  'juan',
#  'pndro',
#  'damiani',
#  'finsbury',
#  'international',
#  'limited',
#  'rr',
#  'seref',
#  'dogan',
#  'erbek',
#  'roblrto',
#  'pocaterma',
#  'powell',
#  'estate',
#  'ltd',
#  'hitectebcom',
#  'ltd',
#  'runshine',
#  'businessqaac',
#  'valarie',
#  'jean',
#  'ward',
#  'pin',
#  'international',
#  'holdings',
#  'limited',
#  'rpptman',
#  'ooman',
#  'jtc',
#  'securities',
#  'limited',
#  'yong',
#  'hong',
#  'wei',
#  'rantiagoqgombz',
#  'juniper',
#  'trading',
#  'group',
#  'sa',
#  'jlannie',
#  'chungyingpaiu',
#  'mr',
#  'lukyanchuk',
#  'yury',
#  'carlyle',
#  'trading',
#  'limiteo',
#  'rexford',
#  'holdings',
#  'sa',
#  'crown',
#  'fair',
#  'investment',
#  'ltd',
#  'knight',
#  'star',
#  'sa',
#  'ignacio',
#  'agustin',
#  'kassis',
#  'manzur',
#  'quantic',
#  'oil',
#  'sa',
#  'offshore',
#  'zhu',
#  'ping',
#  'reflex',
#  'holdings',
#  'ltd',
#  'satabco',
#  'ltd',
#  'grand',
#  'world',
#  'investment',
#  'ltd',
#  'ukr',
#  'international',
#  'limited',
#  'a',
#  'pw',
#  'corpoeation',
#  'diego',
#  'alfie',
#  'gonzlez',
#  'semita',
#  'limited',
#  'andrey',
#  'ruzheynikov',
#  'zhangvjiyang',
#  'stelmar',
#  'daimonds',
#  'xtd',
#  'gladstone',
#  'lwasinv',
#  'inc',
#  'lo',
#  'hiu',
#  'fai',
#  'johnny',
#  'curaldo',
#  'investments',
#  'limited',
#  'keasn',
#  'fialko',
#  'hancker',
#  'corporation',
#  'haymend',
#  'sa',
#  'alfred',
#  'aspen',
#  'laurent',
#  'nheypitet',
#  'vistrade',
#  'engineering',
#  'corp',
#  'joyce',
#  'harvest',
#  'international',
#  'ltd',
#  'exclusive',
#  'wotldwide',
#  'likited',
#  'vigilax',
#  'inc',
#  'north',
#  'atlantic',
#  'secretaries',
#  'limited',
#  'hartsdale',
#  'nv',
#  'persephone',
#  'investments',
#  'holding',
#  'ltd',
#  'la',
#  'atlantida',
#  's',
#  'a',
#  'pranor',
#  'holding',
#  'inc',
#  'grand',
#  'chinp',
#  'international',
#  'limited',
#  'glanford',
#  'foundrtioy',
#  'lai',
#  'lungchin',
#  'happy',
#  'rise',
#  'management',
#  'ltd',
#  'lawngrove',
#  'overseas',
#  'limited',
#  'denver',
#  'finance',
#  'ltd',
#  'orino',
#  'corp',
#  'orient',
#  'future',
#  'international',
#  'limited',
#  'enoc',
#  'limited',
#  'imperial',
#  'company',
#  'limited',
#  'suite1r',
#  'cunbeblvnd',
#  'ltd',
#  'wang',
#  'jian',
#  'qiang',
#  'mr',
#  'kenneth',
#  'chin',
#  'su',
#  'sian',
#  'malshost',
#  'international',
#  'lymited',
#  'intercare',
#  'limited',
#  'purple',
#  'hoydingq',
#  'llc',
#  'lisle',
#  'international',
#  'group',
#  'corp',
#  'iap',
#  'investment',
#  'trust',
#  'services',
#  'ag',
#  'soonhee',
#  'hinrichs',
#  'lancelot',
#  'associates',
#  'limited',
#  'law',
#  'yuk',
#  'ling',
#  'kleinwort',
#  'benson',
#  'guernsey',
#  'trustees',
#  'limited',
#  'n',
#  'c',
#  'robins',
#  'and',
#  'p',
#  's',
#  'le',
#  'poidevin',
#  're',
#  'g',
#  'baron',
#  'paxton',
#  'financial',
#  'group',
#  'corp',
#  'tenon',
#  'iom',
#  'nominees',
#  'ltd',
#  'cristalmar',
#  'corporation',
#  'paneast',
#  'investments',
#  'inc',
#  'clearwater',
#  'yachtf',
#  'limited',
#  'mrs',
#  'natalia',
#  'melikhova',
#  'sunora',
#  'limited',
#  'dugminhvng',
#  'ningyudn',
#  'holdings',
#  'ltd',
#  'dalex',
#  'alliance',
#  'inc',
#  'thalassa',
#  'nominees',
#  'swa',
#  'crosskeys',
#  'services',
#  'limited',
#  'caravel',
#  'development',
#  'international',
#  'projects',
#  'inc',
#  'pinama',
#  'sun',
#  'dried',
#  'mnc',
#  'leisure',
#  'products',
#  'holdings',
#  'limited',
#  'wang',
#  'han',
#  'qing',
#  'damor',
#  'investments',
#  'limited',
#  'querrin',
#  'shipping',
#  'limited',
#  'lam',
#  'sim',
#  'kuen',
#  'jeroda',
#  'promotion',
#  'ltd',
#  'bush',
#  'ac',
#  'ltd',
#  'charterhyuse',
#  'finance',
#  'inc',
#  'nyon',
#  'worldwide',
#  'corp',
#  'sonic',
#  'connect',
#  'limitek',
#  'yellow',
#  'light',
#  'sa',
#  'yew',
#  'green',
#  'properties',
#  'limited',
#  'james',
#  'h',
#  'hafterson',
#  'bereficence',
#  'fowndaticn',
#  'georg',
#  'staeheli',
#  'javie',
#  'kendraxlai',
#  'sook',
#  'chiuem',
#  'ornsay',
#  'residency',
#  'uk',
#  'ltd',
#  'cheer',
#  'ascent',
#  'investment',
#  'limited',
#  'karaboon',
#  'company',
#  'limited',
#  'zahida',
#  'dero',
#  'swan',
#  'capital',
#  'management',
#  'ltd',
#  'mr',
#  'hseyin',
#  'ayduk',
#  'esat',
#  'koray',
#  'dxb',
#  'international',
#  'holdings',
#  'ltd',
#  'detris',
#  'intefnawional',
#  'coqp',
#  'matura',
#  'holding',
#  'inc',
#  'baldaquin',
#  'inc',
#  'hansa',
#  'maritime',
#  'ltd',
#  'lynus',
#  'properties',
#  'limited',
#  'new',
#  'shobe',
#  'finanoe',
#  'limited',
#  'sirgronald',
#  'girierson',
#  'internabional',
#  'businegs',
#  'commercial',
#  'company',
#  'inc',
#  'fenera',
#  'corporation',
#  'holenstein',
#  'rechtsanwlte',
#  'ringo',
#  'star',
#  'trading',
#  'inc',
#  'beijing',
#  'dragon',
#  'resources',
#  'limited',
#  'weldin',
#  'inc',
#  'ontech',
#  'technology',
#  'corp',
#  'zhang',
#  'sen',
#  'qi',
#  'joseeluis',
#  'bruzgond',
#  'li',
#  'gui',
#  'chun',
#  'kryn',
#  'holdinhs',
#  'limited',
#  ...]

# %%
from collections import Counter
top_50_words = [x[0] for x in Counter(col_exp).most_common()[:50]]
top_50_words
# Out:
# ['limited',
#  'ltd',
#  'inc',
#  'sa',
#  'international',
#  'holdings',
#  'corp',
#  'investments',
#  'group',
#  'management',
#  'co',
#  'trading',
#  'corporation',
#  'services',
#  'investment',
#  'mr',
#  'company',
#  'enterprises',
#  'trust',
#  'holding',
#  'development',
#  'properties',
#  'finance',
#  'the',
#  'foundation',
#  'of',
#  'capital',
#  'global',
#  'and',
#  'de',
#  'nominees',
#  'as',
#  'trustees',
#  'consultants',
#  'overseas',
#  'associates',
#  'assets',
#  'a',
#  'business',
#  'li',
#  'consulting',
#  'wang',
#  'property',
#  'chen',
#  'trustee',
#  's',
#  'equities',
#  'mrs',
#  'technology',
#  'maria']

# %%
cleaned_col = [[y for y in x if y not in top_50_words] for x in tqdm(col_words)] 
cleaned_col
# Out:
# HBox(children=(IntProgress(value=0, max=333070), HTML(value='')))
# [['mo', 'yuling'],
#  ['hermes', 'fz', 'lle', 'monaco'],
#  ['deerfield'],
#  ['sidney', 'frankel'],
#  ['freshlolkarmrltd'],
#  ['pricewaterhouse', 'coopers', 'malta'],
#  ['solby'],
#  ['chang', 'min', 'seok'],
#  ['tsax', 'wuli'],
#  ['peter', 'colaco'],
#  ['leisure'],
#  ['dencourt'],
#  ['fotlock'],
#  ['jiang', 'qiang'],
#  ['whemoton', 'scyprusglimited'],
#  ['east', 'dawn', 'sen'],
#  ['savas', 'oil'],
#  ['amerwell'],
#  ['sinocom', 'ideas', 'lizitkd'],
#  ['rivaldi'],
#  ['ventura', 'propertieb'],
#  ['natron'],
#  ['virtus', 'trustess', 'hayward', 'family', '1993', 'settlement'],
#  ['primeline'],
#  ['canal', 'tryst', 'companywlimitld'],
#  ['invest', 'portfolio'],
#  ['mrpetergschopt'],
#  ['edmundo', 'david', 'tefel', 'pasos'],
#  ['crinam'],
#  ['dazzle'],
#  ['furnidec'],
#  ['dblmaixe', 'limided'],
#  ['ellenton', 'atd'],
#  ['utrition'],
#  ['hearnville'],
#  ['nilo', 'consultores', 'sas'],
#  ['piat'],
#  ['fund'],
#  ['montis'],
#  ['geron', 'pozov'],
#  ['gloria'],
#  ['francisco', 'ortiz', 'von', 'bismarck'],
#  ['newmarket', 'traders'],
#  ['tristan', 'energy'],
#  ['chu', 'ah', 'kiew'],
#  ['ikroy'],
#  ['tomsun'],
#  ['palmdella'],
#  ['paula', 'andrea', 'osorio', 'muoz'],
#  ['denvale', 'incorporated'],
#  ['sigesky', 'sav'],
#  ['peace', 'afd', 'serenity', 'limsved'],
#  ['christopher',
#   'anthony',
#   'castelloe',
#   'kathleen',
#   'costelloe',
#   'jointly',
#   'with',
#   'right',
#   'qurvivorship'],
#  ['apson'],
#  ['liu', 'lfng'],
#  ['tyliam'],
#  ['eriton'],
#  ['wenqiao'],
#  ['cafate'],
#  ['glory', 'champion', 'holdinqscltd'],
#  ['joaquin', 'ziaedurn'],
#  ['selectron', 'members'],
#  ['taiwan', 'tunes', 'inl'],
#  ['ambert'],
#  ['millside'],
#  ['forest', 'ggpen', 'howdings'],
#  ['zandeleigh'],
#  ['peravro'],
#  ['amphios'],
#  ['hedsham'],
#  ['pebble'],
#  ['roberi', 'newmin'],
#  ['you', 'wei'],
#  ['avel', 'gonzalez'],
#  ['zng', 'bvi'],
#  ['ferrrtti'],
#  ['malina'],
#  ['ralph', 'gore', 'watson'],
#  ['sunvjle'],
#  ['akron'],
#  ['bondex', 'logistics'],
#  ['lupus'],
#  ['piru'],
#  ['jc', 'paemkum', 'lwd'],
#  ['wings'],
#  ['monthrie', 'nssociatws'],
#  ['leymer'],
#  ['lidena', 'intergroup'],
#  ['canadian', 'phoperties'],
#  ['compagnie', 'financiere', 'et', 'fonciere'],
#  ['utiglobe', 'secukities'],
#  ['asil'],
#  ['citco', 'trusteys', 'bvi', 'creative', 'vysta'],
#  ['wu', 'yuanlin'],
#  ['metchem', 'engineering'],
#  ['forest', 'industries'],
#  ['belen', 'velutini'],
#  ['sergev', 'zuixstv'],
#  ['gold', 'come'],
#  ['wincqester'],
#  ['ya', 'xiaolong'],
#  ['joasma'],
#  ['petr', 'skovotodko'],
#  ['transit', 'technologies'],
#  ['zona', 'impex'],
#  ['gold', 'rush'],
#  ['patrizia', 'poggi'],
#  ['jabar'],
#  ['ehab', 'osman', 'khalil'],
#  ['rheindeer'],
#  ['key', 'line', 'pamific', 'eimited'],
#  ['carlos', 'carvalho', 'crespo'],
#  ['bickerton'],
#  ['goxden', 'garewao'],
#  ['regiu', 'compavy'],
#  ['victor', 'sukmanov'],
#  ['facai'],
#  ['advanlinksinvestment', 'utd'],
#  ['edward', 'meja'],
#  ['musa'],
#  ['intercoa'],
#  ['design', 'away'],
#  ['baker', 'industries'],
#  ['renyard'],
#  ['artisti'],
#  ['multicare', 'pharma'],
#  ['comblowx', 'investmentd'],
#  ['jerome'],
#  ['bartlou', 'limqeed'],
#  ['suliman', 'dockrat'],
#  ['bikler'],
#  ['leonia'],
#  ['liu', 'zinghsien'],
#  ['jianwei'],
#  ['apic', 'ap119'],
#  ['berrima'],
#  ['perth', 'pkoperties'],
#  ['willamett', 'enterprise'],
#  ['parkhouse'],
#  ['carrolabd', 'industries'],
#  ['nominest'],
#  ['petcon', 'borneo'],
#  ['ccs', 'corporate'],
#  ['jefny', 'del', 'consuelo', 'jimenez', 'asanza'],
#  ['alarion'],
#  ['intergirasol', 'jm'],
#  ['roisine'],
#  ['depec', 'technologies'],
#  ['han', 'hong', 'jun'],
#  ['david', 'adamson', 'hirst'],
#  ['voorma', 'hannie'],
#  ['invernada'],
#  ['owsley', 'marketingxcorp'],
#  ['vintage'],
#  ['vitamax'],
#  ['shao', 'changshi'],
#  ['white', 'raven'],
#  ['huang', 'ping'],
#  ['corporate', 'agents', 'bvi', 'silver', 'mine'],
#  ['albion', 'fvnanciab'],
#  ['bakkari'],
#  ['maxwall', 'invest'],
#  ['bearej', 'share'],
#  ['inprover'],
#  ['harvest', 'aspect'],
#  ['thetie', 'marite'],
#  ['alderson'],
#  ['zarnol'],
#  ['libshqq'],
#  ['artviewwgrhuc'],
#  ['asialeesources'],
#  ['pergola', 'partners'],
#  ['marwan', 'r', 'frem'],
#  ['kambo', 'securidy', 'products'],
#  ['buwan', 'marketing'],
#  ['personal', 'trainer', 'institute'],
#  ['overlea'],
#  ['borrowdale'],
#  ['delphisuconsultkng'],
#  ['xiaocong', 'qiu'],
#  ['awad', 'ammora'],
#  ['rodney',
#   'glyndwr',
#   'james',
#   'thea',
#   'van',
#   'eupen',
#   'james',
#   'dominic',
#   'anthony',
#   'oneil',
#   'jointly'],
#  ['trenton'],
#  ['lexington', 'computer'],
#  ['furantall'],
#  ['chienchou'],
#  ['roussellelimiten'],
#  ['zenith', 'marketing'],
#  ['tao', 'wenchieh'],
#  ['lankom'],
#  ['zonea', 'liiitxd'],
#  ['jade', 'port', 'technologyhltdo'],
#  ['andreytrogachev'],
#  ['james', 'john', 'zuehlen'],
#  ['elena', 'gemeliari'],
#  ['gao', 'guargpi'],
#  ['juan', 'pndro', 'damiani'],
#  ['finsbury'],
#  ['rr', 'seref', 'dogan', 'erbek'],
#  ['roblrto', 'pocaterma'],
#  ['powell', 'estate'],
#  ['hitectebcom'],
#  ['runshine', 'businessqaac'],
#  ['valarie', 'jean', 'ward'],
#  ['pin'],
#  ['rpptman', 'ooman'],
#  ['jtc', 'securities'],
#  ['yong', 'hong', 'wei'],
#  ['rantiagoqgombz'],
#  ['juniper'],
#  ['jlannie', 'chungyingpaiu'],
#  ['lukyanchuk', 'yury'],
#  ['carlyle', 'limiteo'],
#  ['rexford'],
#  ['crown', 'fair'],
#  ['knight', 'star'],
#  ['ignacio', 'agustin', 'kassis', 'manzur'],
#  ['quantic', 'oil', 'offshore'],
#  ['zhu', 'ping'],
#  ['reflex'],
#  ['satabco'],
#  ['grand', 'world'],
#  ['ukr'],
#  ['pw', 'corpoeation'],
#  ['diego', 'alfie', 'gonzlez'],
#  ['semita'],
#  ['andrey', 'ruzheynikov'],
#  ['zhangvjiyang'],
#  ['stelmar', 'daimonds', 'xtd'],
#  ['gladstone', 'lwasinv'],
#  ['lo', 'hiu', 'fai', 'johnny'],
#  ['curaldo'],
#  ['keasn', 'fialko'],
#  ['hancker'],
#  ['haymend'],
#  ['alfred', 'aspen'],
#  ['laurent', 'nheypitet'],
#  ['vistrade', 'engineering'],
#  ['joyce', 'harvest'],
#  ['exclusive', 'wotldwide', 'likited'],
#  ['vigilax'],
#  ['north', 'atlantic', 'secretaries'],
#  ['hartsdale', 'nv'],
#  ['persephone'],
#  ['la', 'atlantida'],
#  ['pranor'],
#  ['grand', 'chinp'],
#  ['glanford', 'foundrtioy'],
#  ['lai', 'lungchin'],
#  ['happy', 'rise'],
#  ['lawngrove'],
#  ['denver'],
#  ['orino'],
#  ['orient', 'future'],
#  ['enoc'],
#  ['imperial'],
#  ['suite1r', 'cunbeblvnd'],
#  ['jian', 'qiang'],
#  ['kenneth', 'chin', 'su', 'sian'],
#  ['malshost', 'lymited'],
#  ['intercare'],
#  ['purple', 'hoydingq', 'llc'],
#  ['lisle'],
#  ['iap', 'ag'],
#  ['soonhee', 'hinrichs'],
#  ['lancelot'],
#  ['law', 'yuk', 'ling'],
#  ['kleinwort',
#   'benson',
#   'guernsey',
#   'n',
#   'c',
#   'robins',
#   'p',
#   'le',
#   'poidevin',
#   're',
#   'g',
#   'baron'],
#  ['paxton', 'financial'],
#  ['tenon', 'iom'],
#  ['cristalmar'],
#  ['paneast'],
#  ['clearwater', 'yachtf'],
#  ['natalia', 'melikhova'],
#  ['sunora'],
#  ['dugminhvng'],
#  ['ningyudn'],
#  ['dalex', 'alliance'],
#  ['thalassa', 'swa'],
#  ['crosskeys'],
#  ['caravel', 'projects'],
#  ['pinama', 'sun', 'dried', 'mnc'],
#  ['leisure', 'products'],
#  ['han', 'qing'],
#  ['damor'],
#  ['querrin', 'shipping'],
#  ['lam', 'sim', 'kuen'],
#  ['jeroda', 'promotion'],
#  ['bush', 'ac'],
#  ['charterhyuse'],
#  ['nyon', 'worldwide'],
#  ['sonic', 'connect', 'limitek'],
#  ['yellow', 'light'],
#  ['yew', 'green'],
#  ['james', 'h', 'hafterson'],
#  ['bereficence', 'fowndaticn'],
#  ['georg', 'staeheli'],
#  ['javie', 'kendraxlai', 'sook', 'chiuem'],
#  ['ornsay', 'residency', 'uk'],
#  ['cheer', 'ascent'],
#  ['karaboon'],
#  ['zahida', 'dero'],
#  ['swan'],
#  ['hseyin', 'ayduk', 'esat', 'koray'],
#  ['dxb'],
#  ['detris', 'intefnawional', 'coqp'],
#  ['matura'],
#  ['baldaquin'],
#  ['hansa', 'maritime'],
#  ['lynus'],
#  ['new', 'shobe', 'finanoe'],
#  ['sirgronald', 'girierson'],
#  ['internabional', 'businegs', 'commercial'],
#  ['fenera'],
#  ['holenstein', 'rechtsanwlte'],
#  ['ringo', 'star'],
#  ['beijing', 'dragon', 'resources'],
#  ['weldin'],
#  ['ontech'],
#  ['zhang', 'sen', 'qi'],
#  ['joseeluis', 'bruzgond'],
#  ['gui', 'chun'],
#  ['kryn', 'holdinhs'],
#  ['silos', 'bonniere'],
#  ['wangnang'],
#  ['her', 'chan'],
#  ['union', 'tiger'],
#  ['patricia', 'mesa'],
#  ['keen', 'wise'],
#  ['wyman'],
#  ['arctilana'],
#  ['estudio',
#   'juridico',
#   'ortega',
#   'moreira',
#   'ortega',
#   'trwjillo',
#   'abogados'],
#  ['cees', 'baas'],
#  ['eastqrn', 'aqcessoqies'],
#  ['wt'],
#  ['buxter', 'associatfs'],
#  ['carolyue', 'duncombe', 'robinson'],
#  ['omega'],
#  ['imiying', 'eleccronics'],
#  ['elena', 'nikolayevna', 'shipitsyna'],
#  ['stantrade'],
#  ['big', 'world'],
#  ['mandarin', 'traxing', 'limiteh'],
#  ['gaosxiang'],
#  ['denis', 'kropotkin'],
#  ['carena', 'inzernational', 'covp'],
#  ['prodectors', 'limiten'],
#  ['maeve'],
#  ['equity', 'bahamas'],
#  ['trent', 'vale'],
#  ['ryedale'],
#  ['nek'],
#  ['ultimatetm', 'organisation', 'llc'],
#  ['marcos', 'alberto', 'labaton'],
#  ['zhao', 'siyuan'],
#  ['sumesh', 'rajgopal'],
#  ['oldroy'],
#  ['oriental'],
#  ['oldwick', 'litited'],
#  ['azamat', 'babmjkhanbetov'],
#  ['sharington'],
#  ['fairview'],
#  ['taporley'],
#  ['sheridan'],
#  ['abdul', 'kayum'],
#  ['uniped', 'prosper', 'enserpriwe'],
#  ['huang', 'guoyu'],
#  ['kenway', 'technologies'],
#  ['best', 'resources', 'managers'],
#  ['mindmotion', 'microelectrondck', 'ltm'],
#  ['claudie', 'degchamps'],
#  ['cheer', 'point'],
#  ['stpdie', 'scgt'],
#  ['velsen'],
#  ['wenhsiang'],
#  ['zhao', 'jing'],
#  ['neofantastic', 'fashions'],
#  ['verug', 'holdgng', 'incf'],
#  ['kenner'],
#  ['silvejlock'],
#  ['arco'],
#  ['monte', 'cristo', 'captial'],
#  ['mohammed', 'nizar', 'alnakeeb'],
#  ['briardjle', 'limitee'],
#  ['filament'],
#  ['corvest', 'invlstmezts'],
#  ['valroy'],
#  ['fouad', 'el', 'imam'],
#  ['majed', 'sulaiman', 'al', 'nafie'],
#  ['kang', 'shaokui'],
#  ['garfinkel', 'simon'],
#  ['dulwich'],
#  ['juan', 'oswaldo', 'ywnelli', 'aguirrh'],
#  ['novaglobus'],
#  ['westland'],
#  ['ms', 'bassil', 'yasmeen', 'elieqmalip'],
#  ['ocean', 'treasure'],
#  ['montserrat', 'developments'],
#  ['high', 'court'],
#  ['auxiliadora', 'febres', 'cordero', 'cordovez'],
#  ['colorado', 'compaly', 'equiyies'],
#  ['lu', 'weidong'],
#  ['gong', 'yishu'],
#  ['zhuang', 'yonysheng'],
#  ['mohamad', 'tahsine', 'el', 'khayat'],
#  ['worldwise'],
#  ['kestrel'],
#  ['mossack', 'fonseca', 'per'],
#  ['robinaalvarez'],
#  ['vinayak'],
#  ['gwrtonville', 'limiled'],
#  ['k11', 'partners'],
#  ['dominion'],
#  ['b24', 'marquisconsultadoria', 'e', 'servicos', 'lda'],
#  ['perosa'],
#  ['avgousta', 'svoronou'],
#  ['kathleen', 'tynan'],
#  ['scysee'],
#  ['paddock', 'crediyz'],
#  ['lebowitz', 'chedva'],
#  ['castle', 'hill'],
#  ['komustrade'],
#  ['mrsd', 'aida', 'asoaad', 'kawkabani'],
#  ['teresahmercedes', 'faoli', 'wuitrago'],
#  ['bearer', 'koviljon', 'boborajabog'],
#  ['satura'],
#  ['averline'],
#  ['newstead'],
#  ['guardian', 'jersey'],
#  ['aln', 'strengtpjltd'],
#  ['bagshaw'],
#  ['forstrua', 'groupwinc'],
#  ['karpatsi'],
#  ['wan', 'liaqm', 'he'],
#  ['decency', 'advisors'],
#  ['abacus'],
#  ['epic', 'electronics', 'limitqd'],
#  ['geng', 'ning'],
#  ['myojacob', 'perez'],
#  ['demarest'],
#  ['billingsley', 'alliance'],
#  ['andrea', 'paolo', 'bresolin'],
#  ['asia', 'mato', 'tejhnologies', 'ltc'],
#  ['pafnos'],
#  ['carelia'],
#  ['inner', 'gongolia', 'fuguang', 'food'],
#  ['chaucer', 'estates'],
#  ['nurgul', 'rasulova'],
#  ['jaim', 'aezelopment', 'enterpriszs', 'lc'],
#  ['charmeuse', 'incorporated'],
#  ['goldsun', 'incorporation'],
#  ['jetford'],
#  ['vadima', 'enc'],
#  ['viking', 'dynamics'],
#  ['arlesford'],
#  ['navin', 'mehra'],
#  ['sunnyrock'],
#  ['ariston', 'incorporated'],
#  ['durston'],
#  ['anthony', 'zammlt'],
#  ['eleteve', 'likieed'],
#  ['agri', 'partqiiternational', 'incorporated'],
#  ['suntown'],
#  ['meridian', 'partnership'],
#  ['jiy', 'ye', 'zk'],
#  ['lu', 'jian', 'fen'],
#  ['ieixiojg', 'ye'],
#  ['peach', 'blossdm'],
#  ['golden', 'cape'],
#  ['mm', 'concepts'],
#  ['anemone'],
#  ['bismarck', 'offshore'],
#  ['andrey', 'panagushin'],
#  ['mole', 'ovedseas'],
#  ['kevin', 'william', 'braddick'],
#  ['powerhkl', 'enterprines'],
#  ['archer'],
#  ['gautier', 'andr', 'louis', 'marechalgouee'],
#  ['huang', 'yihsuan'],
#  ['mary',
#   'justiniano',
#   'vda',
#   'guillemes',
#   'jose',
#   'emeterio',
#   'guillemes',
#   'justiniano',
#   'amparo',
#   'guillemes',
#   'justiniano',
#   'juan',
#   'carlos',
#   'guillemes',
#   'justiniano',
#   'joint',
#   'tenancy',
#   'with',
#   'right',
#   'survivorship'],
#  ['oakwood'],
#  ['miehail', 'mishcgenko'],
#  ['smile', 'ermibed'],
#  ['cece', 'grafitwerke'],
#  ['tang', 'xue', 'jiao'],
#  ['thyson'],
#  ['zhai', 'min'],
#  ['xarin', 'sachzev'],
#  ['mariana', 'andrea', 'alvarado', 'chacn'],
#  ['valtenor'],
#  ['fernando', 'bernardes', 'pinheiro'],
#  ['hm', 'bvilqlimityd'],
#  ['song', 'yong', 'sheng'],
#  ['interlink'],
#  ['laurita', 'karsten', 'weege'],
#  ['krakatoa'],
#  ['hynstar', 'iyvestmmnt'],
#  ['katran'],
#  ['moacyr', 'pessi'],
#  ['gonten', 'establishment'],
#  ['tam', 'marrie', 'han'],
#  ['isu', 'hudgschun'],
#  ['intco'],
#  ['kapik'],
#  ['mario', 'gmez', 'duque'],
#  ['godfrey'],
#  ['hotel', 'san', 'antonio', 'plc'],
#  ['macroplast'],
#  ['easthaugh'],
#  ['rupaul'],
#  ['sikhuti'],
#  ['rosebud', 'research'],
#  ['jorge', 'luis', 'takahashi', 'iguchi'],
#  ['oziris'],
#  ['alajeel'],
#  ['landmajk', 'manaqerent'],
#  ['andrie', 'doljitch'],
#  ['power', 'treasure', 'drading'],
#  ['pastorale'],
#  ['zhongyuat'],
#  ['moorfsnomineek'],
#  ['wai', 'chi'],
#  ['ubi'],
#  ['servicios', 'auditora', 'negocios', 'ltda'],
#  ['index', 'asia', 'pacimic'],
#  ['quanto', 'mabagemeat'],
#  ['park', 'misuk'],
#  ['cac', 'asesores'],
#  ['marc', 'gugerli'],
#  ['greensmone', 'propeeties'],
#  ['hassan', 'nasser', 'h', 'alnaimi'],
#  ['westhorpe'],
#  ['cirkumpola'],
#  ['yellow'],
#  ['huang', 'youmin'],
#  ['panayiotis', 'konaris'],
#  ['souyd', 'hong', 'kong'],
#  ['practical'],
#  ['hungarian', 'rdal', 'estnte'],
#  ['arundel'],
#  ['dastona', 'holdingz', 'eorp'],
#  ['beijing', 'hati', 'consultant'],
#  ['mohamed', 'salem', 'kardous', 'obaid', 'al', 'ameri'],
#  ['acsa'],
#  ['mayo', 'nominess'],
#  ['gennady', 'korenev'],
#  ['torriginda'],
#  ['cristina', 'aya', 'caro'],
#  ['oberon'],
#  ['multi', 'marketing'],
#  ['royal', 'internatidnao'],
#  ['corporate', 'directors'],
#  ['lui', 'pak', 'hoi'],
#  ['darazar', 'inco'],
#  ['ines', 'calmell', 'del', 'solar', 'del', 'rio'],
#  ['ian', 'david', 'fletchvr'],
#  ['fidelity', 'pat', 'maurice', 'brown', 'settlement'],
#  ['purplevest'],
#  ['solvent', 'xroap', 'ync'],
#  ['norlane'],
#  ['acklin', 'limitet'],
#  ['crystal', 'top'],
#  ['devas'],
#  ['baresdale'],
#  ['trade', 'pacific'],
#  ['houng', 'ying'],
#  ['traderoutes'],
#  ['perfumes', 'internacionales'],
#  ['jonquille', 'sla'],
#  ['parkgate'],
#  ['soreco', 'ivvestment', 'rnc'],
#  ['belvedere', 'administration'],
#  ['mirabaud', 'financial', 'planning', 'zurich', 'client'],
#  ['wsapeinternational', 'corporaaion'],
#  ['tanbark'],
#  ['snowberry', 'commercial'],
#  ['zilmak'],
#  ['urwich'],
#  ['chae', 'young', 'chong'],
#  ['frederick', 'taft'],
#  ['bay', 'tree', 'asset'],
#  ['blueriver'],
#  ['pearl', 'securities'],
#  ['pagripherzfinanze'],
#  ['sparrowtsecuiities'],
#  ['ems'],
#  ['luis', 'pircio', 'pupillf'],
#  ['beijing', 'voson', 'intl', 'ip', 'attorney'],
#  ['segg', 'asset'],
#  ['tercel'],
#  ['multi', 'crystal'],
#  ['kgrkat'],
#  ['orient', 'first'],
#  ['horizon', 'universal'],
#  ['eurotec', 'uk'],
#  ['platy'],
#  ['jiangfhaijun'],
#  ['larisa', 'trubetskaya'],
#  ['agencia', 'martima', 'mundomar'],
#  ['heartland'],
#  ['samsudin', 'bin', 'abu', 'hassan'],
#  ['magnhild', 'faleide', 'fristad'],
#  ['monh'],
#  ['night', 'heron'],
#  ['mcdonagh', 'brenden'],
#  ['qiyin'],
#  ['alpine', 'advisory'],
#  ['fabrice', 'vizl'],
#  ['westworld'],
#  ['highstage'],
#  ['sound', 'cheers'],
#  ['cezanne'],
#  ['alfredo', 'ovalle', 'rodrgrez'],
#  ['cui', 'jingtao'],
#  ['cornhill', 'ventures'],
#  ['bumkbilf'],
#  ['turnbridge'],
#  ['huang', 'hua', 'lan'],
#  ['uxbridge'],
#  ['lexmont'],
#  [],
#  ['george', 'christppoubos'],
#  ['irene', 'florencia', 'letss', 'colmenares', 'romaa'],
#  ['high', 'colt'],
#  ['brilliant', 'lighting', 'pte'],
#  ['fletcher'],
#  ['mokhtar', 'abou', 'basha'],
#  ['ma', 'xiao', 'fei'],
#  [],
#  ['wong', 'pik', 'lin', 'barbara'],
#  ['phoenis'],
#  ['powell'],
#  ['belfastscorpkration'],
#  ['ichi', 'dr', 'joe', 'corppration'],
#  ['sandra', 'anne', 'meadows'],
#  ['rufus', 'resourses'],
#  ['eastern', 'lake'],
#  ['tania', 'lucia', 'balta', 'mansilla'],
#  ['pennydale'],
#  ['orvell', 'estate'],
#  ['facoraf'],
#  ['etozir', 'asset'],
#  ['mscoy', 'assetsalimited'],
#  ['myron', 'pacific'],
#  ['arnoold', 'denes'],
#  ['huang', 'yuan', 'lx'],
#  ['top', 'china', 'strategy'],
#  ['thisledon'],
#  ['jelen'],
#  ['hermitage'],
#  ['michel', 'andre', 'oyharcabal'],
#  ['radiant'],
#  ['lotco'],
#  ['juan', 'nicolas', 'leao', 'leal'],
#  ['rivolta'],
#  ['gaud', 'grobal'],
#  ['wingfield'],
#  ['greater', 'beijing', 'regiongexpressways'],
#  ['nominee'],
#  ['bakner'],
#  ['kaslo'],
#  ['ellerton'],
#  ['robert', 'david', 'fuchs'],
#  ['chang', 'chia'],
#  ['baysan'],
#  ['wilian',
#   'raimundo',
#   'ferreira',
#   'egido',
#   'claudia',
#   'cristina',
#   'mateus',
#   'egido',
#   'marlon',
#   'mateus',
#   'egxdo',
#   'carlos',
#   'augusto',
#   'mateus',
#   'egido',
#   'joint',
#   'tenancy',
#   'wuth',
#   'right',
#   'survivorship'],
#  ['john', 'sturgeon'],
#  ['cheufang', 'chapg'],
#  ['procovest'],
#  ['panroc'],
#  ['tenison', 'likited'],
#  ['mujeres'],
#  ['curby'],
#  ['energy'],
#  ['copper', 'hill', 'ltdz'],
#  ['bassacs'],
#  ['bluebell', 'internataonal'],
#  ['mischositos', 'invesmment'],
#  ['kean', 'ahkmboo'],
#  ['brilliwnt', 'city', 'enterprisestltd'],
#  ['barwick'],
#  ['britannia', 'land'],
#  ['mirador', 'resources'],
#  ['dornberg'],
#  ['supreme', 'pohensinvestment'],
#  ['byrnestone'],
#  ['newflame'],
#  ['tsollaj', 'yung'],
#  ['mohammad', 'mansour', 'al', 'rumaih'],
#  ['mkc'],
#  ['african', 'agricultural', 'advisors'],
#  ['bisney', 'profits'],
#  ['albany'],
#  ['harry', 'pryomitro', 'simon'],
#  ['longville'],
#  ['smart', 'faith'],
#  ['ery', 'yunasri'],
#  ['molard'],
#  ['liu', 'xin', 'hua'],
#  ['maura', 'santiago', 'salles'],
#  ['radiance'],
#  ['fribel', 'alphil'],
#  ['master', 'nice'],
#  ['switch', 'financial'],
#  ['tihe', 'creation', 'sechnotogy'],
#  ['nadarioo', 'uimitid'],
#  ['ghi', 'yintai'],
#  ['springtide'],
#  ['solent'],
#  ['inversorm', 'meysson', 'uruguay'],
#  ['ying', 'liu'],
#  ['gefest'],
#  ['yin', 'ke'],
#  ['sapphire', 'equitirs', 'limitnd'],
#  ['smacas'],
#  ['tasso'],
#  ['sergey', 'shikhaleev'],
#  ['rosni', 'lis'],
#  ['xu', 'shu', 'fu'],
#  ['mezzola'],
#  ['acertis'],
#  ['nebadcyn'],
#  ['lama', 'petroleum'],
#  ['bader', 'f', 'mugayel'],
#  ['ebcny', 'saa'],
#  ['sunyview', 'lkmited'],
#  ['wilderspool', 'jersey'],
#  ['jose', 'lalo'],
#  ['flice'],
#  ['dalcam', 'businqss'],
#  ['bale'],
#  ['bagstock'],
#  ['dallain'],
#  ['mayton'],
#  ['wagnon'],
#  ['guyod'],
#  ['naugai', 'lbw', 'firm'],
#  ['evelenk', 'bianchi', 'y', 'bianchi'],
#  ['khang', 'yl', 'sheng'],
#  ['chan', 'suk', 'lingshirley'],
#  ['cao', 'wensheng'],
#  ['catherine', 'tsung'],
#  ['interworld'],
#  ['hampton'],
#  ['sergey', 'kupriyanov'],
#  ['cojbo', 'oa'],
#  ['roan', 'partners'],
#  ['hsieh', 'chin', 'lung'],
#  ['starpeak'],
#  ['cheng', 'kwli', 'chun', 'john'],
#  ['northern', 'minerals', 'partners'],
#  ['sino', 'sky', 'entrrprises'],
#  ['abu', 'bakr', 'abidlla', 'hadi', 'aheed', 'al', 'hussaini'],
#  ['clifton', 'sc'],
#  ['dzt'],
#  ['tarshaql', 'techgincorporated'],
#  ['guernsey', 'administrative'],
#  ['primb'],
#  ['kong', 'jun'],
#  ['tower', 'bridge'],
#  ['yaomchengzhi'],
#  ['bearef'],
#  ['litewell', 'industrial'],
#  ['beechleigh'],
#  ['he', 'mohammad', 'abdulla', 'ali', 'algergawi'],
#  ['jean', 'paul', 'van', 'den', 'brande'],
#  ['great', 'talent'],
#  ['tomas', 'otto', 'hanson'],
#  ['parklane', 'invostments', 'grour', 'limiyed'],
#  ['oswid', 'tervicesilimited'],
#  ['finisterre'],
#  ['danielixbay', 'fcundation'],
#  ['lqu', 'yur', 'sfng'],
#  ['dimitrios', 'papachristos'],
#  ['sierra', 'diamonds'],
#  ['budhichand', 'premchand', 'shah'],
#  ['picardy'],
#  ['feapearl', 'maritime', 'limised'],
#  ['zhou', 'sui', 'tong'],
#  ['quality', 'communication'],
#  ['pinktrol'],
#  ['victor', 'daniel', 'martin'],
#  ['corporativo', 'acr', 'cv'],
#  ['zhou', 'yi'],
#  ['sheringham', 'industries'],
#  ['yugraj'],
#  ['satsaco'],
#  ['coaaburn'],
#  ['alexander', 'nicholas'],
#  ['ahasia'],
#  ['zheng', 'zhixiao'],
#  ['heathev', 'jnan', 'nicholson'],
#  ['mary', 'mznir', 'ghobrial'],
#  ['promyliz'],
#  ['jitko'],
#  ['ctm'],
#  ['ang', 'intl'],
#  ['amwtde', 'manrgement'],
#  ['lin', 'ching', 'wei'],
#  ['rajesh', 'kumar', 'parmar'],
#  ['church', 'street', 'la', 'rochelle'],
#  ['projects', 'conqracts'],
#  ['rendmunl', 'marketing'],
#  ['fundacion', 'arien'],
#  ['mrsirita', 'lorenzi'],
#  ['elgahar', 'incr'],
#  ['radu', 'ciorba'],
#  ['yu', 'dezhang'],
#  ['cheng', 'cohholdfngs', 'sen', 'bhd'],
#  ['zhu', 'hong', 'yan'],
#  ['cassian', 'darcy', 'coquelle'],
#  ['cheung', 'kam', 'kwong'],
#  ['haili'],
#  ['buchovia'],
#  ['procos', 'worldwide'],
#  ['woodside'],
#  ['bridgford'],
#  ['europlan', 'no', '2'],
#  ['winley'],
#  ['ingredients'],
#  ['minor', 'chit', 'khim', 'richard'],
#  ['do', 'not', 'use', 'see', 'a122', 'acecroft'],
#  ['cristine', 'lto'],
#  ['leontino'],
#  ['strong', 'energy'],
#  ['charm'],
#  ['chin', 'chieh', 'shipping'],
#  ['ralter', 'izvest', 'ltk'],
#  ['mangh', 'shuvho'],
#  ['dolenin', 'ltdk'],
#  ['tam', 'po', 'ki'],
#  ['friendship'],
#  ['finortrust'],
#  ['xue', 'qun'],
#  ['royal', 'fiduciary', 're', 'aurora'],
#  ['atherfields'],
#  ['greater', 'zone'],
#  ['chadwych'],
#  ['abbeybridge'],
#  ['pengrove', 'licited', 'jly'],
#  ['huangbyi', 'cing'],
#  ['m3', 'madagascar'],
#  ['lu', 'hongfei'],
#  ['siti', 'nurbainy', 'akil', 'sahab'],
#  ['imagdnation', 'world', 'limlted'],
#  ['gordy', 'finanqecgroup', 'ja'],
#  ['elsey', 'commerce'],
#  ['horgen'],
#  ['bakkar'],
#  ['sinter'],
#  ['ernie', 'continental'],
#  ['jiang', 'hui'],
#  ['tax', 'ding'],
#  ['mourgue', 'd', 'algue', 'cie'],
#  ['benjamin', 'flournoy'],
#  ['qiankmin'],
#  ['mrqj', 'rnnemaker', 'llm'],
#  ['plink'],
#  ['manoranjana', 'dasgupta'],
#  ['eurofrasia'],
#  ['kormac'],
#  ['mercurio'],
#  ['ni', 'jun'],
#  ['oceanus'],
#  ['sunnybay', 'estates'],
#  ['sharp', 'idea'],
#  ['max', 'target'],
#  ['three', 'ventures', 'incorporated'],
#  ['leticia', 'panugayan'],
#  ['dou', 'mei'],
#  ['wellbred'],
#  ['madam', 'tam', 'ming', 'leun'],
#  ['wealthy', 'land'],
#  ['patson'],
#  ['scott', 'r', 'dvniels', 'deborah', 'daniels', 'jt', 'ten'],
#  ['vanair', 'shippingoinc'],
#  ['xin', 'yi'],
#  ['uniglobexconsultants'],
#  ['baviright', 'zyoup'],
#  ['feng', 'bin'],
#  ['silverdene'],
#  ['beauty', 'flame'],
#  ['chrysantal'],
#  ['caledonian', 'hallmark'],
#  ['marios', 'papadimas'],
#  ['ayv'],
#  ['techgart'],
#  ['success', 'new'],
#  ['greencastle'],
#  ['powerline'],
#  ['hsu', 'shen'],
#  ['angel', 'eecasnino'],
#  ['biofish', 'aquicultusa'],
#  ['yu', 'uhun', 'guang'],
#  ['liao', 'pichu'],
#  ['beaumont'],
#  ['premierynominecs'],
#  ['contec'],
#  ['interfield', 'sylutions'],
#  ['darius'],
#  ['gustavo', 'alberto', 'aquino', 'alfieri'],
#  ['adithya', 'kumar', 'poddar'],
#  ['vanluck'],
#  ['langford', 'invesf'],
#  ['christie'],
#  ['dr', 'kapranmkamal'],
#  ['hhiyn', 'chihming'],
#  ['nicole', 'f', 'blancbrude', 'andor', 'alain', 'blancbrude'],
#  ['luo', 'wenching'],
#  ['igor', 'flasz'],
#  ['anj', '1996', 'limated'],
#  ['acra'],
#  ['monica', 'rodriguez'],
#  ['jatkoesalimited'],
#  ['tammwai', 'ying'],
#  ['laxsnt', 'sam'],
#  ['bao'],
#  ['campus'],
#  ['barnt', 'spring'],
#  ['ztaxhill'],
#  ['trenton', 'invzrtment', 'ttd'],
#  ['1868', 'enterprise'],
#  ['michael', 'alter', 'kushnir'],
#  ['dfp'],
#  ['corpoqate'],
#  ['arafah', 'bint', 'ali', 'bin', 'mussallam'],
#  ['polytimi', 'manintqs'],
#  ['edgar', 'rene', 'ciceron', 'puyol', 'perdomo'],
#  ['nicole', 'didi'],
#  ['european'],
#  ['park', 'young', 'soo'],
#  ['rpm', 'systems'],
#  ['riselark', 'jentures'],
#  ['industrial', 'plant', 'design'],
#  ['sherlock', 'burns'],
#  ['winyoung'],
#  ['china', 'joyce', 'limiyed'],
#  ['filip', 'olqa', 'jacek'],
#  ['planet', 'solution'],
#  ['arius'],
#  ['tarantella', 'securities'],
#  ['secomd', 'court', 'limnted'],
#  ['luis', 'alberto', 'dimnik'],
#  ['carlos', 'enrique', 'larios', 'cueloar'],
#  ['fragrance', 'perfumes', 'o', 'cosmevicos', 'cosp'],
#  ['virgen', 'nutrition'],
#  ['allied', 'success', 'hk'],
#  ['wingo', 'managemeag'],
#  ['pearce', 'hughes', 'aoife', 'hughes'],
#  ['pls', 'cwd'],
#  ['marco', 'montis'],
#  ['redxmocn', 'deveropment'],
#  ['quindale'],
#  ['tang', 'meichun'],
#  ['marlon', 'aviation'],
#  ['comercio', 'interamericano'],
#  ['millican'],
#  ['lockstone'],
#  ['fundacin', 'nissim'],
#  ['diverse', 'consultancy'],
#  ['hallmark'],
#  ['abdullah', 'hamad', 'alrsagrr', 'brothers'],
#  ['sunflower'],
#  ['joao', 'edward', 'vaz', 'maia'],
#  ['gobeli', 'doll', 'christel'],
#  ['glass', 'plus', 'industries'],
#  ['dominic', 'john', 'coubeck'],
#  ['victoria', 'saiidas', 'calvo'],
#  ['aubola', 'raphael', 'oluyede'],
#  ['morehead', 'incorporated'],
#  ['erchi', 'investmont'],
#  ['camden', 'tkchnology', 'limqted'],
#  ['spacecode', 'ventures'],
#  ['wilson', 'offshore', 'bvi'],
#  ['luizaumaripni'],
#  ['harvest', 'fortune'],
#  ['aiyana'],
#  ['regency'],
#  ['sergio', 'alejandro', 'koreybvit'],
#  ['tamarin'],
#  ['buchanan'],
#  ['ellabad', 'fondation'],
#  ['jtc', 'suisse', 'velmi'],
#  ['quayla', 'investmengs', 'tzust'],
#  ['min', 'xuan'],
#  ['gca', 'information'],
#  ['genesis', 'exports'],
#  ['d', 'd'],
#  ['celtic'],
#  ['wcn'],
#  ['kai'],
#  ['gzorious', 'billion', 'develnpment'],
#  ['rayville'],
#  ['lu', 'minghui'],
#  ['polysjates', 'internftionrl'],
#  ['hoarding', 'aahu'],
#  ['tamaz', 'jakhutashvili'],
#  ['layton', 'ventures'],
#  ['c', 'jerrett'],
#  ['yang', 'wen', 'tao'],
#  ...]

# %%
[ ' '.join(x) for x in cleaned_col]
# Out:
# ['mo yuling',
#  'hermes fz lle monaco',
#  'deerfield',
#  'sidney frankel',
#  'freshlolkarmrltd',
#  'pricewaterhouse coopers malta',
#  'solby',
#  'chang min seok',
#  'tsax wuli',
#  'peter colaco',
#  'leisure',
#  'dencourt',
#  'fotlock',
#  'jiang qiang',
#  'whemoton scyprusglimited',
#  'east dawn sen',
#  'savas oil',
#  'amerwell',
#  'sinocom ideas lizitkd',
#  'rivaldi',
#  'ventura propertieb',
#  'natron',
#  'virtus trustess hayward family 1993 settlement',
#  'primeline',
#  'canal tryst companywlimitld',
#  'invest portfolio',
#  'mrpetergschopt',
#  'edmundo david tefel pasos',
#  'crinam',
#  'dazzle',
#  'furnidec',
#  'dblmaixe limided',
#  'ellenton atd',
#  'utrition',
#  'hearnville',
#  'nilo consultores sas',
#  'piat',
#  'fund',
#  'montis',
#  'geron pozov',
#  'gloria',
#  'francisco ortiz von bismarck',
#  'newmarket traders',
#  'tristan energy',
#  'chu ah kiew',
#  'ikroy',
#  'tomsun',
#  'palmdella',
#  'paula andrea osorio muoz',
#  'denvale incorporated',
#  'sigesky sav',
#  'peace afd serenity limsved',
#  'christopher anthony castelloe kathleen costelloe jointly with right qurvivorship',
#  'apson',
#  'liu lfng',
#  'tyliam',
#  'eriton',
#  'wenqiao',
#  'cafate',
#  'glory champion holdinqscltd',
#  'joaquin ziaedurn',
#  'selectron members',
#  'taiwan tunes inl',
#  'ambert',
#  'millside',
#  'forest ggpen howdings',
#  'zandeleigh',
#  'peravro',
#  'amphios',
#  'hedsham',
#  'pebble',
#  'roberi newmin',
#  'you wei',
#  'avel gonzalez',
#  'zng bvi',
#  'ferrrtti',
#  'malina',
#  'ralph gore watson',
#  'sunvjle',
#  'akron',
#  'bondex logistics',
#  'lupus',
#  'piru',
#  'jc paemkum lwd',
#  'wings',
#  'monthrie nssociatws',
#  'leymer',
#  'lidena intergroup',
#  'canadian phoperties',
#  'compagnie financiere et fonciere',
#  'utiglobe secukities',
#  'asil',
#  'citco trusteys bvi creative vysta',
#  'wu yuanlin',
#  'metchem engineering',
#  'forest industries',
#  'belen velutini',
#  'sergev zuixstv',
#  'gold come',
#  'wincqester',
#  'ya xiaolong',
#  'joasma',
#  'petr skovotodko',
#  'transit technologies',
#  'zona impex',
#  'gold rush',
#  'patrizia poggi',
#  'jabar',
#  'ehab osman khalil',
#  'rheindeer',
#  'key line pamific eimited',
#  'carlos carvalho crespo',
#  'bickerton',
#  'goxden garewao',
#  'regiu compavy',
#  'victor sukmanov',
#  'facai',
#  'advanlinksinvestment utd',
#  'edward meja',
#  'musa',
#  'intercoa',
#  'design away',
#  'baker industries',
#  'renyard',
#  'artisti',
#  'multicare pharma',
#  'comblowx investmentd',
#  'jerome',
#  'bartlou limqeed',
#  'suliman dockrat',
#  'bikler',
#  'leonia',
#  'liu zinghsien',
#  'jianwei',
#  'apic ap119',
#  'berrima',
#  'perth pkoperties',
#  'willamett enterprise',
#  'parkhouse',
#  'carrolabd industries',
#  'nominest',
#  'petcon borneo',
#  'ccs corporate',
#  'jefny del consuelo jimenez asanza',
#  'alarion',
#  'intergirasol jm',
#  'roisine',
#  'depec technologies',
#  'han hong jun',
#  'david adamson hirst',
#  'voorma hannie',
#  'invernada',
#  'owsley marketingxcorp',
#  'vintage',
#  'vitamax',
#  'shao changshi',
#  'white raven',
#  'huang ping',
#  'corporate agents bvi silver mine',
#  'albion fvnanciab',
#  'bakkari',
#  'maxwall invest',
#  'bearej share',
#  'inprover',
#  'harvest aspect',
#  'thetie marite',
#  'alderson',
#  'zarnol',
#  'libshqq',
#  'artviewwgrhuc',
#  'asialeesources',
#  'pergola partners',
#  'marwan r frem',
#  'kambo securidy products',
#  'buwan marketing',
#  'personal trainer institute',
#  'overlea',
#  'borrowdale',
#  'delphisuconsultkng',
#  'xiaocong qiu',
#  'awad ammora',
#  'rodney glyndwr james thea van eupen james dominic anthony oneil jointly',
#  'trenton',
#  'lexington computer',
#  'furantall',
#  'chienchou',
#  'roussellelimiten',
#  'zenith marketing',
#  'tao wenchieh',
#  'lankom',
#  'zonea liiitxd',
#  'jade port technologyhltdo',
#  'andreytrogachev',
#  'james john zuehlen',
#  'elena gemeliari',
#  'gao guargpi',
#  'juan pndro damiani',
#  'finsbury',
#  'rr seref dogan erbek',
#  'roblrto pocaterma',
#  'powell estate',
#  'hitectebcom',
#  'runshine businessqaac',
#  'valarie jean ward',
#  'pin',
#  'rpptman ooman',
#  'jtc securities',
#  'yong hong wei',
#  'rantiagoqgombz',
#  'juniper',
#  'jlannie chungyingpaiu',
#  'lukyanchuk yury',
#  'carlyle limiteo',
#  'rexford',
#  'crown fair',
#  'knight star',
#  'ignacio agustin kassis manzur',
#  'quantic oil offshore',
#  'zhu ping',
#  'reflex',
#  'satabco',
#  'grand world',
#  'ukr',
#  'pw corpoeation',
#  'diego alfie gonzlez',
#  'semita',
#  'andrey ruzheynikov',
#  'zhangvjiyang',
#  'stelmar daimonds xtd',
#  'gladstone lwasinv',
#  'lo hiu fai johnny',
#  'curaldo',
#  'keasn fialko',
#  'hancker',
#  'haymend',
#  'alfred aspen',
#  'laurent nheypitet',
#  'vistrade engineering',
#  'joyce harvest',
#  'exclusive wotldwide likited',
#  'vigilax',
#  'north atlantic secretaries',
#  'hartsdale nv',
#  'persephone',
#  'la atlantida',
#  'pranor',
#  'grand chinp',
#  'glanford foundrtioy',
#  'lai lungchin',
#  'happy rise',
#  'lawngrove',
#  'denver',
#  'orino',
#  'orient future',
#  'enoc',
#  'imperial',
#  'suite1r cunbeblvnd',
#  'jian qiang',
#  'kenneth chin su sian',
#  'malshost lymited',
#  'intercare',
#  'purple hoydingq llc',
#  'lisle',
#  'iap ag',
#  'soonhee hinrichs',
#  'lancelot',
#  'law yuk ling',
#  'kleinwort benson guernsey n c robins p le poidevin re g baron',
#  'paxton financial',
#  'tenon iom',
#  'cristalmar',
#  'paneast',
#  'clearwater yachtf',
#  'natalia melikhova',
#  'sunora',
#  'dugminhvng',
#  'ningyudn',
#  'dalex alliance',
#  'thalassa swa',
#  'crosskeys',
#  'caravel projects',
#  'pinama sun dried mnc',
#  'leisure products',
#  'han qing',
#  'damor',
#  'querrin shipping',
#  'lam sim kuen',
#  'jeroda promotion',
#  'bush ac',
#  'charterhyuse',
#  'nyon worldwide',
#  'sonic connect limitek',
#  'yellow light',
#  'yew green',
#  'james h hafterson',
#  'bereficence fowndaticn',
#  'georg staeheli',
#  'javie kendraxlai sook chiuem',
#  'ornsay residency uk',
#  'cheer ascent',
#  'karaboon',
#  'zahida dero',
#  'swan',
#  'hseyin ayduk esat koray',
#  'dxb',
#  'detris intefnawional coqp',
#  'matura',
#  'baldaquin',
#  'hansa maritime',
#  'lynus',
#  'new shobe finanoe',
#  'sirgronald girierson',
#  'internabional businegs commercial',
#  'fenera',
#  'holenstein rechtsanwlte',
#  'ringo star',
#  'beijing dragon resources',
#  'weldin',
#  'ontech',
#  'zhang sen qi',
#  'joseeluis bruzgond',
#  'gui chun',
#  'kryn holdinhs',
#  'silos bonniere',
#  'wangnang',
#  'her chan',
#  'union tiger',
#  'patricia mesa',
#  'keen wise',
#  'wyman',
#  'arctilana',
#  'estudio juridico ortega moreira ortega trwjillo abogados',
#  'cees baas',
#  'eastqrn aqcessoqies',
#  'wt',
#  'buxter associatfs',
#  'carolyue duncombe robinson',
#  'omega',
#  'imiying eleccronics',
#  'elena nikolayevna shipitsyna',
#  'stantrade',
#  'big world',
#  'mandarin traxing limiteh',
#  'gaosxiang',
#  'denis kropotkin',
#  'carena inzernational covp',
#  'prodectors limiten',
#  'maeve',
#  'equity bahamas',
#  'trent vale',
#  'ryedale',
#  'nek',
#  'ultimatetm organisation llc',
#  'marcos alberto labaton',
#  'zhao siyuan',
#  'sumesh rajgopal',
#  'oldroy',
#  'oriental',
#  'oldwick litited',
#  'azamat babmjkhanbetov',
#  'sharington',
#  'fairview',
#  'taporley',
#  'sheridan',
#  'abdul kayum',
#  'uniped prosper enserpriwe',
#  'huang guoyu',
#  'kenway technologies',
#  'best resources managers',
#  'mindmotion microelectrondck ltm',
#  'claudie degchamps',
#  'cheer point',
#  'stpdie scgt',
#  'velsen',
#  'wenhsiang',
#  'zhao jing',
#  'neofantastic fashions',
#  'verug holdgng incf',
#  'kenner',
#  'silvejlock',
#  'arco',
#  'monte cristo captial',
#  'mohammed nizar alnakeeb',
#  'briardjle limitee',
#  'filament',
#  'corvest invlstmezts',
#  'valroy',
#  'fouad el imam',
#  'majed sulaiman al nafie',
#  'kang shaokui',
#  'garfinkel simon',
#  'dulwich',
#  'juan oswaldo ywnelli aguirrh',
#  'novaglobus',
#  'westland',
#  'ms bassil yasmeen elieqmalip',
#  'ocean treasure',
#  'montserrat developments',
#  'high court',
#  'auxiliadora febres cordero cordovez',
#  'colorado compaly equiyies',
#  'lu weidong',
#  'gong yishu',
#  'zhuang yonysheng',
#  'mohamad tahsine el khayat',
#  'worldwise',
#  'kestrel',
#  'mossack fonseca per',
#  'robinaalvarez',
#  'vinayak',
#  'gwrtonville limiled',
#  'k11 partners',
#  'dominion',
#  'b24 marquisconsultadoria e servicos lda',
#  'perosa',
#  'avgousta svoronou',
#  'kathleen tynan',
#  'scysee',
#  'paddock crediyz',
#  'lebowitz chedva',
#  'castle hill',
#  'komustrade',
#  'mrsd aida asoaad kawkabani',
#  'teresahmercedes faoli wuitrago',
#  'bearer koviljon boborajabog',
#  'satura',
#  'averline',
#  'newstead',
#  'guardian jersey',
#  'aln strengtpjltd',
#  'bagshaw',
#  'forstrua groupwinc',
#  'karpatsi',
#  'wan liaqm he',
#  'decency advisors',
#  'abacus',
#  'epic electronics limitqd',
#  'geng ning',
#  'myojacob perez',
#  'demarest',
#  'billingsley alliance',
#  'andrea paolo bresolin',
#  'asia mato tejhnologies ltc',
#  'pafnos',
#  'carelia',
#  'inner gongolia fuguang food',
#  'chaucer estates',
#  'nurgul rasulova',
#  'jaim aezelopment enterpriszs lc',
#  'charmeuse incorporated',
#  'goldsun incorporation',
#  'jetford',
#  'vadima enc',
#  'viking dynamics',
#  'arlesford',
#  'navin mehra',
#  'sunnyrock',
#  'ariston incorporated',
#  'durston',
#  'anthony zammlt',
#  'eleteve likieed',
#  'agri partqiiternational incorporated',
#  'suntown',
#  'meridian partnership',
#  'jiy ye zk',
#  'lu jian fen',
#  'ieixiojg ye',
#  'peach blossdm',
#  'golden cape',
#  'mm concepts',
#  'anemone',
#  'bismarck offshore',
#  'andrey panagushin',
#  'mole ovedseas',
#  'kevin william braddick',
#  'powerhkl enterprines',
#  'archer',
#  'gautier andr louis marechalgouee',
#  'huang yihsuan',
#  'mary justiniano vda guillemes jose emeterio guillemes justiniano amparo guillemes justiniano juan carlos guillemes justiniano joint tenancy with right survivorship',
#  'oakwood',
#  'miehail mishcgenko',
#  'smile ermibed',
#  'cece grafitwerke',
#  'tang xue jiao',
#  'thyson',
#  'zhai min',
#  'xarin sachzev',
#  'mariana andrea alvarado chacn',
#  'valtenor',
#  'fernando bernardes pinheiro',
#  'hm bvilqlimityd',
#  'song yong sheng',
#  'interlink',
#  'laurita karsten weege',
#  'krakatoa',
#  'hynstar iyvestmmnt',
#  'katran',
#  'moacyr pessi',
#  'gonten establishment',
#  'tam marrie han',
#  'isu hudgschun',
#  'intco',
#  'kapik',
#  'mario gmez duque',
#  'godfrey',
#  'hotel san antonio plc',
#  'macroplast',
#  'easthaugh',
#  'rupaul',
#  'sikhuti',
#  'rosebud research',
#  'jorge luis takahashi iguchi',
#  'oziris',
#  'alajeel',
#  'landmajk manaqerent',
#  'andrie doljitch',
#  'power treasure drading',
#  'pastorale',
#  'zhongyuat',
#  'moorfsnomineek',
#  'wai chi',
#  'ubi',
#  'servicios auditora negocios ltda',
#  'index asia pacimic',
#  'quanto mabagemeat',
#  'park misuk',
#  'cac asesores',
#  'marc gugerli',
#  'greensmone propeeties',
#  'hassan nasser h alnaimi',
#  'westhorpe',
#  'cirkumpola',
#  'yellow',
#  'huang youmin',
#  'panayiotis konaris',
#  'souyd hong kong',
#  'practical',
#  'hungarian rdal estnte',
#  'arundel',
#  'dastona holdingz eorp',
#  'beijing hati consultant',
#  'mohamed salem kardous obaid al ameri',
#  'acsa',
#  'mayo nominess',
#  'gennady korenev',
#  'torriginda',
#  'cristina aya caro',
#  'oberon',
#  'multi marketing',
#  'royal internatidnao',
#  'corporate directors',
#  'lui pak hoi',
#  'darazar inco',
#  'ines calmell del solar del rio',
#  'ian david fletchvr',
#  'fidelity pat maurice brown settlement',
#  'purplevest',
#  'solvent xroap ync',
#  'norlane',
#  'acklin limitet',
#  'crystal top',
#  'devas',
#  'baresdale',
#  'trade pacific',
#  'houng ying',
#  'traderoutes',
#  'perfumes internacionales',
#  'jonquille sla',
#  'parkgate',
#  'soreco ivvestment rnc',
#  'belvedere administration',
#  'mirabaud financial planning zurich client',
#  'wsapeinternational corporaaion',
#  'tanbark',
#  'snowberry commercial',
#  'zilmak',
#  'urwich',
#  'chae young chong',
#  'frederick taft',
#  'bay tree asset',
#  'blueriver',
#  'pearl securities',
#  'pagripherzfinanze',
#  'sparrowtsecuiities',
#  'ems',
#  'luis pircio pupillf',
#  'beijing voson intl ip attorney',
#  'segg asset',
#  'tercel',
#  'multi crystal',
#  'kgrkat',
#  'orient first',
#  'horizon universal',
#  'eurotec uk',
#  'platy',
#  'jiangfhaijun',
#  'larisa trubetskaya',
#  'agencia martima mundomar',
#  'heartland',
#  'samsudin bin abu hassan',
#  'magnhild faleide fristad',
#  'monh',
#  'night heron',
#  'mcdonagh brenden',
#  'qiyin',
#  'alpine advisory',
#  'fabrice vizl',
#  'westworld',
#  'highstage',
#  'sound cheers',
#  'cezanne',
#  'alfredo ovalle rodrgrez',
#  'cui jingtao',
#  'cornhill ventures',
#  'bumkbilf',
#  'turnbridge',
#  'huang hua lan',
#  'uxbridge',
#  'lexmont',
#  '',
#  'george christppoubos',
#  'irene florencia letss colmenares romaa',
#  'high colt',
#  'brilliant lighting pte',
#  'fletcher',
#  'mokhtar abou basha',
#  'ma xiao fei',
#  '',
#  'wong pik lin barbara',
#  'phoenis',
#  'powell',
#  'belfastscorpkration',
#  'ichi dr joe corppration',
#  'sandra anne meadows',
#  'rufus resourses',
#  'eastern lake',
#  'tania lucia balta mansilla',
#  'pennydale',
#  'orvell estate',
#  'facoraf',
#  'etozir asset',
#  'mscoy assetsalimited',
#  'myron pacific',
#  'arnoold denes',
#  'huang yuan lx',
#  'top china strategy',
#  'thisledon',
#  'jelen',
#  'hermitage',
#  'michel andre oyharcabal',
#  'radiant',
#  'lotco',
#  'juan nicolas leao leal',
#  'rivolta',
#  'gaud grobal',
#  'wingfield',
#  'greater beijing regiongexpressways',
#  'nominee',
#  'bakner',
#  'kaslo',
#  'ellerton',
#  'robert david fuchs',
#  'chang chia',
#  'baysan',
#  'wilian raimundo ferreira egido claudia cristina mateus egido marlon mateus egxdo carlos augusto mateus egido joint tenancy wuth right survivorship',
#  'john sturgeon',
#  'cheufang chapg',
#  'procovest',
#  'panroc',
#  'tenison likited',
#  'mujeres',
#  'curby',
#  'energy',
#  'copper hill ltdz',
#  'bassacs',
#  'bluebell internataonal',
#  'mischositos invesmment',
#  'kean ahkmboo',
#  'brilliwnt city enterprisestltd',
#  'barwick',
#  'britannia land',
#  'mirador resources',
#  'dornberg',
#  'supreme pohensinvestment',
#  'byrnestone',
#  'newflame',
#  'tsollaj yung',
#  'mohammad mansour al rumaih',
#  'mkc',
#  'african agricultural advisors',
#  'bisney profits',
#  'albany',
#  'harry pryomitro simon',
#  'longville',
#  'smart faith',
#  'ery yunasri',
#  'molard',
#  'liu xin hua',
#  'maura santiago salles',
#  'radiance',
#  'fribel alphil',
#  'master nice',
#  'switch financial',
#  'tihe creation sechnotogy',
#  'nadarioo uimitid',
#  'ghi yintai',
#  'springtide',
#  'solent',
#  'inversorm meysson uruguay',
#  'ying liu',
#  'gefest',
#  'yin ke',
#  'sapphire equitirs limitnd',
#  'smacas',
#  'tasso',
#  'sergey shikhaleev',
#  'rosni lis',
#  'xu shu fu',
#  'mezzola',
#  'acertis',
#  'nebadcyn',
#  'lama petroleum',
#  'bader f mugayel',
#  'ebcny saa',
#  'sunyview lkmited',
#  'wilderspool jersey',
#  'jose lalo',
#  'flice',
#  'dalcam businqss',
#  'bale',
#  'bagstock',
#  'dallain',
#  'mayton',
#  'wagnon',
#  'guyod',
#  'naugai lbw firm',
#  'evelenk bianchi y bianchi',
#  'khang yl sheng',
#  'chan suk lingshirley',
#  'cao wensheng',
#  'catherine tsung',
#  'interworld',
#  'hampton',
#  'sergey kupriyanov',
#  'cojbo oa',
#  'roan partners',
#  'hsieh chin lung',
#  'starpeak',
#  'cheng kwli chun john',
#  'northern minerals partners',
#  'sino sky entrrprises',
#  'abu bakr abidlla hadi aheed al hussaini',
#  'clifton sc',
#  'dzt',
#  'tarshaql techgincorporated',
#  'guernsey administrative',
#  'primb',
#  'kong jun',
#  'tower bridge',
#  'yaomchengzhi',
#  'bearef',
#  'litewell industrial',
#  'beechleigh',
#  'he mohammad abdulla ali algergawi',
#  'jean paul van den brande',
#  'great talent',
#  'tomas otto hanson',
#  'parklane invostments grour limiyed',
#  'oswid tervicesilimited',
#  'finisterre',
#  'danielixbay fcundation',
#  'lqu yur sfng',
#  'dimitrios papachristos',
#  'sierra diamonds',
#  'budhichand premchand shah',
#  'picardy',
#  'feapearl maritime limised',
#  'zhou sui tong',
#  'quality communication',
#  'pinktrol',
#  'victor daniel martin',
#  'corporativo acr cv',
#  'zhou yi',
#  'sheringham industries',
#  'yugraj',
#  'satsaco',
#  'coaaburn',
#  'alexander nicholas',
#  'ahasia',
#  'zheng zhixiao',
#  'heathev jnan nicholson',
#  'mary mznir ghobrial',
#  'promyliz',
#  'jitko',
#  'ctm',
#  'ang intl',
#  'amwtde manrgement',
#  'lin ching wei',
#  'rajesh kumar parmar',
#  'church street la rochelle',
#  'projects conqracts',
#  'rendmunl marketing',
#  'fundacion arien',
#  'mrsirita lorenzi',
#  'elgahar incr',
#  'radu ciorba',
#  'yu dezhang',
#  'cheng cohholdfngs sen bhd',
#  'zhu hong yan',
#  'cassian darcy coquelle',
#  'cheung kam kwong',
#  'haili',
#  'buchovia',
#  'procos worldwide',
#  'woodside',
#  'bridgford',
#  'europlan no 2',
#  'winley',
#  'ingredients',
#  'minor chit khim richard',
#  'do not use see a122 acecroft',
#  'cristine lto',
#  'leontino',
#  'strong energy',
#  'charm',
#  'chin chieh shipping',
#  'ralter izvest ltk',
#  'mangh shuvho',
#  'dolenin ltdk',
#  'tam po ki',
#  'friendship',
#  'finortrust',
#  'xue qun',
#  'royal fiduciary re aurora',
#  'atherfields',
#  'greater zone',
#  'chadwych',
#  'abbeybridge',
#  'pengrove licited jly',
#  'huangbyi cing',
#  'm3 madagascar',
#  'lu hongfei',
#  'siti nurbainy akil sahab',
#  'imagdnation world limlted',
#  'gordy finanqecgroup ja',
#  'elsey commerce',
#  'horgen',
#  'bakkar',
#  'sinter',
#  'ernie continental',
#  'jiang hui',
#  'tax ding',
#  'mourgue d algue cie',
#  'benjamin flournoy',
#  'qiankmin',
#  'mrqj rnnemaker llm',
#  'plink',
#  'manoranjana dasgupta',
#  'eurofrasia',
#  'kormac',
#  'mercurio',
#  'ni jun',
#  'oceanus',
#  'sunnybay estates',
#  'sharp idea',
#  'max target',
#  'three ventures incorporated',
#  'leticia panugayan',
#  'dou mei',
#  'wellbred',
#  'madam tam ming leun',
#  'wealthy land',
#  'patson',
#  'scott r dvniels deborah daniels jt ten',
#  'vanair shippingoinc',
#  'xin yi',
#  'uniglobexconsultants',
#  'baviright zyoup',
#  'feng bin',
#  'silverdene',
#  'beauty flame',
#  'chrysantal',
#  'caledonian hallmark',
#  'marios papadimas',
#  'ayv',
#  'techgart',
#  'success new',
#  'greencastle',
#  'powerline',
#  'hsu shen',
#  'angel eecasnino',
#  'biofish aquicultusa',
#  'yu uhun guang',
#  'liao pichu',
#  'beaumont',
#  'premierynominecs',
#  'contec',
#  'interfield sylutions',
#  'darius',
#  'gustavo alberto aquino alfieri',
#  'adithya kumar poddar',
#  'vanluck',
#  'langford invesf',
#  'christie',
#  'dr kapranmkamal',
#  'hhiyn chihming',
#  'nicole f blancbrude andor alain blancbrude',
#  'luo wenching',
#  'igor flasz',
#  'anj 1996 limated',
#  'acra',
#  'monica rodriguez',
#  'jatkoesalimited',
#  'tammwai ying',
#  'laxsnt sam',
#  'bao',
#  'campus',
#  'barnt spring',
#  'ztaxhill',
#  'trenton invzrtment ttd',
#  '1868 enterprise',
#  'michael alter kushnir',
#  'dfp',
#  'corpoqate',
#  'arafah bint ali bin mussallam',
#  'polytimi manintqs',
#  'edgar rene ciceron puyol perdomo',
#  'nicole didi',
#  'european',
#  'park young soo',
#  'rpm systems',
#  'riselark jentures',
#  'industrial plant design',
#  'sherlock burns',
#  'winyoung',
#  'china joyce limiyed',
#  'filip olqa jacek',
#  'planet solution',
#  'arius',
#  'tarantella securities',
#  'secomd court limnted',
#  'luis alberto dimnik',
#  'carlos enrique larios cueloar',
#  'fragrance perfumes o cosmevicos cosp',
#  'virgen nutrition',
#  'allied success hk',
#  'wingo managemeag',
#  'pearce hughes aoife hughes',
#  'pls cwd',
#  'marco montis',
#  'redxmocn deveropment',
#  'quindale',
#  'tang meichun',
#  'marlon aviation',
#  'comercio interamericano',
#  'millican',
#  'lockstone',
#  'fundacin nissim',
#  'diverse consultancy',
#  'hallmark',
#  'abdullah hamad alrsagrr brothers',
#  'sunflower',
#  'joao edward vaz maia',
#  'gobeli doll christel',
#  'glass plus industries',
#  'dominic john coubeck',
#  'victoria saiidas calvo',
#  'aubola raphael oluyede',
#  'morehead incorporated',
#  'erchi investmont',
#  'camden tkchnology limqted',
#  'spacecode ventures',
#  'wilson offshore bvi',
#  'luizaumaripni',
#  'harvest fortune',
#  'aiyana',
#  'regency',
#  'sergio alejandro koreybvit',
#  'tamarin',
#  'buchanan',
#  'ellabad fondation',
#  'jtc suisse velmi',
#  'quayla investmengs tzust',
#  'min xuan',
#  'gca information',
#  'genesis exports',
#  'd d',
#  'celtic',
#  'wcn',
#  'kai',
#  'gzorious billion develnpment',
#  'rayville',
#  'lu minghui',
#  'polysjates internftionrl',
#  'hoarding aahu',
#  'tamaz jakhutashvili',
#  'layton ventures',
#  'c jerrett',
#  'yang wen tao',
#  ...]

# %%
def ngrams(string, n=2):
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower() #make lower case
    string = string.translate(str.maketrans('', '', string_lib.punctuation)) # remove punctuation
    chars_to_remove = [")","(",".","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string) #remove the list of chars defined above
    string = string.replace('&', ' ')
    string = string.replace(',', ' ')
    string = string.replace('-', ' ')
    string = string.title() # normalise case - capital at start of each word
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single space
    string = ' '+ string +' ' # pad names for ngrams...
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
ngrams('NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.')
# Out:
# [' N',
#  'Ni',
#  'in',
#  'ng',
#  'gb',
#  'bo',
#  'o ',
#  ' S',
#  'Su',
#  'un',
#  'nr',
#  'ri',
#  'is',
#  'se',
#  'e ',
#  ' E',
#  'En',
#  'nt',
#  'te',
#  'er',
#  'rp',
#  'pr',
#  'ri',
#  'is',
#  'se',
#  'es',
#  's ',
#  ' U',
#  'Un',
#  'ni',
#  'it',
#  'te',
#  'ed',
#  'd ',
#  ' C',
#  'Co',
#  'o ',
#  ' L',
#  'Lt',
#  'td',
#  'd ']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
org_names = list(df_train['name'])

# %%
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(org_names)

# %%
tf_idf_matrix.shape[1]
# Out:
# 2045

# %%
cos_sim = sim.cosine(tf_idf_matrix, tf_idf_matrix.T, k = 300)
# Out:
#   0%|          | 0/333070 [00:00<?, ?it/s]
#
#
# Preprocessing:   0%|          | 0/333070 [00:00<?, ?it/s]
#
#
# Allocate memory per threads:   0%|          | 0/333070 [00:00<?, ?it/s]
#
#
# Computing:   0%|          | 666/333070 [00:03<28:03, 197.40it/s]
#
#
# Computing:   0%|          | 1332/333070 [00:06<25:01, 220.97it/s]
#
#
# Computing:   1%|          | 1998/333070 [00:09<25:32, 216.01it/s]
#
#
# Computing:   1%|          | 2664/333070 [00:12<25:30, 215.92it/s]
#
#
# Computing:   1%|          | 3330/333070 [00:14<24:43, 222.21it/s]
#
#
# Computing:   1%|          | 3996/333070 [00:17<24:03, 228.02it/s]
#
#
# Computing:   1%|▏         | 4662/333070 [00:20<23:35, 231.93it/s]
#
#
# Computing:   2%|▏         | 5328/333070 [00:23<23:44, 230.03it/s]
#
#
# Computing:   2%|▏         | 5994/333070 [00:25<23:09, 235.34it/s]
#
#
# Computing:   2%|▏         | 6660/333070 [00:27<22:38, 240.21it/s]
#
#
# Computing:   2%|▏         | 7326/333070 [00:30<22:14, 244.12it/s]
#
#
# Computing:   2%|▏         | 7992/333070 [00:32<21:58, 246.64it/s]
#
#
# Computing:   3%|▎         | 8658/333070 [00:34<21:35, 250.41it/s]
#
#
# Computing:   3%|▎         | 9324/333070 [00:36<21:14, 254.07it/s]
#
#
# Computing:   3%|▎         | 9991/333070 [00:38<20:57, 256.90it/s]
#
#
# Computing:   3%|▎         | 10656/333070 [00:41<20:50, 257.89it/s]
#
#
# Computing:   3%|▎         | 11322/333070 [00:43<20:35, 260.52it/s]
#
#
# Computing:   4%|▎         | 11988/333070 [00:45<20:24, 262.16it/s]
#
#
# Computing:   4%|▍         | 12654/333070 [00:48<20:15, 263.62it/s]
#
#
# Computing:   4%|▍         | 13320/333070 [00:50<20:07, 264.75it/s]
#
#
# Computing:   4%|▍         | 13986/333070 [00:52<20:03, 265.04it/s]
#
#
# Computing:   4%|▍         | 14652/333070 [00:55<19:57, 266.01it/s]
#
#
# Computing:   5%|▍         | 15318/333070 [00:57<19:48, 267.32it/s]
#
#
# Computing:   5%|▍         | 15984/333070 [00:59<19:40, 268.69it/s]
#
#
# Computing:   5%|▍         | 16650/333070 [01:01<19:33, 269.63it/s]
#
#
# Computing:   5%|▌         | 17316/333070 [01:03<19:27, 270.57it/s]
#
#
# Computing:   5%|▌         | 17982/333070 [01:06<19:19, 271.75it/s]
#
#
# Computing:   6%|▌         | 18648/333070 [01:08<19:13, 272.53it/s]
#
#
# Computing:   6%|▌         | 19314/333070 [01:10<19:07, 273.43it/s]
#
#
# Computing:   6%|▌         | 19980/333070 [01:12<19:02, 273.94it/s]
#
#
# Computing:   6%|▌         | 20646/333070 [01:15<18:56, 274.85it/s]
#
#
# Computing:   6%|▋         | 21312/333070 [01:17<18:53, 275.05it/s]
#
#
# Computing:   7%|▋         | 21978/333070 [01:19<18:50, 275.26it/s]
#
#
# Computing:   7%|▋         | 22644/333070 [01:22<18:47, 275.21it/s]
#
#
# Computing:   7%|▋         | 23310/333070 [01:24<18:46, 275.09it/s]
#
#
# Computing:   7%|▋         | 23976/333070 [01:27<18:43, 275.02it/s]
#
#
# Computing:   7%|▋         | 24642/333070 [01:29<18:38, 275.73it/s]
#
#
# Computing:   8%|▊         | 25308/333070 [01:31<18:34, 276.04it/s]
#
#
# Computing:   8%|▊         | 25974/333070 [01:34<18:33, 275.70it/s]
#
#
# Computing:   8%|▊         | 26640/333070 [01:36<18:31, 275.67it/s]
#
#
# Computing:   8%|▊         | 27306/333070 [01:38<18:28, 275.87it/s]
#
#
# Computing:   8%|▊         | 27972/333070 [01:41<18:25, 275.94it/s]
#
#
# Computing:   9%|▊         | 28638/333070 [01:43<18:22, 276.17it/s]
#
#
# Computing:   9%|▉         | 29304/333070 [01:46<18:19, 276.38it/s]
#
#
# Computing:   9%|▉         | 29970/333070 [01:48<18:14, 276.95it/s]
#
#
# Computing:   9%|▉         | 30636/333070 [01:50<18:10, 277.30it/s]
#
#
# Computing:   9%|▉         | 31302/333070 [01:52<18:05, 278.06it/s]
#
#
# Computing:  10%|▉         | 31968/333070 [01:54<18:00, 278.66it/s]
#
#
# Computing:  10%|▉         | 32634/333070 [01:56<17:56, 279.14it/s]
#
#
# Computing:  10%|▉         | 33300/333070 [01:59<17:53, 279.20it/s]
#
#
# Computing:  10%|█         | 33966/333070 [02:01<17:50, 279.36it/s]
#
#
# Computing:  10%|█         | 34632/333070 [02:03<17:47, 279.58it/s]
#
#
# Computing:  11%|█         | 35298/333070 [02:06<17:44, 279.74it/s]
#
#
# Computing:  11%|█         | 35964/333070 [02:08<17:41, 280.01it/s]
#
#
# Computing:  11%|█         | 36630/333070 [02:10<17:38, 280.08it/s]
#
#
# Computing:  11%|█         | 37296/333070 [02:13<17:38, 279.54it/s]
#
#
# Computing:  11%|█▏        | 37962/333070 [02:15<17:36, 279.28it/s]
#
#
# Computing:  12%|█▏        | 38628/333070 [02:18<17:33, 279.42it/s]
#
#
# Computing:  12%|█▏        | 39294/333070 [02:20<17:30, 279.76it/s]
#
#
# Computing:  12%|█▏        | 39960/333070 [02:22<17:26, 280.19it/s]
#
#
# Computing:  12%|█▏        | 40626/333070 [02:24<17:22, 280.43it/s]
#
#
# Computing:  12%|█▏        | 41292/333070 [02:27<17:22, 279.98it/s]
#
#
# Computing:  13%|█▎        | 41958/333070 [02:30<17:26, 278.15it/s]
#
#
# Computing:  13%|█▎        | 42624/333070 [02:33<17:29, 276.84it/s]
#
#
# Computing:  13%|█▎        | 43290/333070 [02:36<17:28, 276.33it/s]
#
#
# Computing:  13%|█▎        | 43956/333070 [02:39<17:29, 275.43it/s]
#
#
# Computing:  13%|█▎        | 44622/333070 [02:42<17:27, 275.31it/s]
#
#
# Computing:  14%|█▎        | 45288/333070 [02:45<17:28, 274.38it/s]
#
#
# Computing:  14%|█▍        | 45954/333070 [02:47<17:27, 274.09it/s]
#
#
# Computing:  14%|█▍        | 46620/333070 [02:50<17:26, 273.83it/s]
#
#
# Computing:  14%|█▍        | 47286/333070 [02:53<17:27, 272.84it/s]
#
#
# Computing:  14%|█▍        | 47952/333070 [02:56<17:27, 272.19it/s]
#
#
# Computing:  15%|█▍        | 48618/333070 [02:59<17:30, 270.85it/s]
#
#
# Computing:  15%|█▍        | 49284/333070 [03:02<17:33, 269.43it/s]
#
#
# Computing:  15%|█▍        | 49950/333070 [03:05<17:33, 268.63it/s]
#
#
# Computing:  15%|█▌        | 50616/333070 [03:09<17:36, 267.43it/s]
#
#
# Computing:  15%|█▌        | 51282/333070 [03:12<17:39, 265.96it/s]
#
#
# Computing:  16%|█▌        | 51948/333070 [03:16<17:41, 264.82it/s]
#
#
# Computing:  16%|█▌        | 52614/333070 [03:19<17:44, 263.55it/s]
#
#
# Computing:  16%|█▌        | 53280/333070 [03:22<17:45, 262.47it/s]
#
#
# Computing:  16%|█▌        | 53946/333070 [03:26<17:47, 261.38it/s]
#
#
# Computing:  16%|█▋        | 54612/333070 [03:29<17:49, 260.29it/s]
#
#
# Computing:  17%|█▋        | 55278/333070 [03:33<17:51, 259.15it/s]
#
#
# Computing:  17%|█▋        | 55945/333070 [03:36<17:53, 258.15it/s]
#
#
# Computing:  17%|█▋        | 56610/333070 [03:40<17:54, 257.21it/s]
#
#
# Computing:  17%|█▋        | 57276/333070 [03:43<17:56, 256.22it/s]
#
#
# Computing:  17%|█▋        | 57942/333070 [03:47<17:58, 255.22it/s]
#
#
# Computing:  18%|█▊        | 58608/333070 [03:50<17:59, 254.17it/s]
#
#
# Computing:  18%|█▊        | 59274/333070 [03:53<18:00, 253.31it/s]
#
#
# Computing:  18%|█▊        | 59940/333070 [03:57<18:01, 252.57it/s]
#
#
# Computing:  18%|█▊        | 60606/333070 [04:00<18:02, 251.68it/s]
#
#
# Computing:  18%|█▊        | 61272/333070 [04:04<18:03, 250.92it/s]
#
#
# Computing:  19%|█▊        | 61938/333070 [04:07<18:04, 250.12it/s]
#
#
# Computing:  19%|█▉        | 62604/333070 [04:11<18:04, 249.35it/s]
#
#
# Computing:  19%|█▉        | 63270/333070 [04:14<18:05, 248.55it/s]
#
#
# Computing:  19%|█▉        | 63936/333070 [04:18<18:06, 247.72it/s]
#
#
# Computing:  19%|█▉        | 64602/333070 [04:21<18:07, 246.91it/s]
#
#
# Computing:  20%|█▉        | 65268/333070 [04:25<18:07, 246.23it/s]
#
#
# Computing:  20%|█▉        | 65934/333070 [04:28<18:07, 245.57it/s]
#
#
# Computing:  20%|█▉        | 66600/333070 [04:31<18:07, 244.95it/s]
#
#
# Computing:  20%|██        | 67266/333070 [04:35<18:07, 244.37it/s]
#
#
# Computing:  20%|██        | 67932/333070 [04:38<18:07, 243.82it/s]
#
#
# Computing:  21%|██        | 68598/333070 [04:42<18:07, 243.19it/s]
#
#
# Computing:  21%|██        | 69264/333070 [04:45<18:08, 242.45it/s]
#
#
# Computing:  21%|██        | 69930/333070 [04:49<18:07, 241.93it/s]
#
#
# Computing:  21%|██        | 70596/333070 [04:52<18:07, 241.27it/s]
#
#
# Computing:  21%|██▏       | 71262/333070 [04:56<18:10, 240.17it/s]
#
#
# Computing:  22%|██▏       | 71928/333070 [05:00<18:11, 239.34it/s]
#
#
# Computing:  22%|██▏       | 72594/333070 [05:04<18:10, 238.76it/s]
#
#
# Computing:  22%|██▏       | 73260/333070 [05:07<18:09, 238.37it/s]
#
#
# Computing:  22%|██▏       | 73926/333070 [05:10<18:09, 237.96it/s]
#
#
# Computing:  22%|██▏       | 74592/333070 [05:14<18:08, 237.46it/s]
#
#
# Computing:  23%|██▎       | 75258/333070 [05:17<18:07, 237.03it/s]
#
#
# Computing:  23%|██▎       | 75924/333070 [05:20<18:06, 236.71it/s]
#
#
# Computing:  23%|██▎       | 76590/333070 [05:24<18:05, 236.37it/s]
#
#
# Computing:  23%|██▎       | 77256/333070 [05:27<18:03, 236.13it/s]
#
#
# Computing:  23%|██▎       | 77922/333070 [05:30<18:01, 235.90it/s]
#
#
# Computing:  24%|██▎       | 78588/333070 [05:33<18:00, 235.58it/s]
#
#
# Computing:  24%|██▍       | 79254/333070 [05:36<17:58, 235.35it/s]
#
#
# Computing:  24%|██▍       | 79920/333070 [05:39<17:56, 235.14it/s]
#
#
# Computing:  24%|██▍       | 80586/333070 [05:43<17:54, 234.89it/s]
#
#
# Computing:  24%|██▍       | 81252/333070 [05:46<17:53, 234.65it/s]
#
#
# Computing:  25%|██▍       | 81918/333070 [05:49<17:51, 234.48it/s]
#
#
# Computing:  25%|██▍       | 82584/333070 [05:52<17:50, 234.02it/s]
#
#
# Computing:  25%|██▍       | 83250/333070 [05:56<17:50, 233.30it/s]
#
#
# Computing:  25%|██▌       | 83916/333070 [05:59<17:48, 233.21it/s]
#
#
# Computing:  25%|██▌       | 84582/333070 [06:02<17:46, 233.06it/s]
#
#
# Computing:  26%|██▌       | 85248/333070 [06:06<17:44, 232.91it/s]
#
#
# Computing:  26%|██▌       | 85914/333070 [06:09<17:41, 232.77it/s]
#
#
# Computing:  26%|██▌       | 86580/333070 [06:12<17:39, 232.60it/s]
#
#
# Computing:  26%|██▌       | 87246/333070 [06:15<17:37, 232.51it/s]
#
#
# Computing:  26%|██▋       | 87912/333070 [06:18<17:34, 232.44it/s]
#
#
# Computing:  27%|██▋       | 88578/333070 [06:21<17:33, 232.06it/s]
#
#
# Computing:  27%|██▋       | 89244/333070 [06:25<17:32, 231.76it/s]
#
#
# Computing:  27%|██▋       | 89910/333070 [06:28<17:30, 231.49it/s]
#
#
# Computing:  27%|██▋       | 90576/333070 [06:31<17:28, 231.37it/s]
#
#
# Computing:  27%|██▋       | 91242/333070 [06:34<17:25, 231.22it/s]
#
#
# Computing:  28%|██▊       | 91908/333070 [06:37<17:24, 230.96it/s]
#
#
# Computing:  28%|██▊       | 92574/333070 [06:40<17:20, 231.03it/s]
#
#
# Computing:  28%|██▊       | 93240/333070 [06:44<17:21, 230.31it/s]
#
#
# Computing:  28%|██▊       | 93906/333070 [06:48<17:20, 229.78it/s]
#
#
# Computing:  28%|██▊       | 94572/333070 [06:52<17:19, 229.51it/s]
#
#
# Computing:  29%|██▊       | 95238/333070 [06:55<17:18, 229.12it/s]
#
#
# Computing:  29%|██▉       | 95904/333070 [06:59<17:18, 228.39it/s]
#
#
# Computing:  29%|██▉       | 96570/333070 [07:04<17:20, 227.37it/s]
#
#
# Computing:  29%|██▉       | 97236/333070 [07:09<17:21, 226.38it/s]
#
#
# Computing:  29%|██▉       | 97902/333070 [07:13<17:21, 225.79it/s]
#
#
# Computing:  30%|██▉       | 98568/333070 [07:17<17:21, 225.25it/s]
#
#
# Computing:  30%|██▉       | 99234/333070 [07:20<17:18, 225.07it/s]
#
#
# Computing:  30%|██▉       | 99900/333070 [07:24<17:17, 224.66it/s]
#
#
# Computing:  30%|███       | 100566/333070 [07:28<17:16, 224.39it/s]
#
#
# Computing:  30%|███       | 101232/333070 [07:32<17:15, 223.81it/s]
#
#
# Computing:  31%|███       | 101898/333070 [07:36<17:16, 223.13it/s]
#
#
# Computing:  31%|███       | 102564/333070 [07:40<17:15, 222.56it/s]
#
#
# Computing:  31%|███       | 103230/333070 [07:43<17:12, 222.59it/s]
#
#
# Computing:  31%|███       | 103896/333070 [07:46<17:09, 222.68it/s]
#
#
# Computing:  31%|███▏      | 104562/333070 [07:49<17:06, 222.60it/s]
#
#
# Computing:  32%|███▏      | 105228/333070 [07:53<17:05, 222.28it/s]
#
#
# Computing:  32%|███▏      | 105894/333070 [07:56<17:03, 222.04it/s]
#
#
# Computing:  32%|███▏      | 106560/333070 [07:59<16:59, 222.12it/s]
#
#
# Computing:  32%|███▏      | 107226/333070 [08:02<16:56, 222.16it/s]
#
#
# Computing:  32%|███▏      | 107892/333070 [08:05<16:53, 222.24it/s]
#
#
# Computing:  33%|███▎      | 108558/333070 [08:08<16:50, 222.19it/s]
#
#
# Computing:  33%|███▎      | 109224/333070 [08:13<16:50, 221.55it/s]
#
#
# Computing:  33%|███▎      | 109890/333070 [08:16<16:47, 221.54it/s]
#
#
# Computing:  33%|███▎      | 110556/333070 [08:18<16:43, 221.65it/s]
#
#
# Computing:  33%|███▎      | 111222/333070 [08:21<16:40, 221.72it/s]
#
#
# Computing:  34%|███▎      | 111888/333070 [08:24<16:37, 221.71it/s]
#
#
# Computing:  34%|███▍      | 112554/333070 [08:28<16:37, 221.16it/s]
#
#
# Computing:  34%|███▍      | 113220/333070 [08:32<16:35, 220.74it/s]
#
#
# Computing:  34%|███▍      | 113886/333070 [08:36<16:34, 220.46it/s]
#
#
# Computing:  34%|███▍      | 114552/333070 [08:40<16:32, 220.25it/s]
#
#
# Computing:  35%|███▍      | 115218/333070 [08:42<16:28, 220.38it/s]
#
#
# Computing:  35%|███▍      | 115884/333070 [08:45<16:25, 220.37it/s]
#
#
# Computing:  35%|███▍      | 116550/333070 [08:49<16:22, 220.31it/s]
#
#
# Computing:  35%|███▌      | 117216/333070 [08:52<16:20, 220.18it/s]
#
#
# Computing:  35%|███▌      | 117882/333070 [08:55<16:17, 220.12it/s]
#
#
# Computing:  36%|███▌      | 118548/333070 [08:58<16:14, 220.23it/s]
#
#
# Computing:  36%|███▌      | 119214/333070 [09:01<16:10, 220.34it/s]
#
#
# Computing:  36%|███▌      | 119880/333070 [09:03<16:07, 220.46it/s]
#
#
# Computing:  36%|███▌      | 120546/333070 [09:06<16:03, 220.58it/s]
#
#
# Computing:  36%|███▋      | 121212/333070 [09:09<16:00, 220.60it/s]
#
#
# Computing:  37%|███▋      | 121878/333070 [09:13<15:58, 220.37it/s]
#
#
# Computing:  37%|███▋      | 122544/333070 [09:15<15:54, 220.48it/s]
#
#
# Computing:  37%|███▋      | 123210/333070 [09:18<15:51, 220.58it/s]
#
#
# Computing:  37%|███▋      | 123876/333070 [09:21<15:47, 220.70it/s]
#
#
# Computing:  37%|███▋      | 124542/333070 [09:24<15:44, 220.78it/s]
#
#
# Computing:  38%|███▊      | 125208/333070 [09:26<15:41, 220.84it/s]
#
#
# Computing:  38%|███▊      | 125874/333070 [09:29<15:37, 220.93it/s]
#
#
# Computing:  38%|███▊      | 126540/333070 [09:32<15:34, 220.98it/s]
#
#
# Computing:  38%|███▊      | 127206/333070 [09:35<15:31, 221.02it/s]
#
#
# Computing:  38%|███▊      | 127872/333070 [09:38<15:28, 221.10it/s]
#
#
# Computing:  39%|███▊      | 128538/333070 [09:41<15:24, 221.16it/s]
#
#
# Computing:  39%|███▉      | 129204/333070 [09:44<15:21, 221.21it/s]
#
#
# Computing:  39%|███▉      | 129870/333070 [09:46<15:18, 221.31it/s]
#
#
# Computing:  39%|███▉      | 130536/333070 [09:49<15:14, 221.38it/s]
#
#
# Computing:  39%|███▉      | 131202/333070 [09:52<15:11, 221.44it/s]
#
#
# Computing:  40%|███▉      | 131868/333070 [09:55<15:08, 221.50it/s]
#
#
# Computing:  40%|███▉      | 132534/333070 [09:58<15:05, 221.51it/s]
#
#
# Computing:  40%|███▉      | 133200/333070 [10:01<15:02, 221.56it/s]
#
#
# Computing:  40%|████      | 133866/333070 [10:04<14:58, 221.62it/s]
#
#
# Computing:  40%|████      | 134532/333070 [10:06<14:55, 221.69it/s]
#
#
# Computing:  41%|████      | 135198/333070 [10:09<14:52, 221.73it/s]
#
#
# Computing:  41%|████      | 135864/333070 [10:12<14:49, 221.79it/s]
#
#
# Computing:  41%|████      | 136530/333070 [10:15<14:45, 221.84it/s]
#
#
# Computing:  41%|████      | 137196/333070 [10:18<14:42, 221.91it/s]
# Computing:  41%|████▏     | 137862/333070 [10:21<14:39, 221.98it/s]
#
#
# Computing:  42%|████▏     | 138528/333070 [10:23<14:36, 222.05it/s]
#
#
# Computing:  42%|████▏     | 139194/333070 [10:26<14:32, 222.12it/s]
#
#
# Computing:  42%|████▏     | 139860/333070 [10:29<14:29, 222.21it/s]
#
#
# Computing:  42%|████▏     | 140526/333070 [10:32<14:26, 222.32it/s]
#
#
# Computing:  42%|████▏     | 141192/333070 [10:34<14:22, 222.41it/s]
#
#
# Computing:  43%|████▎     | 141858/333070 [10:37<14:19, 222.44it/s]
#
#
# Computing:  43%|████▎     | 142524/333070 [10:40<14:16, 222.50it/s]
#
#
# Computing:  43%|████▎     | 143190/333070 [10:43<14:13, 222.53it/s]
#
#
# Computing:  43%|████▎     | 143856/333070 [10:46<14:09, 222.62it/s]
#
#
# Computing:  43%|████▎     | 144522/333070 [10:48<14:06, 222.75it/s]
#
#
# Computing:  44%|████▎     | 145188/333070 [10:51<14:03, 222.85it/s]
#
#
# Computing:  44%|████▍     | 145854/333070 [10:54<13:59, 223.01it/s]
#
#
# Computing:  44%|████▍     | 146520/333070 [10:56<13:55, 223.22it/s]
#
#
# Computing:  44%|████▍     | 147186/333070 [10:58<13:52, 223.40it/s]
#
#
# Computing:  44%|████▍     | 147852/333070 [11:01<13:48, 223.58it/s]
#
#
# Computing:  45%|████▍     | 148518/333070 [11:03<13:44, 223.77it/s]
#
#
# Computing:  45%|████▍     | 149184/333070 [11:06<13:40, 224.00it/s]
#
#
# Computing:  45%|████▍     | 149850/333070 [11:08<13:36, 224.29it/s]
#
#
# Computing:  45%|████▌     | 150516/333070 [11:10<13:32, 224.57it/s]
#
#
# Computing:  45%|████▌     | 151182/333070 [11:12<13:28, 224.87it/s]
#
#
# Computing:  46%|████▌     | 151848/333070 [11:14<13:24, 225.18it/s]
#
#
# Computing:  46%|████▌     | 152514/333070 [11:16<13:20, 225.46it/s]
#
#
# Computing:  46%|████▌     | 153180/333070 [11:18<13:16, 225.76it/s]
#
#
# Computing:  46%|████▌     | 153846/333070 [11:20<13:12, 226.07it/s]
#
#
# Computing:  46%|████▋     | 154512/333070 [11:22<13:08, 226.31it/s]
#
#
# Computing:  47%|████▋     | 155178/333070 [11:24<13:05, 226.58it/s]
#
#
# Computing:  47%|████▋     | 155844/333070 [11:27<13:01, 226.80it/s]
#
#
# Computing:  47%|████▋     | 156510/333070 [11:29<12:57, 227.00it/s]
#
#
# Computing:  47%|████▋     | 157176/333070 [11:31<12:54, 227.16it/s]
#
#
# Computing:  47%|████▋     | 157842/333070 [11:34<12:50, 227.32it/s]
#
#
# Computing:  48%|████▊     | 158508/333070 [11:36<12:47, 227.46it/s]
#
#
# Computing:  48%|████▊     | 159174/333070 [11:39<12:44, 227.61it/s]
#
#
# Computing:  48%|████▊     | 159840/333070 [11:41<12:40, 227.74it/s]
#
#
# Computing:  48%|████▊     | 160506/333070 [11:44<12:37, 227.82it/s]
#
#
# Computing:  48%|████▊     | 161172/333070 [11:47<12:34, 227.91it/s]
#
#
# Computing:  49%|████▊     | 161838/333070 [11:49<12:31, 227.96it/s]
#
#
# Computing:  49%|████▉     | 162504/333070 [11:52<12:28, 228.01it/s]
#
#
# Computing:  49%|████▉     | 163170/333070 [11:55<12:25, 228.05it/s]
#
#
# Computing:  49%|████▉     | 163836/333070 [11:58<12:21, 228.11it/s]
#
#
# Computing:  49%|████▉     | 164502/333070 [12:00<12:18, 228.17it/s]
#
#
# Computing:  50%|████▉     | 165168/333070 [12:03<12:15, 228.23it/s]
#
#
# Computing:  50%|████▉     | 165834/333070 [12:06<12:12, 228.29it/s]
#
#
# Computing:  50%|████▉     | 166500/333070 [12:09<12:09, 228.36it/s]
#
#
# Computing:  50%|█████     | 167166/333070 [12:11<12:06, 228.40it/s]
#
#
# Computing:  50%|█████     | 167832/333070 [12:14<12:03, 228.50it/s]
#
#
# Computing:  51%|█████     | 168498/333070 [12:17<11:59, 228.61it/s]
#
#
# Computing:  51%|█████     | 169164/333070 [12:19<11:56, 228.73it/s]
#
#
# Computing:  51%|█████     | 169830/333070 [12:22<11:53, 228.83it/s]
#
#
# Computing:  51%|█████     | 170496/333070 [12:24<11:50, 228.96it/s]
#
#
# Computing:  51%|█████▏    | 171162/333070 [12:27<11:46, 229.09it/s]
#
#
# Computing:  52%|█████▏    | 171828/333070 [12:29<11:43, 229.25it/s]
#
#
# Computing:  52%|█████▏    | 172494/333070 [12:31<11:39, 229.41it/s]
#
#
# Computing:  52%|█████▏    | 173160/333070 [12:34<11:36, 229.64it/s]
#
#
# Computing:  52%|█████▏    | 173826/333070 [12:36<11:32, 229.82it/s]
#
#
# Computing:  52%|█████▏    | 174492/333070 [12:38<11:29, 230.00it/s]
#
#
# Computing:  53%|█████▎    | 175158/333070 [12:41<11:26, 230.15it/s]
#
#
# Computing:  53%|█████▎    | 175824/333070 [12:43<11:22, 230.24it/s]
#
#
# Computing:  53%|█████▎    | 176490/333070 [12:46<11:19, 230.40it/s]
#
#
# Computing:  53%|█████▎    | 177156/333070 [12:48<11:16, 230.58it/s]
#
#
# Computing:  53%|█████▎    | 177822/333070 [12:50<11:12, 230.71it/s]
#
#
# Computing:  54%|█████▎    | 178488/333070 [12:53<11:09, 230.82it/s]
#
#
# Computing:  54%|█████▍    | 179154/333070 [12:55<11:06, 230.90it/s]
#
#
# Computing:  54%|█████▍    | 179820/333070 [12:58<11:03, 230.85it/s]
#
#
# Computing:  54%|█████▍    | 180486/333070 [13:01<11:00, 230.91it/s]
#
#
# Computing:  54%|█████▍    | 181152/333070 [13:04<10:57, 230.96it/s]
#
#
# Computing:  55%|█████▍    | 181818/333070 [13:07<10:54, 231.01it/s]
#
#
# Computing:  55%|█████▍    | 182484/333070 [13:09<10:51, 231.03it/s]
#
#
# Computing:  55%|█████▍    | 183150/333070 [13:12<10:48, 231.05it/s]
#
#
# Computing:  55%|█████▌    | 183816/333070 [13:15<10:45, 231.12it/s]
#
#
# Computing:  55%|█████▌    | 184482/333070 [13:18<10:42, 231.15it/s]
#
#
# Computing:  56%|█████▌    | 185148/333070 [13:20<10:39, 231.20it/s]
#
#
# Computing:  56%|█████▌    | 185814/333070 [13:23<10:36, 231.26it/s]
#
#
# Computing:  56%|█████▌    | 186480/333070 [13:26<10:33, 231.33it/s]
#
#
# Computing:  56%|█████▌    | 187146/333070 [13:28<10:30, 231.39it/s]
#
#
# Computing:  56%|█████▋    | 187812/333070 [13:31<10:27, 231.42it/s]
#
#
# Computing:  57%|█████▋    | 188478/333070 [13:34<10:24, 231.45it/s]
#
#
# Computing:  57%|█████▋    | 189144/333070 [13:37<10:21, 231.47it/s]
#
#
# Computing:  57%|█████▋    | 189810/333070 [13:39<10:18, 231.49it/s]
#
#
# Computing:  57%|█████▋    | 190476/333070 [13:42<10:15, 231.53it/s]
#
#
# Computing:  57%|█████▋    | 191142/333070 [13:45<10:12, 231.58it/s]
#
#
# Computing:  58%|█████▊    | 191808/333070 [13:47<10:09, 231.67it/s]
#
#
# Computing:  58%|█████▊    | 192474/333070 [13:50<10:06, 231.74it/s]
#
#
# Computing:  58%|█████▊    | 193140/333070 [13:52<10:03, 231.87it/s]
#
#
# Computing:  58%|█████▊    | 193806/333070 [13:55<10:00, 231.99it/s]
#
#
# Computing:  58%|█████▊    | 194472/333070 [13:57<09:57, 232.09it/s]
#
#
# Computing:  59%|█████▊    | 195138/333070 [14:00<09:54, 232.18it/s]
#
#
# Computing:  59%|█████▉    | 195804/333070 [14:03<09:50, 232.27it/s]
#
#
# Computing:  59%|█████▉    | 196470/333070 [14:05<09:47, 232.41it/s]
#
#
# Computing:  59%|█████▉    | 197136/333070 [14:07<09:44, 232.68it/s]
#
#
# Computing:  59%|█████▉    | 197802/333070 [14:09<09:40, 232.93it/s]
#
#
# Computing:  60%|█████▉    | 198468/333070 [14:10<09:37, 233.23it/s]
#
#
# Computing:  60%|█████▉    | 199134/333070 [14:12<09:33, 233.59it/s]
#
#
# Computing:  60%|█████▉    | 199800/333070 [14:14<09:29, 233.90it/s]
#
#
# Computing:  60%|██████    | 200466/333070 [14:15<09:26, 234.21it/s]
#
#
# Computing:  60%|██████    | 201132/333070 [14:17<09:22, 234.53it/s]
#
#
# Computing:  61%|██████    | 201798/333070 [14:19<09:18, 234.88it/s]
#
#
# Computing:  61%|██████    | 202464/333070 [14:20<09:15, 235.25it/s]
#
#
# Computing:  61%|██████    | 203130/333070 [14:22<09:11, 235.59it/s]
#
#
# Computing:  61%|██████    | 203796/333070 [14:24<09:08, 235.82it/s]
#
#
# Computing:  61%|██████▏   | 204462/333070 [14:26<09:05, 235.87it/s]
#
#
# Computing:  62%|██████▏   | 205128/333070 [14:28<09:01, 236.16it/s]
#
#
# Computing:  62%|██████▏   | 205794/333070 [14:30<08:58, 236.34it/s]
#
#
# Computing:  62%|██████▏   | 206460/333070 [14:33<08:55, 236.40it/s]
#
#
# Computing:  62%|██████▏   | 207126/333070 [14:35<08:52, 236.67it/s]
#
#
# Computing:  62%|██████▏   | 207792/333070 [14:37<08:48, 236.89it/s]
#
#
# Computing:  63%|██████▎   | 208458/333070 [14:38<08:45, 237.22it/s]
#
#
# Computing:  63%|██████▎   | 209124/333070 [14:40<08:42, 237.43it/s]
#
#
# Computing:  63%|██████▎   | 209790/333070 [14:43<08:38, 237.53it/s]
#
#
# Computing:  63%|██████▎   | 210456/333070 [14:45<08:36, 237.55it/s]
#
#
# Computing:  63%|██████▎   | 211122/333070 [14:48<08:33, 237.70it/s]
#
#
# Computing:  64%|██████▎   | 211788/333070 [14:50<08:29, 237.91it/s]
#
#
# Computing:  64%|██████▍   | 212454/333070 [14:52<08:26, 238.11it/s]
#
#
# Computing:  64%|██████▍   | 213120/333070 [14:54<08:23, 238.31it/s]
#
#
# Computing:  64%|██████▍   | 213786/333070 [14:56<08:19, 238.58it/s]
#
#
# Computing:  64%|██████▍   | 214452/333070 [14:57<08:16, 238.87it/s]
#
#
# Computing:  65%|██████▍   | 215118/333070 [14:59<08:13, 239.11it/s]
#
#
# Computing:  65%|██████▍   | 215784/333070 [15:01<08:09, 239.39it/s]
#
#
# Computing:  65%|██████▍   | 216450/333070 [15:03<08:06, 239.66it/s]
#
#
# Computing:  65%|██████▌   | 217116/333070 [15:05<08:03, 239.91it/s]
#
#
# Computing:  65%|██████▌   | 217782/333070 [15:06<08:00, 240.17it/s]
#
#
# Computing:  66%|██████▌   | 218448/333070 [15:08<07:56, 240.50it/s]
#
#
# Computing:  66%|██████▌   | 219114/333070 [15:10<07:53, 240.78it/s]
#
#
# Computing:  66%|██████▌   | 219780/333070 [15:11<07:49, 241.05it/s]
#
#
# Computing:  66%|██████▌   | 220446/333070 [15:13<07:46, 241.25it/s]
#
#
# Computing:  66%|██████▋   | 221112/333070 [15:15<07:43, 241.55it/s]
#
#
# Computing:  67%|██████▋   | 221778/333070 [15:16<07:40, 241.88it/s]
#
#
# Computing:  67%|██████▋   | 222444/333070 [15:18<07:36, 242.20it/s]
#
#
# Computing:  67%|██████▋   | 223110/333070 [15:20<07:33, 242.47it/s]
#
#
# Computing:  67%|██████▋   | 223776/333070 [15:22<07:30, 242.55it/s]
#
#
# Computing:  67%|██████▋   | 224442/333070 [15:25<07:27, 242.62it/s]
#
#
# Computing:  68%|██████▊   | 225108/333070 [15:27<07:24, 242.73it/s]
#
#
# Computing:  68%|██████▊   | 225774/333070 [15:29<07:21, 243.00it/s]
#
#
# Computing:  68%|██████▊   | 226440/333070 [15:30<07:18, 243.31it/s]
#
#
# Computing:  68%|██████▊   | 227106/333070 [15:32<07:14, 243.63it/s]
#
#
# Computing:  68%|██████▊   | 227772/333070 [15:33<07:11, 243.95it/s]
#
#
# Computing:  69%|██████▊   | 228438/333070 [15:35<07:08, 244.29it/s]
#
#
# Computing:  69%|██████▉   | 229104/333070 [15:36<07:04, 244.66it/s]
#
#
# Computing:  69%|██████▉   | 229770/333070 [15:37<07:01, 244.99it/s]
#
#
# Computing:  69%|██████▉   | 230436/333070 [15:39<06:58, 245.32it/s]
#
#
# Computing:  69%|██████▉   | 231102/333070 [15:40<06:55, 245.67it/s]
#
#
# Computing:  70%|██████▉   | 231768/333070 [15:42<06:51, 246.02it/s]
#
#
# Computing:  70%|██████▉   | 232434/333070 [15:43<06:48, 246.36it/s]
#
#
# Computing:  70%|██████▉   | 233100/333070 [15:44<06:45, 246.67it/s]
#
#
# Computing:  70%|███████   | 233766/333070 [15:46<06:42, 246.97it/s]
#
#
# Computing:  70%|███████   | 234432/333070 [15:48<06:38, 247.29it/s]
#
#
# Computing:  71%|███████   | 235098/333070 [15:49<06:35, 247.63it/s]
#
#
# Computing:  71%|███████   | 235764/333070 [15:50<06:32, 247.94it/s]
#
#
# Computing:  71%|███████   | 236430/333070 [15:52<06:29, 248.23it/s]
#
#
# Computing:  71%|███████   | 237096/333070 [15:54<06:26, 248.49it/s]
#
#
# Computing:  71%|███████▏  | 237763/333070 [15:56<06:23, 248.51it/s]
#
#
# Computing:  72%|███████▏  | 238428/333070 [15:58<06:20, 248.71it/s]
#
#
# Computing:  72%|███████▏  | 239094/333070 [16:00<06:17, 248.88it/s]
#
#
# Computing:  72%|███████▏  | 239760/333070 [16:02<06:14, 249.02it/s]
#
#
# Computing:  72%|███████▏  | 240426/333070 [16:04<06:11, 249.33it/s]
#
#
# Computing:  72%|███████▏  | 241092/333070 [16:05<06:08, 249.59it/s]
#
#
# Computing:  73%|███████▎  | 241758/333070 [16:07<06:05, 249.89it/s]
#
#
# Computing:  73%|███████▎  | 242424/333070 [16:09<06:02, 250.17it/s]
#
#
# Computing:  73%|███████▎  | 243090/333070 [16:10<05:59, 250.45it/s]
#
#
# Computing:  73%|███████▎  | 243756/333070 [16:12<05:56, 250.74it/s]
#
#
# Computing:  73%|███████▎  | 244422/333070 [16:13<05:53, 251.04it/s]
#
#
# Computing:  74%|███████▎  | 245088/333070 [16:14<05:49, 251.39it/s]
#
#
# Computing:  74%|███████▍  | 245754/333070 [16:17<05:47, 251.54it/s]
#
#
# Computing:  74%|███████▍  | 246420/333070 [16:18<05:44, 251.89it/s]
#
#
# Computing:  74%|███████▍  | 247086/333070 [16:19<05:40, 252.17it/s]
#
#
# Computing:  74%|███████▍  | 247752/333070 [16:21<05:37, 252.49it/s]
#
#
# Computing:  75%|███████▍  | 248418/333070 [16:22<05:34, 252.81it/s]
#
#
# Computing:  75%|███████▍  | 249084/333070 [16:24<05:31, 253.13it/s]
#
#
# Computing:  75%|███████▍  | 249750/333070 [16:25<05:28, 253.43it/s]
#
#
# Computing:  75%|███████▌  | 250416/333070 [16:27<05:25, 253.65it/s]
#
#
# Computing:  75%|███████▌  | 251082/333070 [16:29<05:23, 253.83it/s]
#
#
# Computing:  76%|███████▌  | 251748/333070 [16:31<05:20, 253.97it/s]
#
#
# Computing:  76%|███████▌  | 252414/333070 [16:32<05:17, 254.25it/s]
#
#
# Computing:  76%|███████▌  | 253080/333070 [16:34<05:14, 254.58it/s]
#
#
# Computing:  76%|███████▌  | 253746/333070 [16:35<05:11, 254.88it/s]
#
#
# Computing:  76%|███████▋  | 254412/333070 [16:36<05:08, 255.22it/s]
#
#
# Computing:  77%|███████▋  | 255078/333070 [16:38<05:05, 255.42it/s]
#
#
# Computing:  77%|███████▋  | 255744/333070 [16:41<05:02, 255.38it/s]
#
#
# Computing:  77%|███████▋  | 256410/333070 [16:43<05:00, 255.49it/s]
#
#
# Computing:  77%|███████▋  | 257076/333070 [16:46<04:57, 255.39it/s]
#
#
# Computing:  77%|███████▋  | 257742/333070 [16:49<04:55, 255.32it/s]
#
#
# Computing:  78%|███████▊  | 258408/333070 [16:51<04:52, 255.35it/s]
#
#
# Computing:  78%|███████▊  | 259074/333070 [16:54<04:49, 255.28it/s]
#
#
# Computing:  78%|███████▊  | 259740/333070 [16:56<04:47, 255.42it/s]
#
#
# Computing:  78%|███████▊  | 260406/333070 [16:58<04:44, 255.56it/s]
#
#
# Computing:  78%|███████▊  | 261072/333070 [17:01<04:41, 255.68it/s]
#
#
# Computing:  79%|███████▊  | 261738/333070 [17:03<04:38, 255.85it/s]
#
#
# Computing:  79%|███████▉  | 262404/333070 [17:04<04:35, 256.06it/s]
#
#
# Computing:  79%|███████▉  | 263070/333070 [17:06<04:33, 256.25it/s]
#
#
# Computing:  79%|███████▉  | 263736/333070 [17:08<04:30, 256.48it/s]
#
#
# Computing:  79%|███████▉  | 264402/333070 [17:10<04:27, 256.61it/s]
#
#
# Computing:  80%|███████▉  | 265068/333070 [17:12<04:24, 256.85it/s]
#
#
# Computing:  80%|███████▉  | 265734/333070 [17:13<04:21, 257.09it/s]
#
#
# Computing:  80%|███████▉  | 266400/333070 [17:15<04:19, 257.27it/s]
#
#
# Computing:  80%|████████  | 267066/333070 [17:17<04:16, 257.44it/s]
#
#
# Computing:  80%|████████  | 267732/333070 [17:19<04:13, 257.65it/s]
#
#
# Computing:  81%|████████  | 268398/333070 [17:20<04:10, 257.86it/s]
#
#
# Computing:  81%|████████  | 269064/333070 [17:22<04:08, 257.97it/s]
#
#
# Computing:  81%|████████  | 269730/333070 [17:24<04:05, 258.20it/s]
#
#
# Computing:  81%|████████  | 270396/333070 [17:26<04:02, 258.39it/s]
#
#
# Computing:  81%|████████▏ | 271062/333070 [17:28<03:59, 258.55it/s]
#
#
# Computing:  82%|████████▏ | 271728/333070 [17:31<03:57, 258.49it/s]
#
#
# Computing:  82%|████████▏ | 272394/333070 [17:33<03:54, 258.62it/s]
#
#
# Computing:  82%|████████▏ | 273060/333070 [17:35<03:51, 258.79it/s]
#
#
# Computing:  82%|████████▏ | 273726/333070 [17:36<03:49, 258.99it/s]
#
#
# Computing:  82%|████████▏ | 274392/333070 [17:38<03:46, 259.20it/s]
# Computing:  83%|████████▎ | 275058/333070 [17:40<03:43, 259.28it/s]
#
#
# Computing:  83%|████████▎ | 275724/333070 [17:42<03:41, 259.45it/s]
#
#
# Computing:  83%|████████▎ | 276390/333070 [17:44<03:38, 259.65it/s]
#
#
# Computing:  83%|████████▎ | 277056/333070 [17:46<03:35, 259.66it/s]
#
#
# Computing:  83%|████████▎ | 277722/333070 [17:49<03:33, 259.75it/s]
#
#
# Computing:  84%|████████▎ | 278388/333070 [17:51<03:30, 259.84it/s]
#
#
# Computing:  84%|████████▍ | 279054/333070 [17:54<03:27, 259.70it/s]
#
#
# Computing:  84%|████████▍ | 279720/333070 [17:57<03:25, 259.66it/s]
#
#
# Computing:  84%|████████▍ | 280386/333070 [17:59<03:22, 259.81it/s]
#
#
# Computing:  84%|████████▍ | 281052/333070 [18:01<03:20, 259.95it/s]
#
#
# Computing:  85%|████████▍ | 281718/333070 [18:02<03:17, 260.23it/s]
#
#
# Computing:  85%|████████▍ | 282384/333070 [18:04<03:14, 260.43it/s]
#
#
# Computing:  85%|████████▍ | 283050/333070 [18:05<03:11, 260.74it/s]
#
#
# Computing:  85%|████████▌ | 283716/333070 [18:07<03:09, 261.00it/s]
#
#
# Computing:  85%|████████▌ | 284382/333070 [18:08<03:06, 261.25it/s]
#
#
# Computing:  86%|████████▌ | 285048/333070 [18:10<03:03, 261.41it/s]
#
#
# Computing:  86%|████████▌ | 285714/333070 [18:12<03:01, 261.61it/s]
#
#
# Computing:  86%|████████▌ | 286380/333070 [18:13<02:58, 261.85it/s]
#
#
# Computing:  86%|████████▌ | 287046/333070 [18:15<02:55, 262.07it/s]
#
#
# Computing:  86%|████████▋ | 287712/333070 [18:17<02:53, 262.18it/s]
#
#
# Computing:  87%|████████▋ | 288378/333070 [18:19<02:50, 262.26it/s]
#
#
# Computing:  87%|████████▋ | 289044/333070 [18:21<02:47, 262.34it/s]
#
#
# Computing:  87%|████████▋ | 289710/333070 [18:23<02:45, 262.44it/s]
#
#
# Computing:  87%|████████▋ | 290376/333070 [18:25<02:42, 262.58it/s]
#
#
# Computing:  87%|████████▋ | 291042/333070 [18:27<02:39, 262.73it/s]
#
#
# Computing:  88%|████████▊ | 291708/333070 [18:29<02:37, 263.00it/s]
#
#
# Computing:  88%|████████▊ | 292374/333070 [18:30<02:34, 263.25it/s]
#
#
# Computing:  88%|████████▊ | 293040/333070 [18:32<02:32, 263.31it/s]
#
#
# Computing:  88%|████████▊ | 293706/333070 [18:34<02:29, 263.51it/s]
#
#
# Computing:  88%|████████▊ | 294372/333070 [18:35<02:26, 263.88it/s]
#
#
# Computing:  89%|████████▊ | 295038/333070 [18:36<02:23, 264.18it/s]
#
#
# Computing:  89%|████████▉ | 295704/333070 [18:37<02:21, 264.51it/s]
#
#
# Computing:  89%|████████▉ | 296370/333070 [18:39<02:18, 264.83it/s]
#
#
# Computing:  89%|████████▉ | 297036/333070 [18:40<02:15, 265.11it/s]
#
#
# Computing:  89%|████████▉ | 297702/333070 [18:41<02:13, 265.34it/s]
#
#
# Computing:  90%|████████▉ | 298368/333070 [18:43<02:10, 265.52it/s]
#
#
# Computing:  90%|████████▉ | 299034/333070 [18:45<02:08, 265.66it/s]
#
#
# Computing:  90%|████████▉ | 299700/333070 [18:47<02:05, 265.71it/s]
#
#
# Computing:  90%|█████████ | 300366/333070 [18:50<02:03, 265.67it/s]
#
#
# Computing:  90%|█████████ | 301032/333070 [18:53<02:00, 265.53it/s]
#
#
# Computing:  91%|█████████ | 301698/333070 [18:56<01:58, 265.47it/s]
#
#
# Computing:  91%|█████████ | 302364/333070 [18:58<01:55, 265.53it/s]
#
#
# Computing:  91%|█████████ | 303030/333070 [19:00<01:53, 265.64it/s]
#
#
# Computing:  91%|█████████ | 303696/333070 [19:03<01:50, 265.69it/s]
#
#
# Computing:  91%|█████████▏| 304362/333070 [19:05<01:48, 265.78it/s]
#
#
# Computing:  92%|█████████▏| 305028/333070 [19:07<01:45, 265.85it/s]
#
#
# Computing:  92%|█████████▏| 305694/333070 [19:09<01:42, 265.99it/s]
#
#
# Computing:  92%|█████████▏| 306360/333070 [19:10<01:40, 266.21it/s]
#
#
# Computing:  92%|█████████▏| 307026/333070 [19:12<01:37, 266.45it/s]
#
#
# Computing:  92%|█████████▏| 307692/333070 [19:14<01:35, 266.61it/s]
#
#
# Computing:  93%|█████████▎| 308358/333070 [19:15<01:32, 266.77it/s]
#
#
# Computing:  93%|█████████▎| 309024/333070 [19:17<01:30, 267.05it/s]
#
#
# Computing:  93%|█████████▎| 309690/333070 [19:18<01:27, 267.27it/s]
#
#
# Computing:  93%|█████████▎| 310356/333070 [19:20<01:24, 267.38it/s]
#
#
# Computing:  93%|█████████▎| 311022/333070 [19:22<01:22, 267.66it/s]
#
#
# Computing:  94%|█████████▎| 311688/333070 [19:23<01:19, 267.82it/s]
#
#
# Computing:  94%|█████████▍| 312354/333070 [19:25<01:17, 268.00it/s]
#
#
# Computing:  94%|█████████▍| 313020/333070 [19:26<01:14, 268.32it/s]
#
#
# Computing:  94%|█████████▍| 313686/333070 [19:28<01:12, 268.55it/s]
#
#
# Computing:  94%|█████████▍| 314352/333070 [19:29<01:09, 268.81it/s]
#
#
# Computing:  95%|█████████▍| 315018/333070 [19:31<01:07, 268.95it/s]
#
#
# Computing:  95%|█████████▍| 315684/333070 [19:33<01:04, 269.09it/s]
#
#
# Computing:  95%|█████████▍| 316350/333070 [19:34<01:02, 269.25it/s]
#
#
# Computing:  95%|█████████▌| 317016/333070 [19:36<00:59, 269.40it/s]
#
#
# Computing:  95%|█████████▌| 317682/333070 [19:38<00:57, 269.53it/s]
#
#
# Computing:  96%|█████████▌| 318348/333070 [19:40<00:54, 269.64it/s]
#
#
# Computing:  96%|█████████▌| 319014/333070 [19:42<00:52, 269.75it/s]
#
#
# Computing:  96%|█████████▌| 319680/333070 [19:44<00:49, 269.84it/s]
#
#
# Computing:  96%|█████████▌| 320346/333070 [19:46<00:47, 269.98it/s]
#
#
# Computing:  96%|█████████▋| 321012/333070 [19:48<00:44, 270.16it/s]
#
#
# Computing:  97%|█████████▋| 321678/333070 [19:49<00:42, 270.36it/s]
#
#
# Computing:  97%|█████████▋| 322344/333070 [19:51<00:39, 270.52it/s]
#
#
# Computing:  97%|█████████▋| 323010/333070 [19:53<00:37, 270.65it/s]
#
#
# Computing:  97%|█████████▋| 323676/333070 [19:55<00:34, 270.81it/s]
#
#
# Computing:  97%|█████████▋| 324342/333070 [19:56<00:32, 271.04it/s]
#
#
# Computing:  98%|█████████▊| 325008/333070 [19:57<00:29, 271.34it/s]
#
#
# Computing:  98%|█████████▊| 325674/333070 [19:58<00:27, 271.65it/s]
#
#
# Computing:  98%|█████████▊| 326340/333070 [19:59<00:24, 271.95it/s]
#
#
# Computing:  98%|█████████▊| 327006/333070 [20:01<00:22, 272.26it/s]
#
#
# Computing:  98%|█████████▊| 327672/333070 [20:02<00:19, 272.57it/s]
#
#
# Computing:  99%|█████████▊| 328338/333070 [20:03<00:17, 272.88it/s]
#
#
# Computing:  99%|█████████▉| 329004/333070 [20:04<00:14, 273.20it/s]
#
#
# Computing:  99%|█████████▉| 329670/333070 [20:05<00:12, 273.50it/s]
#
#
# Computing:  99%|█████████▉| 330336/333070 [20:06<00:09, 273.79it/s]
#
#
# Computing:  99%|█████████▉| 331002/333070 [20:07<00:07, 274.09it/s]
#
#
# Computing: 100%|█████████▉| 331668/333070 [20:08<00:05, 274.38it/s]
#
#
# Computing: 100%|█████████▉| 332334/333070 [20:09<00:02, 274.69it/s]
#
#
# Computing: 100%|██████████| 333070/333070 [20:10<00:00, 275.10it/s]
#
#
# Build coo matrix: 100%|██████████| 333070/333070 [20:10<00:00, 275.09it/s]
#
#
# Done: 100%|██████████| 333070/333070 [20:21<00:00, 272.59it/s]

# %%
save_npz('tfidf_300.npz', cos_sim.tocsr())

# %%
tf_idf_matrix[1].data
# Out:
# array([0.08557718, 0.08411946, 0.13826249, 0.13346997, 0.08264572,
#        0.08334072, 0.08253552, 0.16952436, 0.21962298, 0.21962298,
#        0.23380988, 0.20206775, 0.16698972, 0.14297814, 0.17387934,
#        0.23578514, 0.20383918, 0.26192819, 0.2724043 , 0.15087366,
#        0.172217  , 0.13084198, 0.1415761 , 0.09790477, 0.09508332,
#        0.14103535, 0.14190545, 0.1396905 , 0.14412404, 0.08929529,
#        0.23039994, 0.17349882, 0.17788399, 0.18644586, 0.06919488,
#        0.06897476, 0.06766189, 0.16925091])

# %%
similarity = load_npz('tfidf_300.npz')

# %%
similarity[2].data.argsort()[::-1]
# Out:
# array([  0, 128,  78,   3,  75,  26, 157,  39, 162, 293,  95, 257, 122,
#         13, 235, 217, 150, 270,   6, 149, 205,  60, 175, 126,  33,  62,
#        218,  87, 148, 142,  72, 222, 167, 258, 290, 103, 280, 152, 277,
#         17,  73, 132,  76, 189, 279, 203, 232, 255, 151,  31, 154,  22,
#         20,  18, 124, 130, 178, 143, 156,  71, 197, 196,  23, 214, 101,
#        297,  98, 294, 251,  52, 234, 291, 253, 282, 201, 292,  53,  35,
#        238, 260,  70,  96,  79,  21,  36, 191, 171, 125,  16,  44, 284,
#         90, 120, 209, 168,  57, 268,  80, 146,  55,  10,  34,  59, 278,
#         38, 207, 230,  91, 187, 131,  92,  49, 271, 166, 147, 267, 231,
#        285, 248,  84, 298, 137, 226,  54, 192, 121, 105, 289, 210, 190,
#        159,  74, 249,  25, 236,  46,  48, 250,   1, 116, 141,  56,   7,
#        288, 206, 153,  15, 180, 123,  65, 273, 110, 195, 252, 111, 202,
#         47, 185, 265, 179, 239, 161, 119,  27, 237, 211, 262, 274,  89,
#         42,  43, 221, 193, 242,  63, 204,  86, 263, 261, 155, 107, 286,
#        241, 240, 173, 245, 127, 139, 133, 272, 102, 228, 233, 112, 169,
#          2, 208, 145, 244, 186, 104,  77, 114, 227,  67, 182,  37,  40,
#          8, 275, 177,  85, 117, 225,  68, 194, 188, 176,  61, 138, 174,
#         88, 215, 259,  58, 264, 295, 296, 219, 181, 243, 266, 287, 136,
#        246,   9,  97, 164,  12, 113, 276, 160,  28,  83, 129, 118, 170,
#        172, 144, 216, 212,  66, 158, 281,  50, 165,  41,  99, 115,   5,
#        299, 100,  81, 213, 140,  94, 108, 223,  14,   4, 135, 283,  93,
#         19, 198, 224,  29, 200, 229, 109,  69,  45, 254, 220,  32, 163,
#        134, 269, 247,  51, 184, 183, 256, 199,  24, 106,  30,  11,  82,
#         64])

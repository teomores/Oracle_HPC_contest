# %%
import pandas as pd
import similaripy as sim
from scipy import *
from scipy.sparse import *
from tqdm import tqdm
import numpy as np

import re
import string as string_lib
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def ngrams(string, n=3):
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower() #make lower case
    chars_to_remove = [")","(","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string) #remove the list of chars defined above
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single space
    string = ' '+ string +' ' # pad names for ngrams...
    string = re.sub(r'[,-/]',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
ngrams('ciao')
# Out:
# [' ci', 'cia', 'iao', 'ao ']

# %%
# first load the data
df_train = pd.read_csv("../dataset/original/train.csv", escapechar="\\")
df_test = pd.read_csv("../dataset/original/test.csv", escapechar="\\")
# ALWAYS sort the data by record_id
df_train = df_train.sort_values(by=['record_id']).reset_index(drop=True)
df_test = df_test.sort_values(by=['record_id']).reset_index(drop=True)

# %%
df_train.name = df_train.name.astype(str)
df_test.name = df_test.name.astype(str)

# %%
corpus_train = [ngrams(x) for x in tqdm(df_train.name.tolist())]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 691440/691440 [00:07<00:00, 96437.22it/s]

# %%
corpus_test = [ngrams(x) for x in tqdm(df_test.name.tolist())]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 266955/266955 [00:02<00:00, 96040.17it/s]

# %%
from rank_bm25 import BM25Okapi

# %%
bm25 = BM25Okapi(corpus_train)

# %%
df_test.head()
# Out:
#          record_id                                          name    type  \
# 0  10000003-TST-MR                            HOTFOCUS CO., LTD.  entity
# 1   10000008-TST-M                           BONUS TRADE LIMITED  entity
# 2  10000010-TST-CP                              NEW IDEA LIMITED  entity
# 3  10000013-TST-MR                         VICTORY GROUP LIMITED  entity
# 4  10000016-TST-MR  NINGBO RAPID INTERNATIONAL TRADING CO., LTD.  entity
#
#   address         phone                  email    modification
# 0     NaN  4.401574e+11  consulting@outlook.ch     move unique
# 1     NaN           NaN         help@gmail.gov        move row
# 2     NaN  1.912469e+10                    NaN  identical copy
# 3     NaN  1.949506e+10                    NaN     move unique
# 4     NaN  4.446512e+11        info@outlook.cz     move unique

# %%
m = ngrams('VICTORY GROUP LIMITED')
bm25.get_top_n(m, corpus_train, n=1)
# Out:
# [[' wi',
#   'win',
#   'in ',
#   'n v',
#   ' vi',
#   'vic',
#   'ict',
#   'cto',
#   'tor',
#   'ory',
#   'ry ',
#   'y g',
#   ' gr',
#   'gro',
#   'rou',
#   'oup',
#   'up ',
#   'p l',
#   ' li',
#   'lim',
#   'imi',
#   'mit',
#   'ite',
#   'ted',
#   'ed ']]

# %%
df_train.name = df_train.name.str.lower()

# %%
df_train[df_train.name.str.startswith('ningbo e')]
# Out:
#            record_id                                               name  \
# 1062        10000596                     ningbo everwin int'l co., ltd.
# 9644        10005311                         ningbo enlly trade limited
# 9645     10005311-M0                         ningbo enlly trade limited
# 9646     10005311-M1                         ningbo enlly trade limited
# 19655       10010930                   ningbo e.t.d. hotfocus co., ltd.
# 19656   10010930-NV0                   ningbo e.t.d. hotfocus co., ltd.
# 19657   10010930-NV1                   ningbo e.t.d. hotfocus co., ltd.
# 19659    10010930-T1                   ningbo e.t.d. hotfocus co., ltd.
# 33198       10018485                    ningbo easy houseware co., ltd.
# 33199   10018485-NV0                    ningbo easy houseware co., ltd.
# 33200   10018485-NV1                    ningbo easy houseware co., ltd.
# 33201    10018485-T0                    ningbo easy houseware co., ltd.
# 33202    10018485-T1                    ningbo easy houseware co., ltd.
# 33203    10018485-T2                    ningbo easy houweware co., ltd.
# 35842       10019988                     ningbo everwin int'l co., ltd.
# 35843   10019988-NV0                     ningbo everwin int'l co., ltd.
# 35844    10019988-T0                     ningbo everwin int'l co., ltd.
# 35846    10019988-T2                     ningbo everwin ins'l co., lzd.
# 35847    10019988-T3                     ningbo everwin insil coa, ltd.
# 35848    10019988-T4                     ningbo everwin int'l co., ltd.
# 47951       10026683            ningbo elecstar international co., ltd.
# 245429      10137763  ningbo ever sunlight electronic technology co....
# 269877      10151323  ningbo eiko manufacturing & researching develo...
#
#           type                                            address  \
# 1062    entity                                                NaN
# 9644    entity                                                NaN
# 9645    entity                                                NaN
# 9646    entity                                                NaN
# 19655   entity                                                NaN
# 19656   entity  AKARA BUILDING 24; DE CASTRO STREET; WICKHAM'S...
# 19657   entity       Humahuaca 4647 - 8p; Buenos Aires; Argentina
# 19659   entity                                                NaN
# 33198   entity                                                NaN
# 33199   entity                                                NaN
# 33200   entity                                                NaN
# 33201   entity                                                NaN
# 33202   entity                                                NaN
# 33203   entity                                                NaN
# 35842   entity                                                NaN
# 35843   entity                                                NaN
# 35844   entity                                                NaN
# 35846   entity                                                NaN
# 35847   entity                                                NaN
# 35848   entity                                                NaN
# 47951   entity                                                NaN
# 245429  entity                                                NaN
# 269877  entity                                                NaN
#
#                phone                               email modification  \
# 1062    3.387127e+11  help@Ningbo.Everwin.Intl.Co.Ltd.de     original
# 9644    3.981359e+09                                 NaN     original
# 9645    3.981359e+09                                 NaN      missing
# 9646             NaN                                 NaN      missing
# 19655   4.207394e+11                                 NaN     original
# 19656   3.327373e+11                                 NaN    new_value
# 19657   3.327373e+11                                 NaN    new_value
# 19659   4.207394e+11                                 NaN         typo
# 33198   4.489950e+11                                 NaN     original
# 33199   4.489950e+11                                 NaN    new_value
# 33200   3.348977e+11                       sales@zoho.de    new_value
# 33201   4.299958e+11                                 NaN         typo
# 33202   4.489950e+11                                 NaN         typo
# 33203   4.489950e+11                                 NaN         typo
# 35842   4.185531e+12                                 NaN     original
# 35843   4.185531e+12                                 NaN    new_value
# 35844   4.185531e+12                                 NaN         typo
# 35846   4.185531e+12                                 NaN         typo
# 35847   4.185531e+12                                 NaN         typo
# 35848   4.185531e+12                                 NaN         typo
# 47951   4.428708e+11                                 NaN     original
# 245429  4.408843e+11                                 NaN     original
# 269877           NaN                                 NaN     original
#
#         linked_id
# 1062     10000596
# 9644     10005311
# 9645     10005311
# 9646     10005311
# 19655    10010930
# 19656    10010930
# 19657    10010930
# 19659    10010930
# 33198    10018485
# 33199    10018485
# 33200    10018485
# 33201    10018485
# 33202    10018485
# 33203    10018485
# 35842    10019988
# 35843    10019988
# 35844    10019988
# 35846    10019988
# 35847    10019988
# 35848    10019988
# 47951    10026683
# 245429   10137763
# 269877   10151323

# %%
# mi serve una colonna con tutti i telefoni su cui fare tfidf
all_phones = list(df_train.phone) + list(df_test.phone)
# daje con tfidf
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams)
tf_idf_matrix = vectorizer.fit_transform(all_phones)

# %%
# split
tf_idf_train = tf_idf_matrix[:691440,:] # 691440 è la lunghezza del train
tf_idf_test = tf_idf_matrix[691440:,:]
jac = sim.jaccard(tf_idf_test, tf_idf_train.T, k=300)
save_npz('jaccard_tfidf_phone.npz', jac.tocsr())
# Out:
# Computing:   8%|████▏                                                   | 20254/266955 [01:12<14:44, 278.92it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-03939e646b39> in <module>
#       2 tf_idf_train = tf_idf_matrix[:691440,:] # 691440 è la lunghezza del train
#       3 tf_idf_test = tf_idf_matrix[691440:,:]
# ----> 4 jac = sim.jaccard(tf_idf_test, tf_idf_train.T, k=300)
#       5 save_npz('jaccard_tfidf_phone.npz', jac.tocsr())
#
# c:\users\blueace17\appdata\local\programs\python\python37\lib\site-packages\similaripy\similarity.py in jaccard(matrix1, matrix2, k, shrink, threshold, binary, target_rows, target_cols, filter_cols, verbose, format_output)
#     128         filter_cols=filter_cols,
#     129         verbose=verbose,
# --> 130         format_output=format_output)
#     131
#     132
#
# c:\users\blueace17\appdata\local\programs\python\python37\lib\site-packages\similaripy\cython_code\s_plus.pyx in similaripy.cython_code.s_plus.s_plus()
#
# c:\users\blueace17\appdata\local\programs\python\python37\lib\site-packages\tqdm\_tqdm.py in refresh(self, nolock)
#    1286             self._lock.release()
#    1287
# -> 1288     def refresh(self, nolock=False):
#    1289         """
#    1290         Force refresh the display of this bar
#
# KeyboardInterrupt:
